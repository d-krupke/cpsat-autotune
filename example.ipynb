# %%
from cpsat_autotune import (
    tune_for_quality_within_timelimit,
    import_model,
    tune_time_to_optimal,
    tune_for_gap_within_timelimit
)

# %%
model = import_model("models/model_proto_-1368620059351071685.pb")

# %%
best = tune_time_to_optimal(
    model,
    max_time_in_seconds=3,  # Enter a time limit slightly above what the solver with default parameters needs
    n_samples_for_trial=5,  # Number of samples for each trial
    n_samples_for_verification=20,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-17 15:09:47,283 - INFO - Starting tuning to minimize time to optimal solution.
# 2024-08-17 15:09:47,284 - INFO - Initialized Metric with direction: minimize
# 2024-08-17 15:09:47,284 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-17 15:09:47,285 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:09:47,285 - INFO - Starting solver with random_seed: 1383549011, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:49,485 - INFO - Solver completed in 2.198949 seconds with status: 4
# 2024-08-17 15:09:49,485 - INFO - Starting solver with random_seed: 731376590, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:50,788 - INFO - Solver completed in 1.302853 seconds with status: 4
# 2024-08-17 15:09:50,789 - INFO - Starting solver with random_seed: 1159130177, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:53,133 - INFO - Solver completed in 2.343719 seconds with status: 4
# 2024-08-17 15:09:53,134 - INFO - Starting solver with random_seed: 468747690, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:54,857 - INFO - Solver completed in 1.722484 seconds with status: 4
# 2024-08-17 15:09:54,857 - INFO - Starting solver with random_seed: 1798926168, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:56,611 - INFO - Solver completed in 1.753743 seconds with status: 4
# 2024-08-17 15:09:56,612 - INFO - Starting solver with random_seed: 600782994, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:58,286 - INFO - Solver completed in 1.673676 seconds with status: 4
# 2024-08-17 15:09:58,287 - INFO - Starting solver with random_seed: 737962264, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:59,844 - INFO - Solver completed in 1.557517 seconds with status: 4
# 2024-08-17 15:09:59,845 - INFO - Starting solver with random_seed: 745399630, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:00,927 - INFO - Solver completed in 1.081431 seconds with status: 4
# 2024-08-17 15:10:00,927 - INFO - Starting solver with random_seed: 2052148764, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:02,141 - INFO - Solver completed in 1.213306 seconds with status: 4
# 2024-08-17 15:10:02,142 - INFO - Starting solver with random_seed: 1429799148, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:03,736 - INFO - Solver completed in 1.59372 seconds with status: 4
# 2024-08-17 15:10:03,736 - INFO - Starting solver with random_seed: 43922353, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:04,898 - INFO - Solver completed in 1.161242 seconds with status: 4
# 2024-08-17 15:10:04,899 - INFO - Starting solver with random_seed: 628305042, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:06,856 - INFO - Solver completed in 1.957506 seconds with status: 4
# 2024-08-17 15:10:06,857 - INFO - Starting solver with random_seed: 445775452, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:08,713 - INFO - Solver completed in 1.856066 seconds with status: 4
# 2024-08-17 15:10:08,714 - INFO - Starting solver with random_seed: 1845824163, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:10,491 - INFO - Solver completed in 1.776368 seconds with status: 4
# 2024-08-17 15:10:10,491 - INFO - Starting solver with random_seed: 1846298692, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:11,995 - INFO - Solver completed in 1.503162 seconds with status: 4
# 2024-08-17 15:10:11,995 - INFO - Starting solver with random_seed: 2108725596, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:13,992 - INFO - Solver completed in 1.996321 seconds with status: 4
# 2024-08-17 15:10:13,992 - INFO - Starting solver with random_seed: 927218145, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:15,636 - INFO - Solver completed in 1.643715 seconds with status: 4
# 2024-08-17 15:10:15,637 - INFO - Starting solver with random_seed: 724022840, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:16,679 - INFO - Solver completed in 1.042017 seconds with status: 4
# 2024-08-17 15:10:16,680 - INFO - Starting solver with random_seed: 1045821842, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:18,136 - INFO - Solver completed in 1.455871 seconds with status: 4
# 2024-08-17 15:10:18,137 - INFO - Starting solver with random_seed: 345444695, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:19,595 - INFO - Solver completed in 1.457841 seconds with status: 4
# 2024-08-17 15:10:19,595 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:10:19,596 - INFO - Baseline evaluation completed: min=1.042017, mean=1.6145753500000002, max=2.343719
# [I 2024-08-17 15:10:19,596] A new study created in memory with name: no-name-59dce673-abb6-441a-bea9-b580bdfbfb8d
# 2024-08-17 15:10:19,597 - INFO - Starting Optuna optimization.
# 2024-08-17 15:10:19,598 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:19,599 - INFO - Returning cached result.
# 2024-08-17 15:10:19,599 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:19,599 - INFO - Starting solver with random_seed: 433169133, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:20,675 - INFO - Solver completed in 1.075845 seconds with status: 4
# 2024-08-17 15:10:20,676 - INFO - Starting solver with random_seed: 1476692721, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:22,965 - INFO - Solver completed in 2.289141 seconds with status: 4
# 2024-08-17 15:10:22,966 - INFO - Starting solver with random_seed: 1754256381, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:24,124 - INFO - Solver completed in 1.158078 seconds with status: 4
# 2024-08-17 15:10:24,125 - INFO - Starting solver with random_seed: 1216852700, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:25,414 - INFO - Solver completed in 1.288465 seconds with status: 4
# 2024-08-17 15:10:25,414 - INFO - Starting solver with random_seed: 786984063, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:26,982 - INFO - Solver completed in 1.567383 seconds with status: 4
# 2024-08-17 15:10:26,983 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:10:26,983 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 15:10:26,983 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 20, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:26,983 - INFO - Starting solver with random_seed: 974059647, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:28,291 - INFO - Solver completed in 1.306799 seconds with status: 4
# 2024-08-17 15:10:28,291 - INFO - Starting solver with random_seed: 864658485, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:30,448 - INFO - Solver completed in 2.156084 seconds with status: 4
# 2024-08-17 15:10:30,448 - INFO - Starting solver with random_seed: 1252545414, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:32,118 - INFO - Solver completed in 1.669441 seconds with status: 4
# 2024-08-17 15:10:32,118 - INFO - Starting solver with random_seed: 1751689855, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:33,526 - INFO - Solver completed in 1.407192 seconds with status: 4
# 2024-08-17 15:10:33,527 - INFO - Starting solver with random_seed: 1818976676, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:35,077 - INFO - Solver completed in 1.550501 seconds with status: 4
# 2024-08-17 15:10:35,078 - INFO - Starting solver with random_seed: 711169691, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:36,498 - INFO - Solver completed in 1.419432 seconds with status: 4
# 2024-08-17 15:10:36,498 - INFO - Starting solver with random_seed: 61135604, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:37,765 - INFO - Solver completed in 1.265988 seconds with status: 4
# 2024-08-17 15:10:37,765 - INFO - Starting solver with random_seed: 893988656, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:39,270 - INFO - Solver completed in 1.503954 seconds with status: 4
# 2024-08-17 15:10:39,270 - INFO - Starting solver with random_seed: 1303795509, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:40,291 - INFO - Solver completed in 1.020418 seconds with status: 4
# 2024-08-17 15:10:40,291 - INFO - Starting solver with random_seed: 1910072538, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:41,803 - INFO - Solver completed in 1.511771 seconds with status: 4
# 2024-08-17 15:10:41,804 - INFO - Starting solver with random_seed: 1320267979, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:43,180 - INFO - Solver completed in 1.376199 seconds with status: 4
# 2024-08-17 15:10:43,181 - INFO - Starting solver with random_seed: 1022384131, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:44,477 - INFO - Solver completed in 1.295129 seconds with status: 4
# 2024-08-17 15:10:44,477 - INFO - Starting solver with random_seed: 217027896, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:45,693 - INFO - Solver completed in 1.215908 seconds with status: 4
# 2024-08-17 15:10:45,694 - INFO - Starting solver with random_seed: 515290921, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:47,110 - INFO - Solver completed in 1.415464 seconds with status: 4
# 2024-08-17 15:10:47,110 - INFO - Starting solver with random_seed: 949165866, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:48,347 - INFO - Solver completed in 1.236637 seconds with status: 4
# 2024-08-17 15:10:48,348 - INFO - Evaluation completed and result cached.
# [I 2024-08-17 15:10:48,350] Trial 0 finished with value: 1.43649145 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:48,353 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:48,354 - INFO - Returning cached result.
# 2024-08-17 15:10:48,354 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'max_lp', 'reduced_costs', 'lb_tree_search'], 'search_branching': 1, 'repair_hint': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:48,354 - INFO - Starting solver with random_seed: 693063401, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:51,366 - INFO - Solver completed in 3.011815 seconds with status: 2
# 2024-08-17 15:10:51,367 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:10:51,367 - INFO - Returning knockout result.
# [I 2024-08-17 15:10:51,368] Trial 1 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 1, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:51,372 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:51,372 - INFO - Returning cached result.
# 2024-08-17 15:10:51,372 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 8, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:51,372 - INFO - Starting solver with random_seed: 1302118268, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:54,392 - INFO - Solver completed in 3.019359 seconds with status: 2
# 2024-08-17 15:10:54,393 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:10:54,393 - INFO - Returning knockout result.
# [I 2024-08-17 15:10:54,394] Trial 2 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:54,397 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:54,397 - INFO - Returning cached result.
# 2024-08-17 15:10:54,397 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 8, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:54,397 - INFO - Starting solver with random_seed: 283089937, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:57,411 - INFO - Solver completed in 3.013814 seconds with status: 2
# 2024-08-17 15:10:57,412 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:10:57,412 - INFO - Returning knockout result.
# [I 2024-08-17 15:10:57,413] Trial 3 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 8, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:57,416 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:57,416 - INFO - Returning cached result.
# 2024-08-17 15:10:57,417 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 1, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:57,417 - INFO - Starting solver with random_seed: 779169821, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:00,429 - INFO - Solver completed in 3.011973 seconds with status: 2
# 2024-08-17 15:11:00,430 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:00,430 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:00,431] Trial 4 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:00,436 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:00,437 - INFO - Returning cached result.
# 2024-08-17 15:11:00,437 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'probing'], 'search_branching': 6, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:00,437 - INFO - Starting solver with random_seed: 1793497393, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:03,461 - INFO - Solver completed in 3.023445 seconds with status: 2
# 2024-08-17 15:11:03,462 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:03,462 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:03,463] Trial 5 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:03,469 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:03,469 - INFO - Returning cached result.
# 2024-08-17 15:11:03,470 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 8, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:03,470 - INFO - Starting solver with random_seed: 1100474644, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:06,493 - INFO - Solver completed in 3.022235 seconds with status: 2
# 2024-08-17 15:11:06,493 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:06,494 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:06,494] Trial 6 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:06,497 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:06,498 - INFO - Returning cached result.
# 2024-08-17 15:11:06,498 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'clause_cleanup_protection': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'pseudo_costs', 'quick_restart'], 'search_branching': 3, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:06,499 - INFO - Starting solver with random_seed: 1640489858, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:09,532 - INFO - Solver completed in 3.032785 seconds with status: 2
# 2024-08-17 15:11:09,532 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:09,533 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:09,534] Trial 7 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:09,538 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:09,538 - INFO - Returning cached result.
# 2024-08-17 15:11:09,539 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:09,539 - INFO - Starting solver with random_seed: 1950262535, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:12,554 - INFO - Solver completed in 3.014564 seconds with status: 2
# 2024-08-17 15:11:12,554 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:12,555 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:12,556] Trial 8 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:12,559 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:12,559 - INFO - Returning cached result.
# 2024-08-17 15:11:12,560 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 5, 'repair_hint': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'polish_lp_solution': True, 'linearization_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:12,560 - INFO - Starting solver with random_seed: 1356428682, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:15,578 - INFO - Solver completed in 3.017247 seconds with status: 2
# 2024-08-17 15:11:15,578 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:15,578 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:15,579] Trial 9 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 5, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:15,622 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:15,622 - INFO - Returning cached result.
# 2024-08-17 15:11:15,622 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:15,623 - INFO - Starting solver with random_seed: 575150107, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:18,005 - INFO - Solver completed in 2.382045 seconds with status: 4
# 2024-08-17 15:11:18,006 - INFO - Starting solver with random_seed: 1559614286, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:20,533 - INFO - Solver completed in 2.526615 seconds with status: 4
# 2024-08-17 15:11:20,533 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:20,534] Trial 10 finished with value: 2.526615 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:20,577 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:20,577 - INFO - Returning cached result.
# 2024-08-17 15:11:20,578 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:20,578 - INFO - Starting solver with random_seed: 1391725227, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:23,426 - INFO - Solver completed in 2.848024 seconds with status: 4
# 2024-08-17 15:11:23,427 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:23,428] Trial 11 finished with value: 2.848024 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:23,472 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:23,472 - INFO - Returning cached result.
# 2024-08-17 15:11:23,473 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:23,473 - INFO - Starting solver with random_seed: 551823881, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:25,352 - INFO - Solver completed in 1.878258 seconds with status: 4
# 2024-08-17 15:11:25,352 - INFO - Starting solver with random_seed: 1905696713, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:26,566 - INFO - Solver completed in 1.213452 seconds with status: 4
# 2024-08-17 15:11:26,567 - INFO - Starting solver with random_seed: 679618146, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:28,467 - INFO - Solver completed in 1.899754 seconds with status: 4
# 2024-08-17 15:11:28,467 - INFO - Starting solver with random_seed: 1681706302, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:29,969 - INFO - Solver completed in 1.501197 seconds with status: 4
# 2024-08-17 15:11:29,969 - INFO - Starting solver with random_seed: 791831354, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:31,850 - INFO - Solver completed in 1.880544 seconds with status: 4
# 2024-08-17 15:11:31,851 - INFO - Evaluation completed and result cached.
# [I 2024-08-17 15:11:31,852] Trial 12 finished with value: 1.674641 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:31,898 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:31,899 - INFO - Returning cached result.
# 2024-08-17 15:11:31,899 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:31,899 - INFO - Starting solver with random_seed: 1405727505, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:34,918 - INFO - Solver completed in 3.018759 seconds with status: 2
# 2024-08-17 15:11:34,919 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:34,919 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:34,920] Trial 13 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:34,966 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:34,967 - INFO - Returning cached result.
# 2024-08-17 15:11:34,967 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['quick_restart_no_lp'], 'search_branching': 2, 'repair_hint': True, 'use_lb_relax_lns': True, 'linearization_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:34,967 - INFO - Starting solver with random_seed: 1083188333, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:37,119 - INFO - Solver completed in 2.151598 seconds with status: 4
# 2024-08-17 15:11:37,120 - INFO - Starting solver with random_seed: 35545220, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:39,312 - INFO - Solver completed in 2.191862 seconds with status: 4
# 2024-08-17 15:11:39,313 - INFO - Starting solver with random_seed: 1151479737, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:40,710 - INFO - Solver completed in 1.39737 seconds with status: 4
# 2024-08-17 15:11:40,711 - INFO - Starting solver with random_seed: 1615106164, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:43,451 - INFO - Solver completed in 2.739361 seconds with status: 4
# 2024-08-17 15:11:43,451 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:43,452] Trial 14 finished with value: 2.739361 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# ...
# 2024-08-17 15:14:56,661 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-17 15:14:56,661 - INFO - Starting solver with random_seed: 2099374351, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:57,125 - INFO - Solver completed in 0.463796 seconds with status: 4
# 2024-08-17 15:14:57,126 - INFO - Starting solver with random_seed: 1216632387, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:57,694 - INFO - Solver completed in 0.5678 seconds with status: 4
# 2024-08-17 15:14:57,695 - INFO - Starting solver with random_seed: 433861621, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:58,035 - INFO - Solver completed in 0.340633 seconds with status: 4
# 2024-08-17 15:14:58,036 - INFO - Starting solver with random_seed: 468255983, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:58,464 - INFO - Solver completed in 0.427433 seconds with status: 4
# 2024-08-17 15:14:58,464 - INFO - Starting solver with random_seed: 44821627, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:59,031 - INFO - Solver completed in 0.566793 seconds with status: 4
# 2024-08-17 15:14:59,032 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:14:59,032 - INFO - Parameter 'fp_rounding' can be dropped from the optimized parameters.
# 2024-08-17 15:14:59,032 - INFO - Evaluating resetting parameter 'linearization_level' to default...
# 2024-08-17 15:14:59,033 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'cut_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-17 15:14:59,033 - INFO - Starting solver with random_seed: 1572225200, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:59,394 - INFO - Solver completed in 0.360752 seconds with status: 4
# 2024-08-17 15:14:59,395 - INFO - Starting solver with random_seed: 856239723, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:59,882 - INFO - Solver completed in 0.486927 seconds with status: 4
# 2024-08-17 15:14:59,883 - INFO - Starting solver with random_seed: 1299956550, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:00,212 - INFO - Solver completed in 0.328881 seconds with status: 4
# 2024-08-17 15:15:00,212 - INFO - Starting solver with random_seed: 1017194230, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:00,624 - INFO - Solver completed in 0.411077 seconds with status: 4
# 2024-08-17 15:15:00,625 - INFO - Starting solver with random_seed: 32253583, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:01,054 - INFO - Solver completed in 0.429314 seconds with status: 4
# 2024-08-17 15:15:01,055 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:01,055 - INFO - Parameter 'linearization_level' can be dropped from the optimized parameters.
# 2024-08-17 15:15:01,055 - INFO - Evaluating resetting parameter 'cut_level' to default...
# 2024-08-17 15:15:01,056 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-17 15:15:01,056 - INFO - Starting solver with random_seed: 551824446, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:02,062 - INFO - Solver completed in 1.005344 seconds with status: 4
# 2024-08-17 15:15:02,062 - INFO - Starting solver with random_seed: 775340561, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:03,079 - INFO - Solver completed in 1.016922 seconds with status: 4
# 2024-08-17 15:15:03,080 - INFO - Starting solver with random_seed: 1626517169, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:03,708 - INFO - Solver completed in 0.627719 seconds with status: 4
# 2024-08-17 15:15:03,709 - INFO - Starting solver with random_seed: 2127519714, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:04,365 - INFO - Solver completed in 0.655867 seconds with status: 4
# 2024-08-17 15:15:04,366 - INFO - Starting solver with random_seed: 158304753, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:05,318 - INFO - Solver completed in 0.952177 seconds with status: 4
# 2024-08-17 15:15:05,319 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:05,319 - INFO - Parameter 'cut_level' is essential for performance.
# 2024-08-17 15:15:05,319 - INFO - Evaluating resetting parameter 'max_all_diff_cut_size' to default...
# 2024-08-17 15:15:05,319 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 0, 'cut_level': 0}, num_runs: 5, knockout_score: None
# 2024-08-17 15:15:05,320 - INFO - Starting solver with random_seed: 1091904205, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:05,782 - INFO - Solver completed in 0.462024 seconds with status: 4
# 2024-08-17 15:15:05,783 - INFO - Starting solver with random_seed: 183911944, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:06,265 - INFO - Solver completed in 0.481871 seconds with status: 4
# 2024-08-17 15:15:06,266 - INFO - Starting solver with random_seed: 532192160, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:06,734 - INFO - Solver completed in 0.467556 seconds with status: 4
# 2024-08-17 15:15:06,734 - INFO - Starting solver with random_seed: 1574286536, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:07,167 - INFO - Solver completed in 0.432335 seconds with status: 4
# 2024-08-17 15:15:07,167 - INFO - Starting solver with random_seed: 1169282574, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:07,505 - INFO - Solver completed in 0.337355 seconds with status: 4
# 2024-08-17 15:15:07,506 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:07,506 - INFO - Parameter 'max_all_diff_cut_size' can be dropped from the optimized parameters.
# 2024-08-17 15:15:07,507 - INFO - Evaluating with params: {'cp_model_probing_level': 0, 'cut_level': 0}, num_runs: 20, knockout_score: None
# 2024-08-17 15:15:07,507 - INFO - Starting solver with random_seed: 979707413, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:08,000 - INFO - Solver completed in 0.492724 seconds with status: 4
# 2024-08-17 15:15:08,001 - INFO - Starting solver with random_seed: 65512579, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:08,410 - INFO - Solver completed in 0.408467 seconds with status: 4
# 2024-08-17 15:15:08,410 - INFO - Starting solver with random_seed: 1723007468, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:08,820 - INFO - Solver completed in 0.409854 seconds with status: 4
# 2024-08-17 15:15:08,821 - INFO - Starting solver with random_seed: 1381109162, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:09,377 - INFO - Solver completed in 0.555909 seconds with status: 4
# 2024-08-17 15:15:09,378 - INFO - Starting solver with random_seed: 786588924, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:10,218 - INFO - Solver completed in 0.8403 seconds with status: 4
# 2024-08-17 15:15:10,219 - INFO - Starting solver with random_seed: 1645869035, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:10,650 - INFO - Solver completed in 0.430959 seconds with status: 4
# 2024-08-17 15:15:10,651 - INFO - Starting solver with random_seed: 471296462, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:11,075 - INFO - Solver completed in 0.423553 seconds with status: 4
# 2024-08-17 15:15:11,076 - INFO - Starting solver with random_seed: 251538341, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:11,633 - INFO - Solver completed in 0.557149 seconds with status: 4
# 2024-08-17 15:15:11,634 - INFO - Starting solver with random_seed: 1883378135, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:12,113 - INFO - Solver completed in 0.479583 seconds with status: 4
# 2024-08-17 15:15:12,114 - INFO - Starting solver with random_seed: 223675718, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:12,480 - INFO - Solver completed in 0.365221 seconds with status: 4
# 2024-08-17 15:15:12,480 - INFO - Starting solver with random_seed: 1699145421, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:12,849 - INFO - Solver completed in 0.368419 seconds with status: 4
# 2024-08-17 15:15:12,849 - INFO - Starting solver with random_seed: 1624246718, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:13,303 - INFO - Solver completed in 0.453353 seconds with status: 4
# 2024-08-17 15:15:13,304 - INFO - Starting solver with random_seed: 380087502, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:13,645 - INFO - Solver completed in 0.340489 seconds with status: 4
# 2024-08-17 15:15:13,645 - INFO - Starting solver with random_seed: 403692753, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:14,042 - INFO - Solver completed in 0.396563 seconds with status: 4
# 2024-08-17 15:15:14,043 - INFO - Starting solver with random_seed: 837440845, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:14,528 - INFO - Solver completed in 0.48506 seconds with status: 4
# 2024-08-17 15:15:14,529 - INFO - Starting solver with random_seed: 1438387659, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:14,920 - INFO - Solver completed in 0.390817 seconds with status: 4
# 2024-08-17 15:15:14,921 - INFO - Starting solver with random_seed: 1422537533, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:15,333 - INFO - Solver completed in 0.411689 seconds with status: 4
# 2024-08-17 15:15:15,333 - INFO - Starting solver with random_seed: 2007885659, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:15,816 - INFO - Solver completed in 0.482978 seconds with status: 4
# 2024-08-17 15:15:15,817 - INFO - Starting solver with random_seed: 945806970, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:16,501 - INFO - Solver completed in 0.683314 seconds with status: 4
# 2024-08-17 15:15:16,502 - INFO - Starting solver with random_seed: 1826445006, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:17,088 - INFO - Solver completed in 0.586123 seconds with status: 4
# 2024-08-17 15:15:17,089 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:17,089 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter              ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ cp_model_probing_level │   0   │    49.51%    │       2       │
# │ 2   │ cut_level              │   0   │    50.49%    │       1       │
# └─────┴────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
#
# 2. cut_level Sets the level of effort the solver will invest in generating cutting planes, which are linear
# constraints added to remove infeasible regions. Properly applied, cuts can significantly reduce the search space
# and help the solver find an optimal solution more quickly.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                                    ┃ Mean ┃  Min ┃  Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━━━┩
# │ Time in seconds with Default Parameters   │ 1.61 │ 1.04 │ 2.34 │       20 │
# │ Time in seconds with Optimized Parameters │ 0.48 │ 0.34 │ 0.84 │       20 │
# └───────────────────────────────────────────┴──────┴──────┴──────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-17 15:15:17,105 - INFO - Hyperparameter tuning completed.
# 2024-08-17 15:15:17,106 - INFO - Tuning for time to optimal completed.

# %%
best = tune_for_quality_within_timelimit(
    model,
    max_time_in_seconds=0.5,
    obj_for_timeout=0,
    direction="maximize",
    n_samples_for_trial=10,  # Number of samples for each trial
    n_samples_for_verification=40,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-17 19:42:37,659 - INFO - Starting tuning for quality within time limit. Direction: maximize
# 2024-08-17 19:42:37,660 - INFO - Initialized Metric with direction: maximize
# 2024-08-17 19:42:37,660 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-17 19:42:37,661 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:42:37,661 - INFO - Starting solver with random_seed: 1439404906, max_time_in_seconds: 0.3
# 2024-08-17 19:42:37,978 - INFO - Solver found a solution with objective value: 129425.0
# 2024-08-17 19:42:37,979 - INFO - Starting solver with random_seed: 805884198, max_time_in_seconds: 0.3
# 2024-08-17 19:42:38,300 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-17 19:42:38,301 - INFO - Starting solver with random_seed: 59810992, max_time_in_seconds: 0.3
# 2024-08-17 19:42:38,616 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:38,616 - INFO - Starting solver with random_seed: 409088018, max_time_in_seconds: 0.3
# 2024-08-17 19:42:38,933 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:38,933 - INFO - Starting solver with random_seed: 1726402466, max_time_in_seconds: 0.3
# 2024-08-17 19:42:39,250 - INFO - Solver found a solution with objective value: 129636.0
# 2024-08-17 19:42:39,250 - INFO - Starting solver with random_seed: 1998602666, max_time_in_seconds: 0.3
# 2024-08-17 19:42:39,566 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:39,567 - INFO - Starting solver with random_seed: 1075115735, max_time_in_seconds: 0.3
# 2024-08-17 19:42:39,881 - INFO - Solver found a solution with objective value: 132304.0
# 2024-08-17 19:42:39,882 - INFO - Starting solver with random_seed: 605290671, max_time_in_seconds: 0.3
# 2024-08-17 19:42:40,196 - INFO - Solver found a solution with objective value: 129315.0
# 2024-08-17 19:42:40,196 - INFO - Starting solver with random_seed: 1779507707, max_time_in_seconds: 0.3
# 2024-08-17 19:42:40,512 - INFO - Solver found a solution with objective value: 129388.0
# 2024-08-17 19:42:40,513 - INFO - Starting solver with random_seed: 933385695, max_time_in_seconds: 0.3
# 2024-08-17 19:42:40,828 - INFO - Solver found a solution with objective value: 128843.0
# 2024-08-17 19:42:40,828 - INFO - Starting solver with random_seed: 1592627667, max_time_in_seconds: 0.3
# 2024-08-17 19:42:41,141 - INFO - Solver found a solution with objective value: 128529.0
# 2024-08-17 19:42:41,142 - INFO - Starting solver with random_seed: 1526599747, max_time_in_seconds: 0.3
# 2024-08-17 19:42:41,457 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:41,457 - INFO - Starting solver with random_seed: 636654888, max_time_in_seconds: 0.3
# 2024-08-17 19:42:41,778 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:41,778 - INFO - Starting solver with random_seed: 864083045, max_time_in_seconds: 0.3
# 2024-08-17 19:42:42,092 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-17 19:42:42,093 - INFO - Starting solver with random_seed: 1756352267, max_time_in_seconds: 0.3
# 2024-08-17 19:42:42,407 - INFO - Solver found a solution with objective value: 131285.0
# 2024-08-17 19:42:42,408 - INFO - Starting solver with random_seed: 2066278921, max_time_in_seconds: 0.3
# 2024-08-17 19:42:42,721 - INFO - Solver found a solution with objective value: 129134.0
# 2024-08-17 19:42:42,722 - INFO - Starting solver with random_seed: 1603571871, max_time_in_seconds: 0.3
# 2024-08-17 19:42:43,046 - INFO - Solver found a solution with objective value: 129793.0
# 2024-08-17 19:42:43,047 - INFO - Starting solver with random_seed: 7214387, max_time_in_seconds: 0.3
# 2024-08-17 19:42:43,361 - INFO - Solver found a solution with objective value: 129669.0
# 2024-08-17 19:42:43,362 - INFO - Starting solver with random_seed: 1588642809, max_time_in_seconds: 0.3
# 2024-08-17 19:42:43,677 - INFO - Solver found a solution with objective value: 129666.0
# 2024-08-17 19:42:43,678 - INFO - Starting solver with random_seed: 1803263649, max_time_in_seconds: 0.3
# 2024-08-17 19:42:43,992 - INFO - Solver found a solution with objective value: 132765.0
# 2024-08-17 19:42:43,993 - INFO - Starting solver with random_seed: 866537646, max_time_in_seconds: 0.3
# 2024-08-17 19:42:44,307 - INFO - Solver found a solution with objective value: 129403.0
# 2024-08-17 19:42:44,308 - INFO - Starting solver with random_seed: 234652366, max_time_in_seconds: 0.3
# 2024-08-17 19:42:44,623 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:44,624 - INFO - Starting solver with random_seed: 1301500069, max_time_in_seconds: 0.3
# 2024-08-17 19:42:44,939 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:44,939 - INFO - Starting solver with random_seed: 1558547370, max_time_in_seconds: 0.3
# 2024-08-17 19:42:45,254 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:42:45,254 - INFO - Starting solver with random_seed: 1695570308, max_time_in_seconds: 0.3
# 2024-08-17 19:42:45,569 - INFO - Solver found a solution with objective value: 131955.0
# 2024-08-17 19:42:45,570 - INFO - Starting solver with random_seed: 890463390, max_time_in_seconds: 0.3
# 2024-08-17 19:42:45,885 - INFO - Solver found a solution with objective value: 129735.0
# 2024-08-17 19:42:45,885 - INFO - Starting solver with random_seed: 2145577288, max_time_in_seconds: 0.3
# 2024-08-17 19:42:46,199 - INFO - Solver found a solution with objective value: 132400.0
# 2024-08-17 19:42:46,200 - INFO - Starting solver with random_seed: 354924621, max_time_in_seconds: 0.3
# 2024-08-17 19:42:46,514 - INFO - Solver found a solution with objective value: 131185.0
# 2024-08-17 19:42:46,515 - INFO - Starting solver with random_seed: 1968728696, max_time_in_seconds: 0.3
# 2024-08-17 19:42:46,831 - INFO - Solver found a solution with objective value: 132755.0
# 2024-08-17 19:42:46,832 - INFO - Starting solver with random_seed: 1787767025, max_time_in_seconds: 0.3
# 2024-08-17 19:42:47,146 - INFO - Solver found a solution with objective value: 131595.0
# 2024-08-17 19:42:47,146 - INFO - Starting solver with random_seed: 908004824, max_time_in_seconds: 0.3
# 2024-08-17 19:42:47,461 - INFO - Solver found a solution with objective value: 129401.0
# 2024-08-17 19:42:47,462 - INFO - Starting solver with random_seed: 1220322520, max_time_in_seconds: 0.3
# 2024-08-17 19:42:47,776 - INFO - Solver found a solution with objective value: 128553.0
# 2024-08-17 19:42:47,777 - INFO - Starting solver with random_seed: 1403924465, max_time_in_seconds: 0.3
# 2024-08-17 19:42:48,092 - INFO - Solver found a solution with objective value: 130742.0
# 2024-08-17 19:42:48,092 - INFO - Starting solver with random_seed: 904448338, max_time_in_seconds: 0.3
# 2024-08-17 19:42:48,407 - INFO - Solver found a solution with objective value: 130500.0
# 2024-08-17 19:42:48,407 - INFO - Starting solver with random_seed: 216935274, max_time_in_seconds: 0.3
# 2024-08-17 19:42:48,721 - INFO - Solver found a solution with objective value: 130212.0
# 2024-08-17 19:42:48,722 - INFO - Starting solver with random_seed: 1919727759, max_time_in_seconds: 0.3
# 2024-08-17 19:42:49,039 - INFO - Solver found a solution with objective value: 132110.0
# 2024-08-17 19:42:49,040 - INFO - Starting solver with random_seed: 1184111480, max_time_in_seconds: 0.3
# 2024-08-17 19:42:49,355 - INFO - Solver found a solution with objective value: 129589.0
# 2024-08-17 19:42:49,355 - INFO - Starting solver with random_seed: 117929861, max_time_in_seconds: 0.3
# 2024-08-17 19:42:49,671 - INFO - Solver found a solution with objective value: 131407.0
# 2024-08-17 19:42:49,672 - INFO - Starting solver with random_seed: 1861337394, max_time_in_seconds: 0.3
# 2024-08-17 19:42:49,987 - INFO - Solver found a solution with objective value: 129747.0
# 2024-08-17 19:42:49,988 - INFO - Starting solver with random_seed: 1921487424, max_time_in_seconds: 0.3
# 2024-08-17 19:42:50,302 - INFO - Solver found a solution with objective value: 130025.0
# 2024-08-17 19:42:50,303 - INFO - Evaluation completed and result cached.
# 2024-08-17 19:42:50,303 - INFO - Baseline evaluation completed: min=128529.0, mean=130962.5, max=132805.0
# [I 2024-08-17 19:42:50,304] A new study created in memory with name: no-name-88e50207-7bef-4629-b35a-6a4afb1657ac
# 2024-08-17 19:42:50,304 - INFO - Starting Optuna optimization.
# 2024-08-17 19:42:50,306 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:42:50,306 - INFO - Returning cached result.
# 2024-08-17 19:42:50,306 - INFO - Evaluating with params: {}, num_runs: 10, knockout_score: 128101.4
# 2024-08-17 19:42:50,306 - INFO - Returning cached result.
# 2024-08-17 19:42:50,307 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 19:42:50,307 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: 128101.4
# 2024-08-17 19:42:50,308 - INFO - Returning cached result.
# [I 2024-08-17 19:42:50,309] Trial 0 finished with value: 130962.5 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 130962.5.
# 2024-08-17 19:42:50,313 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:42:50,313 - INFO - Returning cached result.
# 2024-08-17 19:42:50,313 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 6, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 128}, num_runs: 10, knockout_score: 128101.4
# 2024-08-17 19:42:50,314 - INFO - Starting solver with random_seed: 1705174590, max_time_in_seconds: 0.3
# 2024-08-17 19:42:50,624 - INFO - Solver found a solution with objective value: 131223.0
# 2024-08-17 19:42:50,625 - INFO - Starting solver with random_seed: 247935167, max_time_in_seconds: 0.3
# 2024-08-17 19:42:50,936 - INFO - Solver found a solution with objective value: 132345.0
# 2024-08-17 19:42:50,937 - INFO - Starting solver with random_seed: 1892900563, max_time_in_seconds: 0.3
# 2024-08-17 19:42:51,249 - INFO - Solver found a solution with objective value: 132229.0
# 2024-08-17 19:42:51,249 - INFO - Starting solver with random_seed: 1805828973, max_time_in_seconds: 0.3
# 2024-08-17 19:42:51,562 - INFO - Solver found a solution with objective value: 131489.0
# 2024-08-17 19:42:51,563 - INFO - Starting solver with random_seed: 834363815, max_time_in_seconds: 0.3
# 2024-08-17 19:42:51,874 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 19:42:51,874 - INFO - Starting solver with random_seed: 1988563387, max_time_in_seconds: 0.3
# 2024-08-17 19:42:52,185 - INFO - Solver found a solution with objective value: 131739.0
# 2024-08-17 19:42:52,186 - INFO - Starting solver with random_seed: 653427226, max_time_in_seconds: 0.3
# 2024-08-17 19:42:52,498 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 19:42:52,499 - INFO - Starting solver with random_seed: 2002489817, max_time_in_seconds: 0.3
# 2024-08-17 19:42:52,811 - INFO - Solver found a solution with objective value: 132765.0
# 2024-08-17 19:42:52,812 - INFO - Starting solver with random_seed: 456895004, max_time_in_seconds: 0.3
# 2024-08-17 19:42:53,123 - INFO - Solver found a solution with objective value: 131855.0
# 2024-08-17 19:42:53,124 - INFO - Starting solver with random_seed: 1556986121, max_time_in_seconds: 0.3
# 2024-08-17 19:42:53,434 - INFO - Solver found a solution with objective value: 129645.0
# 2024-08-17 19:42:53,435 - INFO - Evaluation completed and result cached.
# 2024-08-17 19:42:53,435 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 19:42:53,436 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 6, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 128}, num_runs: 40, knockout_score: 128101.4
# 2024-08-17 19:42:53,436 - INFO - Starting solver with random_seed: 1179168081, max_time_in_seconds: 0.3
# 2024-08-17 19:42:53,748 - INFO - Solver found a solution with objective value: 132089.0
# 2024-08-17 19:42:53,749 - INFO - Starting solver with random_seed: 1071543674, max_time_in_seconds: 0.3
# 2024-08-17 19:42:54,061 - INFO - Solver found a solution with objective value: 131205.0
# 2024-08-17 19:42:54,061 - INFO - Starting solver with random_seed: 835795631, max_time_in_seconds: 0.3
# 2024-08-17 19:42:54,373 - INFO - Solver found a solution with objective value: 132199.0
# 2024-08-17 19:42:54,374 - INFO - Starting solver with random_seed: 1215489757, max_time_in_seconds: 0.3
# 2024-08-17 19:42:54,685 - INFO - Solver found a solution with objective value: 129061.0
# 2024-08-17 19:42:54,686 - INFO - Starting solver with random_seed: 1431416836, max_time_in_seconds: 0.3
# 2024-08-17 19:42:54,998 - INFO - Solver found a solution with objective value: 132505.0
# 2024-08-17 19:42:54,998 - INFO - Starting solver with random_seed: 1226310242, max_time_in_seconds: 0.3
# 2024-08-17 19:42:55,310 - INFO - Solver found a solution with objective value: 132274.0
# 2024-08-17 19:42:55,311 - INFO - Starting solver with random_seed: 790598900, max_time_in_seconds: 0.3
# 2024-08-17 19:42:55,622 - INFO - Solver found a solution with objective value: 130550.0
# 2024-08-17 19:42:55,622 - INFO - Starting solver with random_seed: 1763110505, max_time_in_seconds: 0.3
# 2024-08-17 19:42:55,934 - INFO - Solver found a solution with objective value: 131715.0
# 2024-08-17 19:42:55,935 - INFO - Starting solver with random_seed: 1941778023, max_time_in_seconds: 0.3
# 2024-08-17 19:42:56,247 - INFO - Solver found a solution with objective value: 131364.0
# 2024-08-17 19:42:56,248 - INFO - Starting solver with random_seed: 438001860, max_time_in_seconds: 0.3
# 2024-08-17 19:42:56,560 - INFO - Solver found a solution with objective value: 132215.0
# 2024-08-17 19:42:56,560 - INFO - Starting solver with random_seed: 596621581, max_time_in_seconds: 0.3
# 2024-08-17 19:42:56,873 - INFO - Solver found a solution with objective value: 132025.0
# 2024-08-17 19:42:56,874 - INFO - Starting solver with random_seed: 1773577111, max_time_in_seconds: 0.3
# 2024-08-17 19:42:57,185 - INFO - Solver found a solution with objective value: 132258.0
# 2024-08-17 19:42:57,185 - INFO - Starting solver with random_seed: 1883239911, max_time_in_seconds: 0.3
# 2024-08-17 19:42:57,497 - INFO - Solver found a solution with objective value: 131353.0
# 2024-08-17 19:42:57,497 - INFO - Starting solver with random_seed: 1549456732, max_time_in_seconds: 0.3
# 2024-08-17 19:42:57,809 - INFO - Solver found a solution with objective value: 132630.0
# 2024-08-17 19:42:57,810 - INFO - Starting solver with random_seed: 1045933500, max_time_in_seconds: 0.3
# 2024-08-17 19:42:58,121 - INFO - Solver found a solution with objective value: 132255.0
# 2024-08-17 19:42:58,122 - INFO - Starting solver with random_seed: 1949908224, max_time_in_seconds: 0.3
# 2024-08-17 19:42:58,434 - INFO - Solver found a solution with objective value: 130335.0
# 2024-08-17 19:42:58,434 - INFO - Starting solver with random_seed: 531501187, max_time_in_seconds: 0.3
# 2024-08-17 19:42:58,746 - INFO - Solver found a solution with objective value: 132765.0
# 2024-08-17 19:42:58,747 - INFO - Starting solver with random_seed: 1779600520, max_time_in_seconds: 0.3
# 2024-08-17 19:42:59,059 - INFO - Solver found a solution with objective value: 132755.0
# 2024-08-17 19:42:59,060 - INFO - Starting solver with random_seed: 1068268635, max_time_in_seconds: 0.3
# 2024-08-17 19:42:59,371 - INFO - Solver found a solution with objective value: 132730.0
# 2024-08-17 19:42:59,371 - INFO - Starting solver with random_seed: 1434880678, max_time_in_seconds: 0.3
# 2024-08-17 19:42:59,682 - INFO - Solver found a solution with objective value: 131145.0
# 2024-08-17 19:42:59,683 - INFO - Starting solver with random_seed: 1986506828, max_time_in_seconds: 0.3
# 2024-08-17 19:42:59,995 - INFO - Solver found a solution with objective value: 130157.0
# 2024-08-17 19:42:59,995 - INFO - Starting solver with random_seed: 1145371178, max_time_in_seconds: 0.3
# 2024-08-17 19:43:00,307 - INFO - Solver found a solution with objective value: 129866.0
# 2024-08-17 19:43:00,308 - INFO - Starting solver with random_seed: 342171471, max_time_in_seconds: 0.3
# 2024-08-17 19:43:00,618 - INFO - Solver found a solution with objective value: 131353.0
# 2024-08-17 19:43:00,619 - INFO - Starting solver with random_seed: 1353701149, max_time_in_seconds: 0.3
# 2024-08-17 19:43:00,931 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:00,932 - INFO - Starting solver with random_seed: 5154376, max_time_in_seconds: 0.3
# 2024-08-17 19:43:01,242 - INFO - Solver found a solution with objective value: 131097.0
# 2024-08-17 19:43:01,243 - INFO - Starting solver with random_seed: 331299333, max_time_in_seconds: 0.3
# 2024-08-17 19:43:01,555 - INFO - Solver found a solution with objective value: 129631.0
# 2024-08-17 19:43:01,555 - INFO - Starting solver with random_seed: 889402602, max_time_in_seconds: 0.3
# 2024-08-17 19:43:01,867 - INFO - Solver found a solution with objective value: 131296.0
# 2024-08-17 19:43:01,868 - INFO - Starting solver with random_seed: 134680862, max_time_in_seconds: 0.3
# 2024-08-17 19:43:02,179 - INFO - Solver found a solution with objective value: 127577.0
# 2024-08-17 19:43:02,179 - INFO - Returning knockout result.
# [I 2024-08-17 19:43:02,180] Trial 1 finished with value: 127577.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 130962.5.
# 2024-08-17 19:43:02,184 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:43:02,184 - INFO - Returning cached result.
# 2024-08-17 19:43:02,184 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'ignore_subsolvers': ['default_lp', 'fixed', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 10, knockout_score: 128101.4
# 2024-08-17 19:43:02,185 - INFO - Starting solver with random_seed: 720833442, max_time_in_seconds: 0.3
# 2024-08-17 19:43:02,498 - INFO - Solver found a solution with objective value: 130421.0
# 2024-08-17 19:43:02,498 - INFO - Starting solver with random_seed: 377309173, max_time_in_seconds: 0.3
# 2024-08-17 19:43:02,807 - INFO - Solver found a solution with objective value: 129843.0
# 2024-08-17 19:43:02,808 - INFO - Starting solver with random_seed: 313609248, max_time_in_seconds: 0.3
# 2024-08-17 19:43:03,123 - INFO - Solver found a solution with objective value: 76995.0
# 2024-08-17 19:43:03,124 - INFO - Returning knockout result.
# [I 2024-08-17 19:43:03,125] Trial 2 finished with value: 76995.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 130962.5.
# 2024-08-17 19:43:03,128 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:43:03,128 - INFO - Returning cached result.
# 2024-08-17 19:43:03,129 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'pseudo_costs', 'probing'], 'use_lb_relax_lns': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 32}, num_runs: 10, knockout_score: 128101.4
# 2024-08-17 19:43:03,129 - INFO - Starting solver with random_seed: 907690453, max_time_in_seconds: 0.3
# 2024-08-17 19:43:03,445 - INFO - Solver found a solution with objective value: 130038.0
# 2024-08-17 19:43:03,445 - INFO - Starting solver with random_seed: 205979738, max_time_in_seconds: 0.3
# 2024-08-17 19:43:03,760 - INFO - Solver found a solution with objective value: 128025.0
# 2024-08-17 19:43:03,760 - INFO - Returning knockout result.
# [I 2024-08-17 19:43:03,761] Trial 3 finished with value: 128025.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 130962.5.
# 2024-08-17 19:43:03,765 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:43:03,765 - INFO - Returning cached result.
# 2024-08-17 19:43:03,765 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'max_lp', 'reduced_costs', 'quick_restart_no_lp', 'probing'], 'search_branching': 2, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 10, knockout_score: 128101.4
# 2024-08-17 19:43:03,765 - INFO - Starting solver with random_seed: 789718513, max_time_in_seconds: 0.3
# 2024-08-17 19:43:04,081 - INFO - Solver found a solution with objective value: 52365.0
# 2024-08-17 19:43:04,081 - INFO - Returning knockout result.
# [I 2024-08-17 19:43:04,082] Trial 4 finished with value: 52365.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 2, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 130962.5.
# 2024-08-17 19:43:04,085 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:43:04,086 - INFO - Returning cached result.
# 2024-08-17 19:43:04,086 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'ignore_subsolvers': ['no_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 4, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'cut_level': 2, 'symmetry_level': 1}, num_runs: 10, knockout_score: 128101.4
# 2024-08-17 19:43:04,086 - INFO - Starting solver with random_seed: 1108422779, max_time_in_seconds: 0.3
# 2024-08-17 19:43:04,400 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 19:43:04,401 - INFO - Starting solver with random_seed: 246085787, max_time_in_seconds: 0.3
# 2024-08-17 19:43:04,720 - INFO - Solver found a solution with objective value: 132315.0
# 2024-08-17 19:43:04,721 - INFO - Starting solver with random_seed: 558992284, max_time_in_seconds: 0.3
# 2024-08-17 19:43:05,033 - INFO - Solver found a solution with objective value: 131652.0
# 2024-08-17 19:43:05,033 - INFO - Starting solver with random_seed: 237347686, max_time_in_seconds: 0.3
# 2024-08-17 19:43:05,346 - INFO - Solver found a solution with objective value: 132210.0
# 2024-08-17 19:43:05,346 - INFO - Starting solver with random_seed: 2065809100, max_time_in_seconds: 0.3
# 2024-08-17 19:43:05,662 - INFO - Solver found a solution with objective value: 129956.0
# 2024-08-17 19:43:05,663 - INFO - Starting solver with random_seed: 496241657, max_time_in_seconds: 0.3
# 2024-08-17 19:43:05,974 - INFO - Solver found a solution with objective value: 129729.0
# 2024-08-17 19:43:05,975 - INFO - Starting solver with random_seed: 1061505926, max_time_in_seconds: 0.3
# 2024-08-17 19:43:06,286 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 19:43:06,287 - INFO - Starting solver with random_seed: 1044102700, max_time_in_seconds: 0.3
# 2024-08-17 19:43:06,611 - INFO - Solver found a solution with objective value: 131679.0
# 2024-08-17 19:43:06,612 - INFO - Starting solver with random_seed: 2049834543, max_time_in_seconds: 0.3
# 2024-08-17 19:43:06,923 - INFO - Solver found a solution with objective value: 131948.0
# 2024-08-17 19:43:06,924 - INFO - Starting solver with random_seed: 1879498917, max_time_in_seconds: 0.3
# 2024-08-17 19:43:07,237 - INFO - Solver found a solution with objective value: 131360.0
# 2024-08-17 19:43:07,237 - INFO - Evaluation completed and result cached.
# 2024-08-17 19:43:07,237 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 19:43:07,238 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'ignore_subsolvers': ['no_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 4, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'cut_level': 2, 'symmetry_level': 1}, num_runs: 40, knockout_score: 128101.4
# 2024-08-17 19:43:07,238 - INFO - Starting solver with random_seed: 1808838778, max_time_in_seconds: 0.3
# 2024-08-17 19:43:07,552 - INFO - Solver found a solution with objective value: 131532.0
# 2024-08-17 19:43:07,552 - INFO - Starting solver with random_seed: 870674313, max_time_in_seconds: 0.3
# 2024-08-17 19:43:07,864 - INFO - Solver found a solution with objective value: 132220.0
# 2024-08-17 19:43:07,865 - INFO - Starting solver with random_seed: 1079828564, max_time_in_seconds: 0.3
# 2024-08-17 19:43:08,175 - INFO - Solver found a solution with objective value: 128958.0
# 2024-08-17 19:43:08,176 - INFO - Starting solver with random_seed: 2085207752, max_time_in_seconds: 0.3
# 2024-08-17 19:43:08,498 - INFO - Solver found a solution with objective value: 132259.0
# 2024-08-17 19:43:08,498 - INFO - Starting solver with random_seed: 2100776397, max_time_in_seconds: 0.3
# 2024-08-17 19:43:08,812 - INFO - Solver found a solution with objective value: 132209.0
# 2024-08-17 19:43:08,812 - INFO - Starting solver with random_seed: 107723388, max_time_in_seconds: 0.3
# 2024-08-17 19:43:09,132 - INFO - Solver found a solution with objective value: 132144.0
# 2024-08-17 19:43:09,133 - INFO - Starting solver with random_seed: 1121196309, max_time_in_seconds: 0.3
# 2024-08-17 19:43:09,444 - INFO - Solver found a solution with objective value: 129979.0
# 2024-08-17 19:43:09,445 - INFO - Starting solver with random_seed: 174437163, max_time_in_seconds: 0.3
# 2024-08-17 19:43:09,762 - INFO - Solver found a solution with objective value: 130950.0
# 2024-08-17 19:43:09,763 - INFO - Starting solver with random_seed: 1819098322, max_time_in_seconds: 0.3
# 2024-08-17 19:43:10,074 - INFO - Solver found a solution with objective value: 129292.0
# 2024-08-17 19:43:10,075 - INFO - Starting solver with random_seed: 1535859846, max_time_in_seconds: 0.3
# 2024-08-17 19:43:10,390 - INFO - Solver found a solution with objective value: 128898.0
# 2024-08-17 19:43:10,391 - INFO - Starting solver with random_seed: 1813034035, max_time_in_seconds: 0.3
# 2024-08-17 19:43:10,702 - INFO - Solver found a solution with objective value: 132370.0
# 2024-08-17 19:43:10,703 - INFO - Starting solver with random_seed: 1530375146, max_time_in_seconds: 0.3
# 2024-08-17 19:43:11,016 - INFO - Solver found a solution with objective value: 132189.0
# 2024-08-17 19:43:11,017 - INFO - Starting solver with random_seed: 1047033638, max_time_in_seconds: 0.3
# 2024-08-17 19:43:11,328 - INFO - Solver found a solution with objective value: 131653.0
# 2024-08-17 19:43:11,328 - INFO - Starting solver with random_seed: 980067243, max_time_in_seconds: 0.3
# 2024-08-17 19:43:11,641 - INFO - Solver found a solution with objective value: 130181.0
# 2024-08-17 19:43:11,642 - INFO - Starting solver with random_seed: 1703790277, max_time_in_seconds: 0.3
# 2024-08-17 19:43:11,953 - INFO - Solver found a solution with objective value: 131573.0
# 2024-08-17 19:43:11,954 - INFO - Starting solver with random_seed: 533076824, max_time_in_seconds: 0.3
# 2024-08-17 19:43:12,265 - INFO - Solver found a solution with objective value: 132259.0
# 2024-08-17 19:43:12,265 - INFO - Starting solver with random_seed: 1590537501, max_time_in_seconds: 0.3
# 2024-08-17 19:43:12,576 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-17 19:43:12,577 - INFO - Starting solver with random_seed: 1296913560, max_time_in_seconds: 0.3
# 2024-08-17 19:43:12,893 - INFO - Solver found a solution with objective value: 132215.0
# 2024-08-17 19:43:12,893 - INFO - Starting solver with random_seed: 751917471, max_time_in_seconds: 0.3
# 2024-08-17 19:43:13,204 - INFO - Solver found a solution with objective value: 131854.0
# 2024-08-17 19:43:13,205 - INFO - Starting solver with random_seed: 958061570, max_time_in_seconds: 0.3
# 2024-08-17 19:43:13,522 - INFO - Solver found a solution with objective value: 131647.0
# 2024-08-17 19:43:13,523 - INFO - Starting solver with random_seed: 1479673431, max_time_in_seconds: 0.3
# 2024-08-17 19:43:13,833 - INFO - Solver found a solution with objective value: 129072.0
# 2024-08-17 19:43:13,834 - INFO - Starting solver with random_seed: 1289105140, max_time_in_seconds: 0.3
# 2024-08-17 19:43:14,145 - INFO - Solver found a solution with objective value: 129059.0
# 2024-08-17 19:43:14,146 - INFO - Starting solver with random_seed: 546144291, max_time_in_seconds: 0.3
# 2024-08-17 19:43:14,457 - INFO - Solver found a solution with objective value: 131855.0
# 2024-08-17 19:43:14,458 - INFO - Starting solver with random_seed: 1631962357, max_time_in_seconds: 0.3
# 2024-08-17 19:43:14,771 - INFO - Solver found a solution with objective value: 129051.0
# 2024-08-17 19:43:14,771 - INFO - Starting solver with random_seed: 676063991, max_time_in_seconds: 0.3
# 2024-08-17 19:43:15,084 - INFO - Solver found a solution with objective value: 132153.0
# 2024-08-17 19:43:15,085 - INFO - Starting solver with random_seed: 1507678341, max_time_in_seconds: 0.3
# 2024-08-17 19:43:15,398 - INFO - Solver found a solution with objective value: 132375.0
# 2024-08-17 19:43:15,399 - INFO - Starting solver with random_seed: 759451080, max_time_in_seconds: 0.3
# 2024-08-17 19:43:15,712 - INFO - Solver found a solution with objective value: 131859.0
# 2024-08-17 19:43:15,713 - INFO - Starting solver with random_seed: 472653385, max_time_in_seconds: 0.3
# 2024-08-17 19:43:16,029 - INFO - Solver found a solution with objective value: 131422.0
# 2024-08-17 19:43:16,030 - INFO - Starting solver with random_seed: 759654247, max_time_in_seconds: 0.3
# 2024-08-17 19:43:16,340 - INFO - Solver found a solution with objective value: 132544.0
# 2024-08-17 19:43:16,341 - INFO - Starting solver with random_seed: 1205598314, max_time_in_seconds: 0.3
# 2024-08-17 19:43:16,653 - INFO - Solver found a solution with objective value: 132324.0
# 2024-08-17 19:43:16,653 - INFO - Evaluation completed and result cached.
# [I 2024-08-17 19:43:16,655] Trial 5 finished with value: 131357.05 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 5 with value: 131357.05.
# 2024-08-17 19:43:16,658 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 19:43:16,658 - INFO - Returning cached result.
# 2024-08-17 19:43:16,658 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 7, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'linearization_level': 0, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 10, knockout_score: 128101.4
# 2024-08-17 19:43:16,659 - INFO - Starting solver with random_seed: 396701876, max_time_in_seconds: 0.3
# 2024-08-17 19:43:16,973 - INFO - Solver found a solution with objective value: 128882.0
# 2024-08-17 19:43:16,973 - INFO - Starting solver with random_seed: 1286384670, max_time_in_seconds: 0.3
# 2024-08-17 19:43:17,286 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:17,287 - INFO - Starting solver with random_seed: 1426034001, max_time_in_seconds: 0.3
# 2024-08-17 19:43:17,607 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:17,607 - INFO - Starting solver with random_seed: 535230595, max_time_in_seconds: 0.3
# 2024-08-17 19:43:17,926 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:17,927 - INFO - Starting solver with random_seed: 867652559, max_time_in_seconds: 0.3
# 2024-08-17 19:43:18,240 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:18,241 - INFO - Starting solver with random_seed: 1682375024, max_time_in_seconds: 0.3
# 2024-08-17 19:43:18,553 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:18,554 - INFO - Starting solver with random_seed: 24491723, max_time_in_seconds: 0.3
# 2024-08-17 19:43:18,866 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:18,867 - INFO - Starting solver with random_seed: 926213541, max_time_in_seconds: 0.3
# 2024-08-17 19:43:19,180 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:19,180 - INFO - Starting solver with random_seed: 1101767963, max_time_in_seconds: 0.3
# 2024-08-17 19:43:19,493 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:19,493 - INFO - Starting solver with random_seed: 975115884, max_time_in_seconds: 0.3
# 2024-08-17 19:43:19,806 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:19,806 - INFO - Evaluation completed and result cached.
# 2024-08-17 19:43:19,807 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 19:43:19,807 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 7, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'linearization_level': 0, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 40, knockout_score: 128101.4
# 2024-08-17 19:43:19,807 - INFO - Starting solver with random_seed: 33246983, max_time_in_seconds: 0.3
# 2024-08-17 19:43:20,119 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:20,120 - INFO - Starting solver with random_seed: 705857174, max_time_in_seconds: 0.3
# 2024-08-17 19:43:20,434 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:20,434 - INFO - Starting solver with random_seed: 1477740025, max_time_in_seconds: 0.3
# 2024-08-17 19:43:20,746 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:20,747 - INFO - Starting solver with random_seed: 249332391, max_time_in_seconds: 0.3
# 2024-08-17 19:43:21,060 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:21,061 - INFO - Starting solver with random_seed: 1729594359, max_time_in_seconds: 0.3
# 2024-08-17 19:43:21,375 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:21,376 - INFO - Starting solver with random_seed: 783902772, max_time_in_seconds: 0.3
# 2024-08-17 19:43:21,688 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:21,689 - INFO - Starting solver with random_seed: 173357197, max_time_in_seconds: 0.3
# 2024-08-17 19:43:22,002 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:22,003 - INFO - Starting solver with random_seed: 513686172, max_time_in_seconds: 0.3
# 2024-08-17 19:43:22,316 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:22,317 - INFO - Starting solver with random_seed: 927852421, max_time_in_seconds: 0.3
# 2024-08-17 19:43:22,629 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:22,630 - INFO - Starting solver with random_seed: 1729587405, max_time_in_seconds: 0.3
# 2024-08-17 19:43:22,945 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:22,946 - INFO - Starting solver with random_seed: 1845952291, max_time_in_seconds: 0.3
# 2024-08-17 19:43:23,259 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:23,259 - INFO - Starting solver with random_seed: 264116914, max_time_in_seconds: 0.3
# 2024-08-17 19:43:23,584 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:23,585 - INFO - Starting solver with random_seed: 1153406812, max_time_in_seconds: 0.3
# 2024-08-17 19:43:23,897 - INFO - Solver found a solution with objective value: 132453.0
# 2024-08-17 19:43:23,898 - INFO - Starting solver with random_seed: 133268632, max_time_in_seconds: 0.3
# 2024-08-17 19:43:24,210 - INFO - Solver found a solution with objective value: 132795.0
# 2024-08-17 19:43:24,211 - INFO - Starting solver with random_seed: 722314763, max_time_in_seconds: 0.3
# 2024-08-17 19:43:24,524 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:24,524 - INFO - Starting solver with random_seed: 1848865672, max_time_in_seconds: 0.3
# 2024-08-17 19:43:24,839 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:24,839 - INFO - Starting solver with random_seed: 1095787910, max_time_in_seconds: 0.3
# 2024-08-17 19:43:25,164 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:25,165 - INFO - Starting solver with random_seed: 1081798387, max_time_in_seconds: 0.3
# 2024-08-17 19:43:25,476 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:25,477 - INFO - Starting solver with random_seed: 1104108456, max_time_in_seconds: 0.3
# 2024-08-17 19:43:25,789 - INFO - Solver found a solution with objective value: 128859.0
# 2024-08-17 19:43:25,790 - INFO - Starting solver with random_seed: 898866284, max_time_in_seconds: 0.3
# 2024-08-17 19:43:26,101 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:26,102 - INFO - Starting solver with random_seed: 1680682765, max_time_in_seconds: 0.3
# 2024-08-17 19:43:26,415 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:26,416 - INFO - Starting solver with random_seed: 1073048624, max_time_in_seconds: 0.3
# 2024-08-17 19:43:26,729 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:26,729 - INFO - Starting solver with random_seed: 1503962685, max_time_in_seconds: 0.3
# 2024-08-17 19:43:27,042 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:43:27,043 - INFO - Starting solver with random_seed: 287012558, max_time_in_seconds: 0.3
# 2024-08-17 19:43:27,355 - INFO - Solver found a solution with objective value: 128643.0
# 2024-08-17 19:43:27,356 - INFO - Starting solver with random_seed: 329478249, max_time_in_seconds: 0.3
# 2024-08-17 19:43:27,667 - INFO - Solver found a solution with objective value: 132090.0
# 2024-08-17 19:43:27,668 - INFO - Starting solver with random_seed: 2091000526, max_time_in_seconds: 0.3
# 2024-08-17 19:43:27,980 - INFO - Solver found a solution with objective value: 132805.0
# ...
# 2024-08-17 19:46:40,886 - INFO - Starting solver with random_seed: 225656977, max_time_in_seconds: 0.3
# 2024-08-17 19:46:41,214 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:41,215 - INFO - Starting solver with random_seed: 942194432, max_time_in_seconds: 0.3
# 2024-08-17 19:46:41,530 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:41,531 - INFO - Starting solver with random_seed: 1000929641, max_time_in_seconds: 0.3
# 2024-08-17 19:46:41,846 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:41,847 - INFO - Starting solver with random_seed: 760686115, max_time_in_seconds: 0.3
# 2024-08-17 19:46:42,167 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:42,167 - INFO - Starting solver with random_seed: 80469436, max_time_in_seconds: 0.3
# 2024-08-17 19:46:42,481 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:42,481 - INFO - Starting solver with random_seed: 202993723, max_time_in_seconds: 0.3
# 2024-08-17 19:46:42,793 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:42,794 - INFO - Starting solver with random_seed: 1393491309, max_time_in_seconds: 0.3
# 2024-08-17 19:46:43,107 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:43,108 - INFO - Starting solver with random_seed: 1250720960, max_time_in_seconds: 0.3
# 2024-08-17 19:46:43,423 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:43,423 - INFO - Starting solver with random_seed: 1775818025, max_time_in_seconds: 0.3
# 2024-08-17 19:46:43,736 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:43,737 - INFO - Starting solver with random_seed: 712011096, max_time_in_seconds: 0.3
# 2024-08-17 19:46:44,049 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:44,049 - INFO - Evaluation completed and result cached.
# 2024-08-17 19:46:44,050 - INFO - Parameter 'symmetry_level' can be dropped from the optimized parameters.
# 2024-08-17 19:46:44,050 - INFO - Evaluating with params: {'cp_model_probing_level': 0, 'search_branching': 6, 'linearization_level': 0}, num_runs: 40, knockout_score: None
# 2024-08-17 19:46:44,050 - INFO - Starting solver with random_seed: 1904105590, max_time_in_seconds: 0.3
# 2024-08-17 19:46:44,371 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:44,371 - INFO - Starting solver with random_seed: 674975532, max_time_in_seconds: 0.3
# 2024-08-17 19:46:44,686 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:44,686 - INFO - Starting solver with random_seed: 310607359, max_time_in_seconds: 0.3
# 2024-08-17 19:46:45,002 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:45,002 - INFO - Starting solver with random_seed: 1770907226, max_time_in_seconds: 0.3
# 2024-08-17 19:46:45,322 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:45,323 - INFO - Starting solver with random_seed: 311994622, max_time_in_seconds: 0.3
# 2024-08-17 19:46:45,645 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:45,645 - INFO - Starting solver with random_seed: 2086668249, max_time_in_seconds: 0.3
# 2024-08-17 19:46:45,962 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:45,963 - INFO - Starting solver with random_seed: 644586819, max_time_in_seconds: 0.3
# 2024-08-17 19:46:46,281 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:46,281 - INFO - Starting solver with random_seed: 1125892415, max_time_in_seconds: 0.3
# 2024-08-17 19:46:46,595 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:46,596 - INFO - Starting solver with random_seed: 1031828559, max_time_in_seconds: 0.3
# 2024-08-17 19:46:46,911 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:46,911 - INFO - Starting solver with random_seed: 654529794, max_time_in_seconds: 0.3
# 2024-08-17 19:46:47,225 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:47,225 - INFO - Starting solver with random_seed: 1883558455, max_time_in_seconds: 0.3
# 2024-08-17 19:46:47,541 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:47,541 - INFO - Starting solver with random_seed: 2055097376, max_time_in_seconds: 0.3
# 2024-08-17 19:46:47,855 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:47,856 - INFO - Starting solver with random_seed: 1591324805, max_time_in_seconds: 0.3
# 2024-08-17 19:46:48,172 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:48,172 - INFO - Starting solver with random_seed: 855261281, max_time_in_seconds: 0.3
# 2024-08-17 19:46:48,488 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:48,489 - INFO - Starting solver with random_seed: 1379335793, max_time_in_seconds: 0.3
# 2024-08-17 19:46:48,805 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:48,806 - INFO - Starting solver with random_seed: 35107677, max_time_in_seconds: 0.3
# 2024-08-17 19:46:49,121 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:49,122 - INFO - Starting solver with random_seed: 1433793311, max_time_in_seconds: 0.3
# 2024-08-17 19:46:49,438 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:49,439 - INFO - Starting solver with random_seed: 1622635307, max_time_in_seconds: 0.3
# 2024-08-17 19:46:49,757 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:49,758 - INFO - Starting solver with random_seed: 85530519, max_time_in_seconds: 0.3
# 2024-08-17 19:46:50,076 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:50,077 - INFO - Starting solver with random_seed: 2067272107, max_time_in_seconds: 0.3
# 2024-08-17 19:46:50,398 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:50,399 - INFO - Starting solver with random_seed: 426829945, max_time_in_seconds: 0.3
# 2024-08-17 19:46:50,717 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:50,717 - INFO - Starting solver with random_seed: 1512692067, max_time_in_seconds: 0.3
# 2024-08-17 19:46:51,033 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:51,034 - INFO - Starting solver with random_seed: 602161306, max_time_in_seconds: 0.3
# 2024-08-17 19:46:51,348 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:51,349 - INFO - Starting solver with random_seed: 47559304, max_time_in_seconds: 0.3
# 2024-08-17 19:46:51,663 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:51,664 - INFO - Starting solver with random_seed: 24361005, max_time_in_seconds: 0.3
# 2024-08-17 19:46:51,981 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:51,982 - INFO - Starting solver with random_seed: 61528476, max_time_in_seconds: 0.3
# 2024-08-17 19:46:52,296 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:52,297 - INFO - Starting solver with random_seed: 27102295, max_time_in_seconds: 0.3
# 2024-08-17 19:46:52,611 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:52,611 - INFO - Starting solver with random_seed: 1720791460, max_time_in_seconds: 0.3
# 2024-08-17 19:46:52,927 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:52,928 - INFO - Starting solver with random_seed: 388681474, max_time_in_seconds: 0.3
# 2024-08-17 19:46:53,241 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:53,242 - INFO - Starting solver with random_seed: 956981233, max_time_in_seconds: 0.3
# 2024-08-17 19:46:53,559 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:53,560 - INFO - Starting solver with random_seed: 768177315, max_time_in_seconds: 0.3
# 2024-08-17 19:46:53,881 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:53,882 - INFO - Starting solver with random_seed: 181529226, max_time_in_seconds: 0.3
# 2024-08-17 19:46:54,194 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:54,194 - INFO - Starting solver with random_seed: 132260606, max_time_in_seconds: 0.3
# 2024-08-17 19:46:54,507 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:54,508 - INFO - Starting solver with random_seed: 1136672705, max_time_in_seconds: 0.3
# 2024-08-17 19:46:54,826 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:54,827 - INFO - Starting solver with random_seed: 1890154845, max_time_in_seconds: 0.3
# 2024-08-17 19:46:55,143 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:55,143 - INFO - Starting solver with random_seed: 1259036999, max_time_in_seconds: 0.3
# 2024-08-17 19:46:55,465 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:55,466 - INFO - Starting solver with random_seed: 233418634, max_time_in_seconds: 0.3
# 2024-08-17 19:46:55,779 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:55,780 - INFO - Starting solver with random_seed: 132846820, max_time_in_seconds: 0.3
# 2024-08-17 19:46:56,094 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:56,095 - INFO - Starting solver with random_seed: 1395522532, max_time_in_seconds: 0.3
# 2024-08-17 19:46:56,410 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:56,410 - INFO - Starting solver with random_seed: 1397175215, max_time_in_seconds: 0.3
# 2024-08-17 19:46:56,726 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 19:46:56,727 - INFO - Evaluation completed and result cached.
# 2024-08-17 19:46:56,727 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter              ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ cp_model_probing_level │   0   │    59.67%    │       2       │
# │ 2   │ search_branching       │   6   │    36.50%    │       0       │
# │ 3   │ linearization_level    │   0   │    3.84%     │       1       │
# └─────┴────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
#
# 2. search_branching Defines the branching strategy the solver uses to navigate the search tree. The options are:
#
#  • 0 (AUTOMATIC_SEARCH): The solver automatically selects the most appropriate strategy.
#  • 1 (FIXED_SEARCH): Follows a fixed variable order, as specified by the user or the problem model.
#  • 2 (PORTFOLIO_SEARCH): Uses a combination of multiple strategies to explore the search space.
#  • 3 (LP_SEARCH): Branches based on the LP relaxation of the problem, leveraging the reduced costs of variables.
#  • 4 (PSEUDO_COST_SEARCH): Branches using pseudo-costs, which are estimates of the impact of branching decisions
#    based on past experiences.
#  • 5 (PORTFOLIO_WITH_QUICK_RESTART_SEARCH): Quickly explores different heuristics with low conflict limits, aiming
#    to find a good initial solution.
#  • 6 (HINT_SEARCH): Prioritizes decisions based on hints provided by the user or the problem model.
#  • 7 (PARTIAL_FIXED_SEARCH): Begins with a fixed strategy, then switches to automatic search for the remaining
#    decisions.
#  • 8 (RANDOMIZED_SEARCH): Introduces randomization into branching decisions to diversify the search.
#
# 3. linearization_level Controls the extent to which integer constraints are transformed into Boolean variables for
# LP relaxation. The levels are:
#
#  • 0: No linearization, the solver does not use LP relaxation.
#  • 1: Basic linearization, including linear constraints and fully encoded Boolean variables.
#  • 2: More comprehensive linearization, including Boolean constraints.
#
# Increasing the linearization level can tighten the relaxation, but it also increases the complexity of the model.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                                    ┃     Mean ┃      Min ┃      Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━┩
# │ Objective [MAX] with Default Parameters   │ 130962.5 │ 128529.0 │ 132805.0 │       40 │
# │ Objective [MAX] with Optimized Parameters │ 132805.0 │ 132805.0 │ 132805.0 │       40 │
# └───────────────────────────────────────────┴──────────┴──────────┴──────────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-17 19:46:56,747 - INFO - Hyperparameter tuning completed.
# 2024-08-17 19:46:56,748 - INFO - Tuning for quality within time limit completed.

# %%
best = tune_for_gap_within_timelimit(
    model,
    max_time_in_seconds=0.4,
    n_samples_for_trial=10,  # Number of samples for each trial
    n_samples_for_verification=40,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-17 20:01:01,383 - INFO - Starting tuning for gap within time limit. Limit: 10
# 2024-08-17 20:01:01,384 - INFO - Initialized Metric with direction: minimize
# 2024-08-17 20:01:01,384 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-17 20:01:01,384 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:01,385 - INFO - Starting solver with random_seed: 642849196, max_time_in_seconds: 0.4
# 2024-08-17 20:01:01,800 - INFO - Solver found a solution with objective value: 131705.0
# 2024-08-17 20:01:01,801 - INFO - Starting solver with random_seed: 1688548197, max_time_in_seconds: 0.4
# 2024-08-17 20:01:02,222 - INFO - Solver found a solution with objective value: 131728.0
# 2024-08-17 20:01:02,223 - INFO - Starting solver with random_seed: 1543132671, max_time_in_seconds: 0.4
# 2024-08-17 20:01:02,644 - INFO - Solver found a solution with objective value: 132540.0
# 2024-08-17 20:01:02,645 - INFO - Starting solver with random_seed: 1653766067, max_time_in_seconds: 0.4
# 2024-08-17 20:01:03,060 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:03,061 - INFO - Starting solver with random_seed: 329306729, max_time_in_seconds: 0.4
# 2024-08-17 20:01:03,476 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:03,477 - INFO - Starting solver with random_seed: 547187442, max_time_in_seconds: 0.4
# 2024-08-17 20:01:03,891 - INFO - Solver found a solution with objective value: 130735.0
# 2024-08-17 20:01:03,892 - INFO - Starting solver with random_seed: 268228172, max_time_in_seconds: 0.4
# 2024-08-17 20:01:04,308 - INFO - Solver found a solution with objective value: 132544.0
# 2024-08-17 20:01:04,309 - INFO - Starting solver with random_seed: 1976128699, max_time_in_seconds: 0.4
# 2024-08-17 20:01:04,726 - INFO - Solver found a solution with objective value: 132279.0
# 2024-08-17 20:01:04,726 - INFO - Starting solver with random_seed: 604787156, max_time_in_seconds: 0.4
# 2024-08-17 20:01:05,145 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-17 20:01:05,146 - INFO - Starting solver with random_seed: 1972182870, max_time_in_seconds: 0.4
# 2024-08-17 20:01:05,561 - INFO - Solver found a solution with objective value: 129741.0
# 2024-08-17 20:01:05,562 - INFO - Starting solver with random_seed: 1565587227, max_time_in_seconds: 0.4
# 2024-08-17 20:01:05,981 - INFO - Solver found a solution with objective value: 129970.0
# 2024-08-17 20:01:05,982 - INFO - Starting solver with random_seed: 735676894, max_time_in_seconds: 0.4
# 2024-08-17 20:01:06,399 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:06,400 - INFO - Starting solver with random_seed: 1773697737, max_time_in_seconds: 0.4
# 2024-08-17 20:01:06,816 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:06,816 - INFO - Starting solver with random_seed: 1785100899, max_time_in_seconds: 0.4
# 2024-08-17 20:01:07,238 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:07,239 - INFO - Starting solver with random_seed: 732724491, max_time_in_seconds: 0.4
# 2024-08-17 20:01:07,656 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:07,657 - INFO - Starting solver with random_seed: 1599674553, max_time_in_seconds: 0.4
# 2024-08-17 20:01:08,080 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:08,081 - INFO - Starting solver with random_seed: 2106940220, max_time_in_seconds: 0.4
# 2024-08-17 20:01:08,505 - INFO - Solver found a solution with objective value: 130169.0
# 2024-08-17 20:01:08,506 - INFO - Starting solver with random_seed: 1393117947, max_time_in_seconds: 0.4
# 2024-08-17 20:01:08,922 - INFO - Solver found a solution with objective value: 130590.0
# 2024-08-17 20:01:08,923 - INFO - Starting solver with random_seed: 602271813, max_time_in_seconds: 0.4
# 2024-08-17 20:01:09,341 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:09,341 - INFO - Starting solver with random_seed: 298026637, max_time_in_seconds: 0.4
# 2024-08-17 20:01:09,758 - INFO - Solver found a solution with objective value: 130720.0
# 2024-08-17 20:01:09,758 - INFO - Starting solver with random_seed: 144695085, max_time_in_seconds: 0.4
# 2024-08-17 20:01:10,181 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-17 20:01:10,181 - INFO - Starting solver with random_seed: 106608117, max_time_in_seconds: 0.4
# 2024-08-17 20:01:10,599 - INFO - Solver found a solution with objective value: 131675.0
# 2024-08-17 20:01:10,600 - INFO - Starting solver with random_seed: 910202930, max_time_in_seconds: 0.4
# 2024-08-17 20:01:11,016 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:11,017 - INFO - Starting solver with random_seed: 57985324, max_time_in_seconds: 0.4
# 2024-08-17 20:01:11,432 - INFO - Solver found a solution with objective value: 131294.0
# 2024-08-17 20:01:11,432 - INFO - Starting solver with random_seed: 1353732437, max_time_in_seconds: 0.4
# 2024-08-17 20:01:11,848 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:11,849 - INFO - Starting solver with random_seed: 1297441642, max_time_in_seconds: 0.4
# 2024-08-17 20:01:12,267 - INFO - Solver found a solution with objective value: 130750.0
# 2024-08-17 20:01:12,268 - INFO - Starting solver with random_seed: 1157469596, max_time_in_seconds: 0.4
# 2024-08-17 20:01:12,689 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:12,689 - INFO - Starting solver with random_seed: 366365780, max_time_in_seconds: 0.4
# 2024-08-17 20:01:13,111 - INFO - Solver found a solution with objective value: 130983.0
# 2024-08-17 20:01:13,112 - INFO - Starting solver with random_seed: 1959423709, max_time_in_seconds: 0.4
# 2024-08-17 20:01:13,528 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:13,528 - INFO - Starting solver with random_seed: 1376803343, max_time_in_seconds: 0.4
# 2024-08-17 20:01:13,944 - INFO - Solver found a solution with objective value: 132224.0
# 2024-08-17 20:01:13,945 - INFO - Starting solver with random_seed: 1116065249, max_time_in_seconds: 0.4
# 2024-08-17 20:01:14,361 - INFO - Solver found a solution with objective value: 131765.0
# 2024-08-17 20:01:14,362 - INFO - Starting solver with random_seed: 155982067, max_time_in_seconds: 0.4
# 2024-08-17 20:01:14,779 - INFO - Solver found a solution with objective value: 131179.0
# 2024-08-17 20:01:14,780 - INFO - Starting solver with random_seed: 1200529287, max_time_in_seconds: 0.4
# 2024-08-17 20:01:15,199 - INFO - Solver found a solution with objective value: 129645.0
# 2024-08-17 20:01:15,199 - INFO - Starting solver with random_seed: 260145896, max_time_in_seconds: 0.4
# 2024-08-17 20:01:15,623 - INFO - Solver found a solution with objective value: 131575.0
# 2024-08-17 20:01:15,624 - INFO - Starting solver with random_seed: 1853203658, max_time_in_seconds: 0.4
# 2024-08-17 20:01:16,044 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-17 20:01:16,045 - INFO - Starting solver with random_seed: 362719209, max_time_in_seconds: 0.4
# 2024-08-17 20:01:16,461 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:16,462 - INFO - Starting solver with random_seed: 1126958992, max_time_in_seconds: 0.4
# 2024-08-17 20:01:16,879 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:16,880 - INFO - Starting solver with random_seed: 2075201346, max_time_in_seconds: 0.4
# 2024-08-17 20:01:17,302 - INFO - Solver found a solution with objective value: 132550.0
# 2024-08-17 20:01:17,303 - INFO - Starting solver with random_seed: 1250418472, max_time_in_seconds: 0.4
# 2024-08-17 20:01:17,722 - INFO - Solver found a solution with objective value: 131490.0
# 2024-08-17 20:01:17,722 - INFO - Starting solver with random_seed: 1372490652, max_time_in_seconds: 0.4
# 2024-08-17 20:01:18,140 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:18,140 - INFO - Evaluation completed and result cached.
# 2024-08-17 20:01:18,141 - INFO - Baseline evaluation completed: min=0.004713677948872407, mean=0.012993229607187939, max=0.031223726329592347
# [I 2024-08-17 20:01:18,141] A new study created in memory with name: no-name-eda8380c-6f93-483b-a85a-8726610e8288
# 2024-08-17 20:01:18,142 - INFO - Starting Optuna optimization.
# 2024-08-17 20:01:18,143 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:18,144 - INFO - Returning cached result.
# 2024-08-17 20:01:18,145 - INFO - Evaluating with params: {}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:18,145 - INFO - Returning cached result.
# 2024-08-17 20:01:18,145 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 20:01:18,145 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:18,146 - INFO - Returning cached result.
# [I 2024-08-17 20:01:18,147] Trial 0 finished with value: 0.012993229607187939 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:18,153 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:18,154 - INFO - Returning cached result.
# 2024-08-17 20:01:18,154 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'quick_restart_no_lp'], 'search_branching': 2, 'use_lns_only': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'linearization_level': 0}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:18,154 - INFO - Starting solver with random_seed: 1053812588, max_time_in_seconds: 0.4
# 2024-08-17 20:01:18,566 - INFO - Solver found a solution with objective value: 131794.0
# 2024-08-17 20:01:18,567 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:18,568] Trial 1 finished with value: 3.124808413129581 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:18,572 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:18,572 - INFO - Returning cached result.
# 2024-08-17 20:01:18,572 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'max_lp', 'pseudo_costs', 'probing'], 'search_branching': 3, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:18,573 - INFO - Starting solver with random_seed: 1097480092, max_time_in_seconds: 0.4
# 2024-08-17 20:01:18,957 - INFO - Solver found a solution with objective value: 129507.0
# 2024-08-17 20:01:18,958 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:18,959] Trial 2 finished with value: 0.03578957122008849 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 3, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:18,962 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:18,962 - INFO - Returning cached result.
# 2024-08-17 20:01:18,963 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'ignore_subsolvers': ['fixed', 'lb_tree_search', 'probing'], 'search_branching': 8, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 32}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:18,964 - INFO - Starting solver with random_seed: 1322272666, max_time_in_seconds: 0.4
# 2024-08-17 20:01:19,377 - INFO - Solver found a solution with objective value: 132215.0
# 2024-08-17 20:01:19,378 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:19,379] Trial 3 finished with value: 3.240252618840525 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 8, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:19,382 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:19,383 - INFO - Returning cached result.
# 2024-08-17 20:01:19,383 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'max_lp', 'reduced_costs', 'quick_restart_no_lp', 'probing'], 'search_branching': 1, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 128}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:19,383 - INFO - Starting solver with random_seed: 1042195386, max_time_in_seconds: 0.4
# 2024-08-17 20:01:19,797 - INFO - Solver found a solution with objective value: 132180.0
# 2024-08-17 20:01:19,798 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:19,799] Trial 4 finished with value: 0.102473899228325 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:19,802 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:19,802 - INFO - Returning cached result.
# 2024-08-17 20:01:19,803 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 0, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 4, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:19,803 - INFO - Starting solver with random_seed: 650804719, max_time_in_seconds: 0.4
# 2024-08-17 20:01:20,218 - INFO - Solver found a solution with objective value: 132064.0
# 2024-08-17 20:01:20,218 - INFO - Starting solver with random_seed: 1964759455, max_time_in_seconds: 0.4
# 2024-08-17 20:01:20,641 - INFO - Solver found a solution with objective value: 129462.0
# 2024-08-17 20:01:20,642 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:20,643] Trial 5 finished with value: 0.03431895073457849 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:20,647 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:20,647 - INFO - Returning cached result.
# 2024-08-17 20:01:20,648 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'max_presolve_iterations': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'probing'], 'search_branching': 8, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'linearization_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:20,649 - INFO - Starting solver with random_seed: 1363502278, max_time_in_seconds: 0.4
# 2024-08-17 20:01:21,059 - INFO - Solver found a solution with objective value: 130084.0
# 2024-08-17 20:01:21,060 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:21,060] Trial 6 finished with value: 3.2835783032502075 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 8, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:21,063 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:21,064 - INFO - Returning cached result.
# 2024-08-17 20:01:21,064 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 10, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['no_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 1, 'repair_hint': True, 'use_lns_only': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:21,064 - INFO - Starting solver with random_seed: 177887751, max_time_in_seconds: 0.4
# 2024-08-17 20:01:21,476 - INFO - Solver found a solution with objective value: 98395.0
# 2024-08-17 20:01:21,477 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:21,478] Trial 7 finished with value: 3.763707505462676 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:21,482 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:21,482 - INFO - Returning cached result.
# 2024-08-17 20:01:21,482 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['reduced_costs', 'quick_restart', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:21,483 - INFO - Starting solver with random_seed: 1017534111, max_time_in_seconds: 0.4
# 2024-08-17 20:01:21,897 - INFO - Solver found a solution with objective value: 131965.0
# 2024-08-17 20:01:21,898 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:21,899] Trial 8 finished with value: 3.248285530254234 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:21,903 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:21,904 - INFO - Returning cached result.
# 2024-08-17 20:01:21,904 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 1, 'repair_hint': True, 'use_lb_relax_lns': True, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:21,905 - INFO - Starting solver with random_seed: 470832794, max_time_in_seconds: 0.4
# 2024-08-17 20:01:22,346 - INFO - Solver found a solution with objective value: 132305.0
# 2024-08-17 20:01:22,347 - INFO - Starting solver with random_seed: 121852962, max_time_in_seconds: 0.4
# 2024-08-17 20:01:22,773 - INFO - Solver found a solution with objective value: 132375.0
# 2024-08-17 20:01:22,773 - INFO - Starting solver with random_seed: 546250905, max_time_in_seconds: 0.4
# 2024-08-17 20:01:23,187 - INFO - Solver found a solution with objective value: 132469.0
# 2024-08-17 20:01:23,188 - INFO - Starting solver with random_seed: 1586468269, max_time_in_seconds: 0.4
# 2024-08-17 20:01:23,632 - INFO - Solver found a solution with objective value: 131760.0
# 2024-08-17 20:01:23,632 - INFO - Starting solver with random_seed: 1252609928, max_time_in_seconds: 0.4
# 2024-08-17 20:01:24,065 - INFO - Solver found a solution with objective value: 130905.0
# 2024-08-17 20:01:24,065 - INFO - Starting solver with random_seed: 1408728700, max_time_in_seconds: 0.4
# 2024-08-17 20:01:24,514 - INFO - Solver found a solution with objective value: 127330.0
# 2024-08-17 20:01:24,514 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:24,515] Trial 9 finished with value: 0.05514018691588785 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:24,559 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:24,560 - INFO - Returning cached result.
# 2024-08-17 20:01:24,560 - INFO - Evaluating with params: {'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'reduced_costs', 'lb_tree_search'], 'repair_hint': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'linearization_level': 0, 'cut_level': 0, 'symmetry_level': 0}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:24,560 - INFO - Starting solver with random_seed: 609962823, max_time_in_seconds: 0.4
# 2024-08-17 20:01:24,974 - INFO - Solver found a solution with objective value: 102483.0
# 2024-08-17 20:01:24,975 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:24,977] Trial 10 finished with value: 5.46855576046759 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:25,024 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:25,025 - INFO - Returning cached result.
# 2024-08-17 20:01:25,025 - INFO - Evaluating with params: {'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 4, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 0}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:25,025 - INFO - Starting solver with random_seed: 1957745595, max_time_in_seconds: 0.4
# 2024-08-17 20:01:25,440 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:25,441 - INFO - Starting solver with random_seed: 1227412037, max_time_in_seconds: 0.4
# 2024-08-17 20:01:25,861 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:25,861 - INFO - Starting solver with random_seed: 1556986578, max_time_in_seconds: 0.4
# 2024-08-17 20:01:26,275 - INFO - Solver found a solution with objective value: 129073.0
# 2024-08-17 20:01:26,276 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:26,277] Trial 11 finished with value: 0.03578595058610244 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:26,320 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:26,321 - INFO - Returning cached result.
# 2024-08-17 20:01:26,321 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'max_presolve_iterations': 10, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 4, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'polish_lp_solution': True, 'cut_level': 2}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:26,321 - INFO - Starting solver with random_seed: 1643236784, max_time_in_seconds: 0.4
# 2024-08-17 20:01:26,736 - INFO - Solver found a solution with objective value: 132565.0
# 2024-08-17 20:01:26,737 - INFO - Starting solver with random_seed: 1041339394, max_time_in_seconds: 0.4
# 2024-08-17 20:01:27,151 - INFO - Solver found a solution with objective value: 128740.0
# 2024-08-17 20:01:27,151 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:27,152] Trial 12 finished with value: 0.04031381078141991 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 0.012993229607187939.
# 2024-08-17 20:01:27,196 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:27,196 - INFO - Returning cached result.
# 2024-08-17 20:01:27,197 - INFO - Evaluating with params: {'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['lb_tree_search'], 'fp_rounding': 1, 'add_objective_cut': True, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:27,197 - INFO - Starting solver with random_seed: 1935383096, max_time_in_seconds: 0.4
# 2024-08-17 20:01:27,610 - INFO - Solver found a solution with objective value: 132355.0
# 2024-08-17 20:01:27,611 - INFO - Starting solver with random_seed: 1944601268, max_time_in_seconds: 0.4
# 2024-08-17 20:01:28,024 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:28,025 - INFO - Starting solver with random_seed: 1275236301, max_time_in_seconds: 0.4
# 2024-08-17 20:01:28,439 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:28,440 - INFO - Starting solver with random_seed: 1863858379, max_time_in_seconds: 0.4
# 2024-08-17 20:01:28,855 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:28,856 - INFO - Starting solver with random_seed: 1226790105, max_time_in_seconds: 0.4
# 2024-08-17 20:01:29,272 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:29,273 - INFO - Starting solver with random_seed: 746325619, max_time_in_seconds: 0.4
# 2024-08-17 20:01:29,688 - INFO - Solver found a solution with objective value: 132460.0
# 2024-08-17 20:01:29,689 - INFO - Starting solver with random_seed: 782582108, max_time_in_seconds: 0.4
# 2024-08-17 20:01:30,104 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:30,105 - INFO - Starting solver with random_seed: 499398089, max_time_in_seconds: 0.4
# 2024-08-17 20:01:30,522 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:30,523 - INFO - Starting solver with random_seed: 728501951, max_time_in_seconds: 0.4
# 2024-08-17 20:01:30,940 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:30,940 - INFO - Starting solver with random_seed: 248637539, max_time_in_seconds: 0.4
# 2024-08-17 20:01:31,360 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:31,361 - INFO - Evaluation completed and result cached.
# 2024-08-17 20:01:31,361 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 20:01:31,361 - INFO - Evaluating with params: {'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['lb_tree_search'], 'fp_rounding': 1, 'add_objective_cut': True, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 40, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:31,362 - INFO - Starting solver with random_seed: 1399606510, max_time_in_seconds: 0.4
# 2024-08-17 20:01:31,785 - INFO - Solver found a solution with objective value: 131834.0
# 2024-08-17 20:01:31,785 - INFO - Starting solver with random_seed: 1038318917, max_time_in_seconds: 0.4
# 2024-08-17 20:01:32,201 - INFO - Solver found a solution with objective value: 132330.0
# 2024-08-17 20:01:32,202 - INFO - Starting solver with random_seed: 500589352, max_time_in_seconds: 0.4
# 2024-08-17 20:01:32,618 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:32,619 - INFO - Starting solver with random_seed: 601477802, max_time_in_seconds: 0.4
# 2024-08-17 20:01:33,033 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:33,034 - INFO - Starting solver with random_seed: 35330140, max_time_in_seconds: 0.4
# 2024-08-17 20:01:33,449 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:33,450 - INFO - Starting solver with random_seed: 278438054, max_time_in_seconds: 0.4
# 2024-08-17 20:01:33,863 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:33,864 - INFO - Starting solver with random_seed: 920960690, max_time_in_seconds: 0.4
# 2024-08-17 20:01:34,281 - INFO - Solver found a solution with objective value: 132480.0
# 2024-08-17 20:01:34,282 - INFO - Starting solver with random_seed: 890433799, max_time_in_seconds: 0.4
# 2024-08-17 20:01:34,699 - INFO - Solver found a solution with objective value: 132540.0
# 2024-08-17 20:01:34,700 - INFO - Starting solver with random_seed: 1478207679, max_time_in_seconds: 0.4
# 2024-08-17 20:01:35,115 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:35,116 - INFO - Starting solver with random_seed: 155052929, max_time_in_seconds: 0.4
# 2024-08-17 20:01:35,529 - INFO - Solver found a solution with objective value: 132540.0
# 2024-08-17 20:01:35,530 - INFO - Starting solver with random_seed: 1457429796, max_time_in_seconds: 0.4
# 2024-08-17 20:01:35,944 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-17 20:01:35,945 - INFO - Starting solver with random_seed: 653053793, max_time_in_seconds: 0.4
# 2024-08-17 20:01:36,358 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:36,359 - INFO - Starting solver with random_seed: 975323281, max_time_in_seconds: 0.4
# 2024-08-17 20:01:36,785 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:36,785 - INFO - Starting solver with random_seed: 2063731732, max_time_in_seconds: 0.4
# 2024-08-17 20:01:37,200 - INFO - Solver found a solution with objective value: 132333.0
# 2024-08-17 20:01:37,201 - INFO - Starting solver with random_seed: 466887543, max_time_in_seconds: 0.4
# 2024-08-17 20:01:37,618 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:37,619 - INFO - Starting solver with random_seed: 607900786, max_time_in_seconds: 0.4
# 2024-08-17 20:01:38,034 - INFO - Solver found a solution with objective value: 132445.0
# 2024-08-17 20:01:38,034 - INFO - Starting solver with random_seed: 1886677128, max_time_in_seconds: 0.4
# 2024-08-17 20:01:38,465 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:38,466 - INFO - Starting solver with random_seed: 1234604236, max_time_in_seconds: 0.4
# 2024-08-17 20:01:38,893 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:38,894 - INFO - Starting solver with random_seed: 316507727, max_time_in_seconds: 0.4
# 2024-08-17 20:01:39,309 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:39,310 - INFO - Starting solver with random_seed: 611097950, max_time_in_seconds: 0.4
# 2024-08-17 20:01:39,727 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:39,727 - INFO - Starting solver with random_seed: 1090161185, max_time_in_seconds: 0.4
# 2024-08-17 20:01:40,142 - INFO - Solver found a solution with objective value: 132440.0
# 2024-08-17 20:01:40,143 - INFO - Starting solver with random_seed: 2013338297, max_time_in_seconds: 0.4
# 2024-08-17 20:01:40,559 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:40,560 - INFO - Starting solver with random_seed: 1912991965, max_time_in_seconds: 0.4
# 2024-08-17 20:01:40,986 - INFO - Solver found a solution with objective value: 132805.0
# ...
# 2024-08-17 20:01:52,807 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:52,808 - INFO - Returning cached result.
# 2024-08-17 20:01:52,808 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['lb_tree_search'], 'search_branching': 7, 'fp_rounding': 1, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:52,808 - INFO - Starting solver with random_seed: 1725461874, max_time_in_seconds: 0.4
# 2024-08-17 20:01:53,239 - INFO - Solver found a solution with objective value: 132450.0
# 2024-08-17 20:01:53,239 - INFO - Starting solver with random_seed: 79615670, max_time_in_seconds: 0.4
# 2024-08-17 20:01:53,652 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:53,653 - INFO - Starting solver with random_seed: 1892665598, max_time_in_seconds: 0.4
# 2024-08-17 20:01:54,067 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:54,068 - INFO - Starting solver with random_seed: 1807041062, max_time_in_seconds: 0.4
# 2024-08-17 20:01:54,479 - INFO - Solver found a solution with objective value: 132214.0
# 2024-08-17 20:01:54,480 - INFO - Starting solver with random_seed: 994851403, max_time_in_seconds: 0.4
# 2024-08-17 20:01:54,896 - INFO - Solver found a solution with objective value: 132055.0
# 2024-08-17 20:01:54,896 - INFO - Starting solver with random_seed: 1969681432, max_time_in_seconds: 0.4
# 2024-08-17 20:01:55,328 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:55,328 - INFO - Starting solver with random_seed: 1457985222, max_time_in_seconds: 0.4
# 2024-08-17 20:01:55,740 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:55,741 - INFO - Starting solver with random_seed: 1195276582, max_time_in_seconds: 0.4
# 2024-08-17 20:01:56,155 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:56,155 - INFO - Starting solver with random_seed: 633171875, max_time_in_seconds: 0.4
# 2024-08-17 20:01:56,569 - INFO - Solver found a solution with objective value: 131910.0
# 2024-08-17 20:01:56,570 - INFO - Starting solver with random_seed: 1872024054, max_time_in_seconds: 0.4
# 2024-08-17 20:01:56,983 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:56,984 - INFO - Evaluation completed and result cached.
# [I 2024-08-17 20:01:56,985] Trial 17 finished with value: 0.008266542735139763 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 7, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 13 with value: 0.005522253021364602.
# 2024-08-17 20:01:57,034 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:57,034 - INFO - Returning cached result.
# 2024-08-17 20:01:57,035 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'reduced_costs', 'lb_tree_search'], 'search_branching': 5, 'repair_hint': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:57,035 - INFO - Starting solver with random_seed: 1191537856, max_time_in_seconds: 0.4
# 2024-08-17 20:01:57,447 - INFO - Solver found a solution with objective value: 132020.0
# 2024-08-17 20:01:57,447 - INFO - Returning knockout result.
# [I 2024-08-17 20:01:57,449] Trial 18 finished with value: 3.2462429934858354 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 5, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 13 with value: 0.005522253021364602.
# 2024-08-17 20:01:57,494 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 20:01:57,494 - INFO - Returning cached result.
# 2024-08-17 20:01:57,495 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['lb_tree_search'], 'search_branching': 7, 'fp_rounding': 1, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 10, knockout_score: 0.03387473116766434
# 2024-08-17 20:01:57,495 - INFO - Starting solver with random_seed: 371755062, max_time_in_seconds: 0.4
# 2024-08-17 20:01:57,881 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:57,882 - INFO - Starting solver with random_seed: 1988930514, max_time_in_seconds: 0.4
# 2024-08-17 20:01:58,300 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:58,300 - INFO - Starting solver with random_seed: 1243406550, max_time_in_seconds: 0.4
# 2024-08-17 20:01:58,708 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:58,709 - INFO - Starting solver with random_seed: 162238880, max_time_in_seconds: 0.4
# 2024-08-17 20:01:59,122 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:59,122 - INFO - Starting solver with random_seed: 587851704, max_time_in_seconds: 0.4
# 2024-08-17 20:01:59,500 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:59,500 - INFO - Starting solver with random_seed: 468507396, max_time_in_seconds: 0.4
# 2024-08-17 20:01:59,914 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:01:59,915 - INFO - Starting solver with random_seed: 2100177151, max_time_in_seconds: 0.4
# 2024-08-17 20:02:00,287 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:00,288 - INFO - Starting solver with random_seed: 1801922235, max_time_in_seconds: 0.4
# 2024-08-17 20:02:00,702 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:00,702 - INFO - Starting solver with random_seed: 552470601, max_time_in_seconds: 0.4
# 2024-08-17 20:02:01,115 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:01,115 - INFO - Starting solver with random_seed: 1607762038, max_time_in_seconds: 0.4
# 2024-08-17 20:02:01,524 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:01,525 - INFO - Evaluation completed and result cached.
# 2024-08-17 20:02:01,525 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 20:02:01,525 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['lb_tree_search'], 'search_branching': 7, 'fp_rounding': 1, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 40, knockout_score: 0.03387473116766434
# 2024-08-17 20:02:01,526 - INFO - Starting solver with random_seed: 2097519167, max_time_in_seconds: 0.4
# 2024-08-17 20:02:01,905 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:01,906 - INFO - Starting solver with random_seed: 96798033, max_time_in_seconds: 0.4
# 2024-08-17 20:02:02,321 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:02,321 - INFO - Starting solver with random_seed: 345334970, max_time_in_seconds: 0.4
# 2024-08-17 20:02:02,692 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:02,692 - INFO - Starting solver with random_seed: 826842904, max_time_in_seconds: 0.4
# 2024-08-17 20:02:03,106 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:03,107 - INFO - Starting solver with random_seed: 374247943, max_time_in_seconds: 0.4
# 2024-08-17 20:02:03,513 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:03,514 - INFO - Starting solver with random_seed: 739753114, max_time_in_seconds: 0.4
# 2024-08-17 20:02:03,924 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:03,925 - INFO - Starting solver with random_seed: 255572894, max_time_in_seconds: 0.4
# 2024-08-17 20:02:04,296 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:04,296 - INFO - Starting solver with random_seed: 959145551, max_time_in_seconds: 0.4
# 2024-08-17 20:02:04,711 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:04,712 - INFO - Starting solver with random_seed: 424247306, max_time_in_seconds: 0.4
# 2024-08-17 20:02:05,124 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:05,125 - INFO - Starting solver with random_seed: 1930271074, max_time_in_seconds: 0.4
# 2024-08-17 20:02:05,539 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:05,540 - INFO - Starting solver with random_seed: 362882450, max_time_in_seconds: 0.4
# 2024-08-17 20:02:05,946 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:05,947 - INFO - Starting solver with random_seed: 1091796697, max_time_in_seconds: 0.4
# 2024-08-17 20:02:06,360 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:06,361 - INFO - Starting solver with random_seed: 199598615, max_time_in_seconds: 0.4
# 2024-08-17 20:02:06,775 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:06,776 - INFO - Starting solver with random_seed: 1303422684, max_time_in_seconds: 0.4
# 2024-08-17 20:02:07,190 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:07,190 - INFO - Starting solver with random_seed: 190277211, max_time_in_seconds: 0.4
# 2024-08-17 20:02:07,571 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:07,571 - INFO - Starting solver with random_seed: 84133292, max_time_in_seconds: 0.4
# 2024-08-17 20:02:07,870 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:07,870 - INFO - Starting solver with random_seed: 2126798162, max_time_in_seconds: 0.4
# 2024-08-17 20:02:08,269 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:08,269 - INFO - Starting solver with random_seed: 1312646349, max_time_in_seconds: 0.4
# 2024-08-17 20:02:08,656 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:08,656 - INFO - Starting solver with random_seed: 155759442, max_time_in_seconds: 0.4
# 2024-08-17 20:02:09,070 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:09,071 - INFO - Starting solver with random_seed: 495123944, max_time_in_seconds: 0.4
# 2024-08-17 20:02:09,484 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:09,485 - INFO - Starting solver with random_seed: 567968921, max_time_in_seconds: 0.4
# 2024-08-17 20:02:09,850 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:09,850 - INFO - Starting solver with random_seed: 1740002442, max_time_in_seconds: 0.4
# 2024-08-17 20:02:10,265 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:10,265 - INFO - Starting solver with random_seed: 780336754, max_time_in_seconds: 0.4
# 2024-08-17 20:02:10,648 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:10,648 - INFO - Starting solver with random_seed: 404794812, max_time_in_seconds: 0.4
# 2024-08-17 20:02:11,036 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:11,036 - INFO - Starting solver with random_seed: 871840693, max_time_in_seconds: 0.4
# 2024-08-17 20:02:11,413 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:11,414 - INFO - Starting solver with random_seed: 1975901223, max_time_in_seconds: 0.4
# 2024-08-17 20:02:11,827 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 20:02:11,828 - INFO - Starting solver with random_seed: 1824998358, max_time_in_seconds: 0.4
