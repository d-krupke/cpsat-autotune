# %%
from cpsat_autotune import (
    tune_for_quality_within_timelimit,
    import_model,
    tune_time_to_optimal,
)

# %%
model = import_model("models/model_proto_-1368620059351071685.pb")

# %%
best = tune_time_to_optimal(
    model,
    max_time_in_seconds=3,  # Enter a time limit slightly above what the solver with default parameters needs
    n_samples_for_trial=5,  # Number of samples for each trial
    n_samples_for_verification=20,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-17 15:09:47,283 - INFO - Starting tuning to minimize time to optimal solution.
# 2024-08-17 15:09:47,284 - INFO - Initialized Metric with direction: minimize
# 2024-08-17 15:09:47,284 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-17 15:09:47,285 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:09:47,285 - INFO - Starting solver with random_seed: 1383549011, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:49,485 - INFO - Solver completed in 2.198949 seconds with status: 4
# 2024-08-17 15:09:49,485 - INFO - Starting solver with random_seed: 731376590, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:50,788 - INFO - Solver completed in 1.302853 seconds with status: 4
# 2024-08-17 15:09:50,789 - INFO - Starting solver with random_seed: 1159130177, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:53,133 - INFO - Solver completed in 2.343719 seconds with status: 4
# 2024-08-17 15:09:53,134 - INFO - Starting solver with random_seed: 468747690, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:54,857 - INFO - Solver completed in 1.722484 seconds with status: 4
# 2024-08-17 15:09:54,857 - INFO - Starting solver with random_seed: 1798926168, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:56,611 - INFO - Solver completed in 1.753743 seconds with status: 4
# 2024-08-17 15:09:56,612 - INFO - Starting solver with random_seed: 600782994, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:58,286 - INFO - Solver completed in 1.673676 seconds with status: 4
# 2024-08-17 15:09:58,287 - INFO - Starting solver with random_seed: 737962264, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:09:59,844 - INFO - Solver completed in 1.557517 seconds with status: 4
# 2024-08-17 15:09:59,845 - INFO - Starting solver with random_seed: 745399630, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:00,927 - INFO - Solver completed in 1.081431 seconds with status: 4
# 2024-08-17 15:10:00,927 - INFO - Starting solver with random_seed: 2052148764, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:02,141 - INFO - Solver completed in 1.213306 seconds with status: 4
# 2024-08-17 15:10:02,142 - INFO - Starting solver with random_seed: 1429799148, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:03,736 - INFO - Solver completed in 1.59372 seconds with status: 4
# 2024-08-17 15:10:03,736 - INFO - Starting solver with random_seed: 43922353, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:04,898 - INFO - Solver completed in 1.161242 seconds with status: 4
# 2024-08-17 15:10:04,899 - INFO - Starting solver with random_seed: 628305042, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:06,856 - INFO - Solver completed in 1.957506 seconds with status: 4
# 2024-08-17 15:10:06,857 - INFO - Starting solver with random_seed: 445775452, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:08,713 - INFO - Solver completed in 1.856066 seconds with status: 4
# 2024-08-17 15:10:08,714 - INFO - Starting solver with random_seed: 1845824163, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:10,491 - INFO - Solver completed in 1.776368 seconds with status: 4
# 2024-08-17 15:10:10,491 - INFO - Starting solver with random_seed: 1846298692, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:11,995 - INFO - Solver completed in 1.503162 seconds with status: 4
# 2024-08-17 15:10:11,995 - INFO - Starting solver with random_seed: 2108725596, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:13,992 - INFO - Solver completed in 1.996321 seconds with status: 4
# 2024-08-17 15:10:13,992 - INFO - Starting solver with random_seed: 927218145, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:15,636 - INFO - Solver completed in 1.643715 seconds with status: 4
# 2024-08-17 15:10:15,637 - INFO - Starting solver with random_seed: 724022840, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:16,679 - INFO - Solver completed in 1.042017 seconds with status: 4
# 2024-08-17 15:10:16,680 - INFO - Starting solver with random_seed: 1045821842, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:18,136 - INFO - Solver completed in 1.455871 seconds with status: 4
# 2024-08-17 15:10:18,137 - INFO - Starting solver with random_seed: 345444695, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:19,595 - INFO - Solver completed in 1.457841 seconds with status: 4
# 2024-08-17 15:10:19,595 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:10:19,596 - INFO - Baseline evaluation completed: min=1.042017, mean=1.6145753500000002, max=2.343719
# [I 2024-08-17 15:10:19,596] A new study created in memory with name: no-name-59dce673-abb6-441a-bea9-b580bdfbfb8d
# 2024-08-17 15:10:19,597 - INFO - Starting Optuna optimization.
# 2024-08-17 15:10:19,598 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:19,599 - INFO - Returning cached result.
# 2024-08-17 15:10:19,599 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:19,599 - INFO - Starting solver with random_seed: 433169133, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:20,675 - INFO - Solver completed in 1.075845 seconds with status: 4
# 2024-08-17 15:10:20,676 - INFO - Starting solver with random_seed: 1476692721, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:22,965 - INFO - Solver completed in 2.289141 seconds with status: 4
# 2024-08-17 15:10:22,966 - INFO - Starting solver with random_seed: 1754256381, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:24,124 - INFO - Solver completed in 1.158078 seconds with status: 4
# 2024-08-17 15:10:24,125 - INFO - Starting solver with random_seed: 1216852700, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:25,414 - INFO - Solver completed in 1.288465 seconds with status: 4
# 2024-08-17 15:10:25,414 - INFO - Starting solver with random_seed: 786984063, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:26,982 - INFO - Solver completed in 1.567383 seconds with status: 4
# 2024-08-17 15:10:26,983 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:10:26,983 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 15:10:26,983 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 20, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:26,983 - INFO - Starting solver with random_seed: 974059647, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:28,291 - INFO - Solver completed in 1.306799 seconds with status: 4
# 2024-08-17 15:10:28,291 - INFO - Starting solver with random_seed: 864658485, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:30,448 - INFO - Solver completed in 2.156084 seconds with status: 4
# 2024-08-17 15:10:30,448 - INFO - Starting solver with random_seed: 1252545414, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:32,118 - INFO - Solver completed in 1.669441 seconds with status: 4
# 2024-08-17 15:10:32,118 - INFO - Starting solver with random_seed: 1751689855, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:33,526 - INFO - Solver completed in 1.407192 seconds with status: 4
# 2024-08-17 15:10:33,527 - INFO - Starting solver with random_seed: 1818976676, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:35,077 - INFO - Solver completed in 1.550501 seconds with status: 4
# 2024-08-17 15:10:35,078 - INFO - Starting solver with random_seed: 711169691, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:36,498 - INFO - Solver completed in 1.419432 seconds with status: 4
# 2024-08-17 15:10:36,498 - INFO - Starting solver with random_seed: 61135604, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:37,765 - INFO - Solver completed in 1.265988 seconds with status: 4
# 2024-08-17 15:10:37,765 - INFO - Starting solver with random_seed: 893988656, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:39,270 - INFO - Solver completed in 1.503954 seconds with status: 4
# 2024-08-17 15:10:39,270 - INFO - Starting solver with random_seed: 1303795509, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:40,291 - INFO - Solver completed in 1.020418 seconds with status: 4
# 2024-08-17 15:10:40,291 - INFO - Starting solver with random_seed: 1910072538, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:41,803 - INFO - Solver completed in 1.511771 seconds with status: 4
# 2024-08-17 15:10:41,804 - INFO - Starting solver with random_seed: 1320267979, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:43,180 - INFO - Solver completed in 1.376199 seconds with status: 4
# 2024-08-17 15:10:43,181 - INFO - Starting solver with random_seed: 1022384131, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:44,477 - INFO - Solver completed in 1.295129 seconds with status: 4
# 2024-08-17 15:10:44,477 - INFO - Starting solver with random_seed: 217027896, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:45,693 - INFO - Solver completed in 1.215908 seconds with status: 4
# 2024-08-17 15:10:45,694 - INFO - Starting solver with random_seed: 515290921, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:47,110 - INFO - Solver completed in 1.415464 seconds with status: 4
# 2024-08-17 15:10:47,110 - INFO - Starting solver with random_seed: 949165866, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:48,347 - INFO - Solver completed in 1.236637 seconds with status: 4
# 2024-08-17 15:10:48,348 - INFO - Evaluation completed and result cached.
# [I 2024-08-17 15:10:48,350] Trial 0 finished with value: 1.43649145 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:48,353 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:48,354 - INFO - Returning cached result.
# 2024-08-17 15:10:48,354 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'max_lp', 'reduced_costs', 'lb_tree_search'], 'search_branching': 1, 'repair_hint': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:48,354 - INFO - Starting solver with random_seed: 693063401, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:51,366 - INFO - Solver completed in 3.011815 seconds with status: 2
# 2024-08-17 15:10:51,367 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:10:51,367 - INFO - Returning knockout result.
# [I 2024-08-17 15:10:51,368] Trial 1 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 1, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:51,372 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:51,372 - INFO - Returning cached result.
# 2024-08-17 15:10:51,372 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 8, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:51,372 - INFO - Starting solver with random_seed: 1302118268, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:54,392 - INFO - Solver completed in 3.019359 seconds with status: 2
# 2024-08-17 15:10:54,393 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:10:54,393 - INFO - Returning knockout result.
# [I 2024-08-17 15:10:54,394] Trial 2 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:54,397 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:54,397 - INFO - Returning cached result.
# 2024-08-17 15:10:54,397 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 8, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:54,397 - INFO - Starting solver with random_seed: 283089937, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:10:57,411 - INFO - Solver completed in 3.013814 seconds with status: 2
# 2024-08-17 15:10:57,412 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:10:57,412 - INFO - Returning knockout result.
# [I 2024-08-17 15:10:57,413] Trial 3 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 8, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:10:57,416 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:10:57,416 - INFO - Returning cached result.
# 2024-08-17 15:10:57,417 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 1, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:10:57,417 - INFO - Starting solver with random_seed: 779169821, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:00,429 - INFO - Solver completed in 3.011973 seconds with status: 2
# 2024-08-17 15:11:00,430 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:00,430 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:00,431] Trial 4 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:00,436 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:00,437 - INFO - Returning cached result.
# 2024-08-17 15:11:00,437 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'probing'], 'search_branching': 6, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:00,437 - INFO - Starting solver with random_seed: 1793497393, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:03,461 - INFO - Solver completed in 3.023445 seconds with status: 2
# 2024-08-17 15:11:03,462 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:03,462 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:03,463] Trial 5 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:03,469 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:03,469 - INFO - Returning cached result.
# 2024-08-17 15:11:03,470 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 8, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:03,470 - INFO - Starting solver with random_seed: 1100474644, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:06,493 - INFO - Solver completed in 3.022235 seconds with status: 2
# 2024-08-17 15:11:06,493 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:06,494 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:06,494] Trial 6 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:06,497 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:06,498 - INFO - Returning cached result.
# 2024-08-17 15:11:06,498 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'clause_cleanup_protection': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'pseudo_costs', 'quick_restart'], 'search_branching': 3, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:06,499 - INFO - Starting solver with random_seed: 1640489858, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:09,532 - INFO - Solver completed in 3.032785 seconds with status: 2
# 2024-08-17 15:11:09,532 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:09,533 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:09,534] Trial 7 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:09,538 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:09,538 - INFO - Returning cached result.
# 2024-08-17 15:11:09,539 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:09,539 - INFO - Starting solver with random_seed: 1950262535, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:12,554 - INFO - Solver completed in 3.014564 seconds with status: 2
# 2024-08-17 15:11:12,554 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:12,555 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:12,556] Trial 8 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 0}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:12,559 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:12,559 - INFO - Returning cached result.
# 2024-08-17 15:11:12,560 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 5, 'repair_hint': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'polish_lp_solution': True, 'linearization_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:12,560 - INFO - Starting solver with random_seed: 1356428682, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:15,578 - INFO - Solver completed in 3.017247 seconds with status: 2
# 2024-08-17 15:11:15,578 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:15,578 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:15,579] Trial 9 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 5, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:15,622 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:15,622 - INFO - Returning cached result.
# 2024-08-17 15:11:15,622 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:15,623 - INFO - Starting solver with random_seed: 575150107, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:18,005 - INFO - Solver completed in 2.382045 seconds with status: 4
# 2024-08-17 15:11:18,006 - INFO - Starting solver with random_seed: 1559614286, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:20,533 - INFO - Solver completed in 2.526615 seconds with status: 4
# 2024-08-17 15:11:20,533 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:20,534] Trial 10 finished with value: 2.526615 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:20,577 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:20,577 - INFO - Returning cached result.
# 2024-08-17 15:11:20,578 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:20,578 - INFO - Starting solver with random_seed: 1391725227, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:23,426 - INFO - Solver completed in 2.848024 seconds with status: 4
# 2024-08-17 15:11:23,427 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:23,428] Trial 11 finished with value: 2.848024 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:23,472 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:23,472 - INFO - Returning cached result.
# 2024-08-17 15:11:23,473 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:23,473 - INFO - Starting solver with random_seed: 551823881, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:25,352 - INFO - Solver completed in 1.878258 seconds with status: 4
# 2024-08-17 15:11:25,352 - INFO - Starting solver with random_seed: 1905696713, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:26,566 - INFO - Solver completed in 1.213452 seconds with status: 4
# 2024-08-17 15:11:26,567 - INFO - Starting solver with random_seed: 679618146, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:28,467 - INFO - Solver completed in 1.899754 seconds with status: 4
# 2024-08-17 15:11:28,467 - INFO - Starting solver with random_seed: 1681706302, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:29,969 - INFO - Solver completed in 1.501197 seconds with status: 4
# 2024-08-17 15:11:29,969 - INFO - Starting solver with random_seed: 791831354, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:31,850 - INFO - Solver completed in 1.880544 seconds with status: 4
# 2024-08-17 15:11:31,851 - INFO - Evaluation completed and result cached.
# [I 2024-08-17 15:11:31,852] Trial 12 finished with value: 1.674641 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:31,898 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:31,899 - INFO - Returning cached result.
# 2024-08-17 15:11:31,899 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart_no_lp'], 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:31,899 - INFO - Starting solver with random_seed: 1405727505, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:34,918 - INFO - Solver completed in 3.018759 seconds with status: 2
# 2024-08-17 15:11:34,919 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-17 15:11:34,919 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:34,920] Trial 13 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 1.43649145.
# 2024-08-17 15:11:34,966 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-17 15:11:34,967 - INFO - Returning cached result.
# 2024-08-17 15:11:34,967 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['quick_restart_no_lp'], 'search_branching': 2, 'repair_hint': True, 'use_lb_relax_lns': True, 'linearization_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.4738892000000003
# 2024-08-17 15:11:34,967 - INFO - Starting solver with random_seed: 1083188333, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:37,119 - INFO - Solver completed in 2.151598 seconds with status: 4
# 2024-08-17 15:11:37,120 - INFO - Starting solver with random_seed: 35545220, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:39,312 - INFO - Solver completed in 2.191862 seconds with status: 4
# 2024-08-17 15:11:39,313 - INFO - Starting solver with random_seed: 1151479737, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:40,710 - INFO - Solver completed in 1.39737 seconds with status: 4
# 2024-08-17 15:11:40,711 - INFO - Starting solver with random_seed: 1615106164, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:11:43,451 - INFO - Solver completed in 2.739361 seconds with status: 4
# 2024-08-17 15:11:43,451 - INFO - Returning knockout result.
# [I 2024-08-17 15:11:43,452] Trial 14 finished with value: 2.739361 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 1.43649145.
# ...
# 2024-08-17 15:14:56,661 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-17 15:14:56,661 - INFO - Starting solver with random_seed: 2099374351, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:57,125 - INFO - Solver completed in 0.463796 seconds with status: 4
# 2024-08-17 15:14:57,126 - INFO - Starting solver with random_seed: 1216632387, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:57,694 - INFO - Solver completed in 0.5678 seconds with status: 4
# 2024-08-17 15:14:57,695 - INFO - Starting solver with random_seed: 433861621, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:58,035 - INFO - Solver completed in 0.340633 seconds with status: 4
# 2024-08-17 15:14:58,036 - INFO - Starting solver with random_seed: 468255983, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:58,464 - INFO - Solver completed in 0.427433 seconds with status: 4
# 2024-08-17 15:14:58,464 - INFO - Starting solver with random_seed: 44821627, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:59,031 - INFO - Solver completed in 0.566793 seconds with status: 4
# 2024-08-17 15:14:59,032 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:14:59,032 - INFO - Parameter 'fp_rounding' can be dropped from the optimized parameters.
# 2024-08-17 15:14:59,032 - INFO - Evaluating resetting parameter 'linearization_level' to default...
# 2024-08-17 15:14:59,033 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'cut_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-17 15:14:59,033 - INFO - Starting solver with random_seed: 1572225200, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:59,394 - INFO - Solver completed in 0.360752 seconds with status: 4
# 2024-08-17 15:14:59,395 - INFO - Starting solver with random_seed: 856239723, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:14:59,882 - INFO - Solver completed in 0.486927 seconds with status: 4
# 2024-08-17 15:14:59,883 - INFO - Starting solver with random_seed: 1299956550, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:00,212 - INFO - Solver completed in 0.328881 seconds with status: 4
# 2024-08-17 15:15:00,212 - INFO - Starting solver with random_seed: 1017194230, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:00,624 - INFO - Solver completed in 0.411077 seconds with status: 4
# 2024-08-17 15:15:00,625 - INFO - Starting solver with random_seed: 32253583, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:01,054 - INFO - Solver completed in 0.429314 seconds with status: 4
# 2024-08-17 15:15:01,055 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:01,055 - INFO - Parameter 'linearization_level' can be dropped from the optimized parameters.
# 2024-08-17 15:15:01,055 - INFO - Evaluating resetting parameter 'cut_level' to default...
# 2024-08-17 15:15:01,056 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-17 15:15:01,056 - INFO - Starting solver with random_seed: 551824446, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:02,062 - INFO - Solver completed in 1.005344 seconds with status: 4
# 2024-08-17 15:15:02,062 - INFO - Starting solver with random_seed: 775340561, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:03,079 - INFO - Solver completed in 1.016922 seconds with status: 4
# 2024-08-17 15:15:03,080 - INFO - Starting solver with random_seed: 1626517169, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:03,708 - INFO - Solver completed in 0.627719 seconds with status: 4
# 2024-08-17 15:15:03,709 - INFO - Starting solver with random_seed: 2127519714, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:04,365 - INFO - Solver completed in 0.655867 seconds with status: 4
# 2024-08-17 15:15:04,366 - INFO - Starting solver with random_seed: 158304753, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:05,318 - INFO - Solver completed in 0.952177 seconds with status: 4
# 2024-08-17 15:15:05,319 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:05,319 - INFO - Parameter 'cut_level' is essential for performance.
# 2024-08-17 15:15:05,319 - INFO - Evaluating resetting parameter 'max_all_diff_cut_size' to default...
# 2024-08-17 15:15:05,319 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 0, 'cut_level': 0}, num_runs: 5, knockout_score: None
# 2024-08-17 15:15:05,320 - INFO - Starting solver with random_seed: 1091904205, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:05,782 - INFO - Solver completed in 0.462024 seconds with status: 4
# 2024-08-17 15:15:05,783 - INFO - Starting solver with random_seed: 183911944, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:06,265 - INFO - Solver completed in 0.481871 seconds with status: 4
# 2024-08-17 15:15:06,266 - INFO - Starting solver with random_seed: 532192160, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:06,734 - INFO - Solver completed in 0.467556 seconds with status: 4
# 2024-08-17 15:15:06,734 - INFO - Starting solver with random_seed: 1574286536, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:07,167 - INFO - Solver completed in 0.432335 seconds with status: 4
# 2024-08-17 15:15:07,167 - INFO - Starting solver with random_seed: 1169282574, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:07,505 - INFO - Solver completed in 0.337355 seconds with status: 4
# 2024-08-17 15:15:07,506 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:07,506 - INFO - Parameter 'max_all_diff_cut_size' can be dropped from the optimized parameters.
# 2024-08-17 15:15:07,507 - INFO - Evaluating with params: {'cp_model_probing_level': 0, 'cut_level': 0}, num_runs: 20, knockout_score: None
# 2024-08-17 15:15:07,507 - INFO - Starting solver with random_seed: 979707413, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:08,000 - INFO - Solver completed in 0.492724 seconds with status: 4
# 2024-08-17 15:15:08,001 - INFO - Starting solver with random_seed: 65512579, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:08,410 - INFO - Solver completed in 0.408467 seconds with status: 4
# 2024-08-17 15:15:08,410 - INFO - Starting solver with random_seed: 1723007468, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:08,820 - INFO - Solver completed in 0.409854 seconds with status: 4
# 2024-08-17 15:15:08,821 - INFO - Starting solver with random_seed: 1381109162, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:09,377 - INFO - Solver completed in 0.555909 seconds with status: 4
# 2024-08-17 15:15:09,378 - INFO - Starting solver with random_seed: 786588924, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:10,218 - INFO - Solver completed in 0.8403 seconds with status: 4
# 2024-08-17 15:15:10,219 - INFO - Starting solver with random_seed: 1645869035, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:10,650 - INFO - Solver completed in 0.430959 seconds with status: 4
# 2024-08-17 15:15:10,651 - INFO - Starting solver with random_seed: 471296462, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:11,075 - INFO - Solver completed in 0.423553 seconds with status: 4
# 2024-08-17 15:15:11,076 - INFO - Starting solver with random_seed: 251538341, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:11,633 - INFO - Solver completed in 0.557149 seconds with status: 4
# 2024-08-17 15:15:11,634 - INFO - Starting solver with random_seed: 1883378135, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:12,113 - INFO - Solver completed in 0.479583 seconds with status: 4
# 2024-08-17 15:15:12,114 - INFO - Starting solver with random_seed: 223675718, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:12,480 - INFO - Solver completed in 0.365221 seconds with status: 4
# 2024-08-17 15:15:12,480 - INFO - Starting solver with random_seed: 1699145421, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:12,849 - INFO - Solver completed in 0.368419 seconds with status: 4
# 2024-08-17 15:15:12,849 - INFO - Starting solver with random_seed: 1624246718, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:13,303 - INFO - Solver completed in 0.453353 seconds with status: 4
# 2024-08-17 15:15:13,304 - INFO - Starting solver with random_seed: 380087502, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:13,645 - INFO - Solver completed in 0.340489 seconds with status: 4
# 2024-08-17 15:15:13,645 - INFO - Starting solver with random_seed: 403692753, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:14,042 - INFO - Solver completed in 0.396563 seconds with status: 4
# 2024-08-17 15:15:14,043 - INFO - Starting solver with random_seed: 837440845, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:14,528 - INFO - Solver completed in 0.48506 seconds with status: 4
# 2024-08-17 15:15:14,529 - INFO - Starting solver with random_seed: 1438387659, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:14,920 - INFO - Solver completed in 0.390817 seconds with status: 4
# 2024-08-17 15:15:14,921 - INFO - Starting solver with random_seed: 1422537533, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:15,333 - INFO - Solver completed in 0.411689 seconds with status: 4
# 2024-08-17 15:15:15,333 - INFO - Starting solver with random_seed: 2007885659, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:15,816 - INFO - Solver completed in 0.482978 seconds with status: 4
# 2024-08-17 15:15:15,817 - INFO - Starting solver with random_seed: 945806970, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:16,501 - INFO - Solver completed in 0.683314 seconds with status: 4
# 2024-08-17 15:15:16,502 - INFO - Starting solver with random_seed: 1826445006, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-17 15:15:17,088 - INFO - Solver completed in 0.586123 seconds with status: 4
# 2024-08-17 15:15:17,089 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:15:17,089 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter              ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ cp_model_probing_level │   0   │    49.51%    │       2       │
# │ 2   │ cut_level              │   0   │    50.49%    │       1       │
# └─────┴────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
#
# 2. cut_level Sets the level of effort the solver will invest in generating cutting planes, which are linear
# constraints added to remove infeasible regions. Properly applied, cuts can significantly reduce the search space
# and help the solver find an optimal solution more quickly.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                                    ┃ Mean ┃  Min ┃  Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━━━┩
# │ Time in seconds with Default Parameters   │ 1.61 │ 1.04 │ 2.34 │       20 │
# │ Time in seconds with Optimized Parameters │ 0.48 │ 0.34 │ 0.84 │       20 │
# └───────────────────────────────────────────┴──────┴──────┴──────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-17 15:15:17,105 - INFO - Hyperparameter tuning completed.
# 2024-08-17 15:15:17,106 - INFO - Tuning for time to optimal completed.

# %%
best = tune_for_quality_within_timelimit(
    model,
    max_time_in_seconds=0.5,
    obj_for_timeout=0,
    direction="maximize",
    n_samples_for_trial=10,  # Number of samples for each trial
    n_samples_for_verification=40,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-17 15:20:01,942 - INFO - Starting tuning for quality within time limit. Direction: maximize
# 2024-08-17 15:20:01,942 - INFO - Initialized Metric with direction: maximize
# 2024-08-17 15:20:01,943 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-17 15:20:01,943 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:01,943 - INFO - Starting solver with random_seed: 1995863275, max_time_in_seconds: 0.5
# 2024-08-17 15:20:02,462 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:02,463 - INFO - Starting solver with random_seed: 1461274366, max_time_in_seconds: 0.5
# 2024-08-17 15:20:02,980 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:02,981 - INFO - Starting solver with random_seed: 1500808210, max_time_in_seconds: 0.5
# 2024-08-17 15:20:03,497 - INFO - Solver found a solution with objective value: 130403.0
# 2024-08-17 15:20:03,498 - INFO - Starting solver with random_seed: 1093083514, max_time_in_seconds: 0.5
# 2024-08-17 15:20:04,018 - INFO - Solver found a solution with objective value: 131365.0
# 2024-08-17 15:20:04,018 - INFO - Starting solver with random_seed: 649777818, max_time_in_seconds: 0.5
# 2024-08-17 15:20:04,534 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-17 15:20:04,535 - INFO - Starting solver with random_seed: 748878317, max_time_in_seconds: 0.5
# 2024-08-17 15:20:05,052 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-17 15:20:05,053 - INFO - Starting solver with random_seed: 1750985406, max_time_in_seconds: 0.5
# 2024-08-17 15:20:05,570 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:05,571 - INFO - Starting solver with random_seed: 1425028617, max_time_in_seconds: 0.5
# 2024-08-17 15:20:06,088 - INFO - Solver found a solution with objective value: 132023.0
# 2024-08-17 15:20:06,088 - INFO - Starting solver with random_seed: 163448319, max_time_in_seconds: 0.5
# 2024-08-17 15:20:06,604 - INFO - Solver found a solution with objective value: 130268.0
# 2024-08-17 15:20:06,605 - INFO - Starting solver with random_seed: 124596982, max_time_in_seconds: 0.5
# 2024-08-17 15:20:07,121 - INFO - Solver found a solution with objective value: 131985.0
# 2024-08-17 15:20:07,122 - INFO - Starting solver with random_seed: 1347977365, max_time_in_seconds: 0.5
# 2024-08-17 15:20:07,640 - INFO - Solver found a solution with objective value: 131719.0
# 2024-08-17 15:20:07,640 - INFO - Starting solver with random_seed: 603733575, max_time_in_seconds: 0.5
# 2024-08-17 15:20:08,156 - INFO - Solver found a solution with objective value: 131070.0
# 2024-08-17 15:20:08,156 - INFO - Starting solver with random_seed: 2093350866, max_time_in_seconds: 0.5
# 2024-08-17 15:20:08,671 - INFO - Solver found a solution with objective value: 132175.0
# 2024-08-17 15:20:08,672 - INFO - Starting solver with random_seed: 785542680, max_time_in_seconds: 0.5
# 2024-08-17 15:20:09,187 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:09,188 - INFO - Starting solver with random_seed: 1520571300, max_time_in_seconds: 0.5
# 2024-08-17 15:20:09,706 - INFO - Solver found a solution with objective value: 131748.0
# 2024-08-17 15:20:09,707 - INFO - Starting solver with random_seed: 1107360682, max_time_in_seconds: 0.5
# 2024-08-17 15:20:10,226 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:10,227 - INFO - Starting solver with random_seed: 983418185, max_time_in_seconds: 0.5
# 2024-08-17 15:20:10,745 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:10,746 - INFO - Starting solver with random_seed: 1545804670, max_time_in_seconds: 0.5
# 2024-08-17 15:20:11,262 - INFO - Solver found a solution with objective value: 131309.0
# 2024-08-17 15:20:11,263 - INFO - Starting solver with random_seed: 1703135260, max_time_in_seconds: 0.5
# 2024-08-17 15:20:11,777 - INFO - Solver found a solution with objective value: 131555.0
# 2024-08-17 15:20:11,778 - INFO - Starting solver with random_seed: 1166765083, max_time_in_seconds: 0.5
# 2024-08-17 15:20:12,295 - INFO - Solver found a solution with objective value: 132280.0
# 2024-08-17 15:20:12,295 - INFO - Starting solver with random_seed: 1194318667, max_time_in_seconds: 0.5
# 2024-08-17 15:20:12,814 - INFO - Solver found a solution with objective value: 131125.0
# 2024-08-17 15:20:12,815 - INFO - Starting solver with random_seed: 855578409, max_time_in_seconds: 0.5
# 2024-08-17 15:20:13,330 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-17 15:20:13,331 - INFO - Starting solver with random_seed: 96336806, max_time_in_seconds: 0.5
# 2024-08-17 15:20:13,847 - INFO - Solver found a solution with objective value: 131560.0
# 2024-08-17 15:20:13,848 - INFO - Starting solver with random_seed: 43446538, max_time_in_seconds: 0.5
# 2024-08-17 15:20:14,364 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:14,365 - INFO - Starting solver with random_seed: 1593748545, max_time_in_seconds: 0.5
# 2024-08-17 15:20:14,882 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:14,883 - INFO - Starting solver with random_seed: 32313405, max_time_in_seconds: 0.5
# 2024-08-17 15:20:15,400 - INFO - Solver found a solution with objective value: 132115.0
# 2024-08-17 15:20:15,401 - INFO - Starting solver with random_seed: 720384006, max_time_in_seconds: 0.5
# 2024-08-17 15:20:15,917 - INFO - Solver found a solution with objective value: 132015.0
# 2024-08-17 15:20:15,918 - INFO - Starting solver with random_seed: 1788006388, max_time_in_seconds: 0.5
# 2024-08-17 15:20:16,435 - INFO - Solver found a solution with objective value: 132115.0
# 2024-08-17 15:20:16,436 - INFO - Starting solver with random_seed: 778718908, max_time_in_seconds: 0.5
# 2024-08-17 15:20:16,952 - INFO - Solver found a solution with objective value: 132710.0
# 2024-08-17 15:20:16,952 - INFO - Starting solver with random_seed: 1675105140, max_time_in_seconds: 0.5
# 2024-08-17 15:20:17,467 - INFO - Solver found a solution with objective value: 130840.0
# 2024-08-17 15:20:17,467 - INFO - Starting solver with random_seed: 952930720, max_time_in_seconds: 0.5
# 2024-08-17 15:20:17,985 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:17,986 - INFO - Starting solver with random_seed: 378871610, max_time_in_seconds: 0.5
# 2024-08-17 15:20:18,502 - INFO - Solver found a solution with objective value: 131760.0
# 2024-08-17 15:20:18,503 - INFO - Starting solver with random_seed: 1994047113, max_time_in_seconds: 0.5
# 2024-08-17 15:20:19,020 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:19,020 - INFO - Starting solver with random_seed: 408149523, max_time_in_seconds: 0.5
# 2024-08-17 15:20:19,537 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:19,538 - INFO - Starting solver with random_seed: 1191569593, max_time_in_seconds: 0.5
# 2024-08-17 15:20:20,054 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:20,055 - INFO - Starting solver with random_seed: 1524484690, max_time_in_seconds: 0.5
# 2024-08-17 15:20:20,570 - INFO - Solver found a solution with objective value: 131520.0
# 2024-08-17 15:20:20,571 - INFO - Starting solver with random_seed: 1352667885, max_time_in_seconds: 0.5
# 2024-08-17 15:20:21,088 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:21,089 - INFO - Starting solver with random_seed: 169062009, max_time_in_seconds: 0.5
# 2024-08-17 15:20:21,605 - INFO - Solver found a solution with objective value: 132218.0
# 2024-08-17 15:20:21,606 - INFO - Starting solver with random_seed: 1519481100, max_time_in_seconds: 0.5
# 2024-08-17 15:20:22,120 - INFO - Solver found a solution with objective value: 131539.0
# 2024-08-17 15:20:22,121 - INFO - Starting solver with random_seed: 2128324229, max_time_in_seconds: 0.5
# 2024-08-17 15:20:22,642 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:22,643 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:20:22,643 - INFO - Baseline evaluation completed: min=130268.0, mean=132081.575, max=132805.0
# [I 2024-08-17 15:20:22,644] A new study created in memory with name: no-name-11a9388c-cbd1-4260-adac-6ce7aaef68f9
# 2024-08-17 15:20:22,644 - INFO - Starting Optuna optimization.
# 2024-08-17 15:20:22,645 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:22,646 - INFO - Returning cached result.
# 2024-08-17 15:20:22,646 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:22,646 - INFO - Starting solver with random_seed: 912785534, max_time_in_seconds: 0.5
# 2024-08-17 15:20:23,163 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:23,164 - INFO - Starting solver with random_seed: 734922194, max_time_in_seconds: 0.5
# 2024-08-17 15:20:23,686 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:23,687 - INFO - Starting solver with random_seed: 1757619203, max_time_in_seconds: 0.5
# 2024-08-17 15:20:24,203 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-17 15:20:24,204 - INFO - Starting solver with random_seed: 1827082859, max_time_in_seconds: 0.5
# 2024-08-17 15:20:24,720 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:24,721 - INFO - Starting solver with random_seed: 1058246652, max_time_in_seconds: 0.5
# 2024-08-17 15:20:25,238 - INFO - Solver found a solution with objective value: 130799.0
# 2024-08-17 15:20:25,239 - INFO - Starting solver with random_seed: 1438315639, max_time_in_seconds: 0.5
# 2024-08-17 15:20:25,759 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:25,760 - INFO - Starting solver with random_seed: 1865787871, max_time_in_seconds: 0.5
# 2024-08-17 15:20:26,278 - INFO - Solver found a solution with objective value: 132310.0
# 2024-08-17 15:20:26,279 - INFO - Starting solver with random_seed: 1350167440, max_time_in_seconds: 0.5
# 2024-08-17 15:20:26,796 - INFO - Solver found a solution with objective value: 132260.0
# 2024-08-17 15:20:26,797 - INFO - Starting solver with random_seed: 877009860, max_time_in_seconds: 0.5
# 2024-08-17 15:20:27,314 - INFO - Solver found a solution with objective value: 129976.0
# 2024-08-17 15:20:27,315 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:27,316] Trial 0 finished with value: 129976.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:27,320 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:27,320 - INFO - Returning cached result.
# 2024-08-17 15:20:27,320 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['no_lp', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 5, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'linearization_level': 2, 'symmetry_level': 1}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:27,320 - INFO - Starting solver with random_seed: 920071017, max_time_in_seconds: 0.5
# 2024-08-17 15:20:27,832 - INFO - Solver found a solution with objective value: 127905.0
# 2024-08-17 15:20:27,833 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:27,834] Trial 1 finished with value: 127905.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 5, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:27,838 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:27,838 - INFO - Returning cached result.
# 2024-08-17 15:20:27,838 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp'], 'search_branching': 2, 'repair_hint': True, 'use_lns_only': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 0}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:27,838 - INFO - Starting solver with random_seed: 1534021211, max_time_in_seconds: 0.5
# 2024-08-17 15:20:28,348 - INFO - Solver found a solution with objective value: 132389.0
# 2024-08-17 15:20:28,348 - INFO - Starting solver with random_seed: 718274684, max_time_in_seconds: 0.5
# 2024-08-17 15:20:28,858 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:28,858 - INFO - Starting solver with random_seed: 887775174, max_time_in_seconds: 0.5
# 2024-08-17 15:20:29,370 - INFO - Solver found a solution with objective value: 132469.0
# 2024-08-17 15:20:29,370 - INFO - Starting solver with random_seed: 1978210042, max_time_in_seconds: 0.5
# 2024-08-17 15:20:29,880 - INFO - Solver found a solution with objective value: 132469.0
# 2024-08-17 15:20:29,881 - INFO - Starting solver with random_seed: 1277141146, max_time_in_seconds: 0.5
# 2024-08-17 15:20:30,391 - INFO - Solver found a solution with objective value: 132544.0
# 2024-08-17 15:20:30,392 - INFO - Starting solver with random_seed: 481970664, max_time_in_seconds: 0.5
# 2024-08-17 15:20:30,903 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-17 15:20:30,904 - INFO - Starting solver with random_seed: 1283029159, max_time_in_seconds: 0.5
# 2024-08-17 15:20:31,421 - INFO - Solver found a solution with objective value: 131600.0
# 2024-08-17 15:20:31,422 - INFO - Starting solver with random_seed: 472147415, max_time_in_seconds: 0.5
# 2024-08-17 15:20:31,936 - INFO - Solver found a solution with objective value: 131870.0
# 2024-08-17 15:20:31,937 - INFO - Starting solver with random_seed: 357876399, max_time_in_seconds: 0.5
# 2024-08-17 15:20:32,448 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:32,449 - INFO - Starting solver with random_seed: 944829409, max_time_in_seconds: 0.5
# 2024-08-17 15:20:32,960 - INFO - Solver found a solution with objective value: 132065.0
# 2024-08-17 15:20:32,961 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:20:32,961 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-17 15:20:32,961 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp'], 'search_branching': 2, 'repair_hint': True, 'use_lns_only': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 0}, num_runs: 40, knockout_score: 130014.3
# 2024-08-17 15:20:32,962 - INFO - Starting solver with random_seed: 993333189, max_time_in_seconds: 0.5
# 2024-08-17 15:20:33,477 - INFO - Solver found a solution with objective value: 132438.0
# 2024-08-17 15:20:33,478 - INFO - Starting solver with random_seed: 196094532, max_time_in_seconds: 0.5
# 2024-08-17 15:20:33,995 - INFO - Solver found a solution with objective value: 132080.0
# 2024-08-17 15:20:33,996 - INFO - Starting solver with random_seed: 157965282, max_time_in_seconds: 0.5
# 2024-08-17 15:20:34,510 - INFO - Solver found a solution with objective value: 129198.0
# 2024-08-17 15:20:34,511 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:34,512] Trial 2 finished with value: 129198.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:34,515 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:34,515 - INFO - Returning cached result.
# 2024-08-17 15:20:34,516 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'lb_tree_search'], 'search_branching': 1, 'repair_hint': True, 'use_objective_shaving_search': True, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:34,516 - INFO - Starting solver with random_seed: 2121367448, max_time_in_seconds: 0.5
# 2024-08-17 15:20:35,033 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-17 15:20:35,034 - INFO - Starting solver with random_seed: 783372055, max_time_in_seconds: 0.5
# 2024-08-17 15:20:35,562 - INFO - Solver found a solution with objective value: 126917.0
# 2024-08-17 15:20:35,563 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:35,564] Trial 3 finished with value: 126917.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:35,567 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:35,567 - INFO - Returning cached result.
# 2024-08-17 15:20:35,567 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 1, 'repair_hint': True, 'use_lb_relax_lns': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'linearization_level': 2, 'symmetry_level': 0}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:35,568 - INFO - Starting solver with random_seed: 1935441521, max_time_in_seconds: 0.5
# 2024-08-17 15:20:36,082 - INFO - Solver found a solution with objective value: 130848.0
# 2024-08-17 15:20:36,083 - INFO - Starting solver with random_seed: 659891735, max_time_in_seconds: 0.5
# 2024-08-17 15:20:36,597 - INFO - Solver found a solution with objective value: 132645.0
# 2024-08-17 15:20:36,598 - INFO - Starting solver with random_seed: 679148270, max_time_in_seconds: 0.5
# 2024-08-17 15:20:37,110 - INFO - Solver found a solution with objective value: 128983.0
# 2024-08-17 15:20:37,110 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:37,111] Trial 4 finished with value: 128983.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:37,114 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:37,115 - INFO - Returning cached result.
# 2024-08-17 15:20:37,115 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 7, 'repair_hint': True, 'use_lb_relax_lns': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:37,116 - INFO - Starting solver with random_seed: 734507711, max_time_in_seconds: 0.5
# 2024-08-17 15:20:37,629 - INFO - Solver found a solution with objective value: 132349.0
# 2024-08-17 15:20:37,629 - INFO - Starting solver with random_seed: 810843644, max_time_in_seconds: 0.5
# 2024-08-17 15:20:38,141 - INFO - Solver found a solution with objective value: 131910.0
# 2024-08-17 15:20:38,142 - INFO - Starting solver with random_seed: 1088739445, max_time_in_seconds: 0.5
# 2024-08-17 15:20:38,657 - INFO - Solver found a solution with objective value: 131834.0
# 2024-08-17 15:20:38,658 - INFO - Starting solver with random_seed: 1284704222, max_time_in_seconds: 0.5
# 2024-08-17 15:20:39,173 - INFO - Solver found a solution with objective value: 131834.0
# 2024-08-17 15:20:39,173 - INFO - Starting solver with random_seed: 515865763, max_time_in_seconds: 0.5
# 2024-08-17 15:20:39,689 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:39,690 - INFO - Starting solver with random_seed: 254252069, max_time_in_seconds: 0.5
# 2024-08-17 15:20:40,204 - INFO - Solver found a solution with objective value: 132525.0
# 2024-08-17 15:20:40,205 - INFO - Starting solver with random_seed: 1053735602, max_time_in_seconds: 0.5
# 2024-08-17 15:20:40,719 - INFO - Solver found a solution with objective value: 129012.0
# 2024-08-17 15:20:40,720 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:40,721] Trial 5 finished with value: 129012.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 7, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:40,724 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:40,724 - INFO - Returning cached result.
# 2024-08-17 15:20:40,724 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['fixed', 'reduced_costs', 'quick_restart'], 'search_branching': 2, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:40,725 - INFO - Starting solver with random_seed: 210436740, max_time_in_seconds: 0.5
# 2024-08-17 15:20:41,236 - INFO - Solver found a solution with objective value: 75375.0
# 2024-08-17 15:20:41,237 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:41,238] Trial 6 finished with value: 75375.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:41,241 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:41,242 - INFO - Returning cached result.
# 2024-08-17 15:20:41,242 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 3, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:41,242 - INFO - Starting solver with random_seed: 1414822750, max_time_in_seconds: 0.5
# 2024-08-17 15:20:41,752 - INFO - Solver found a solution with objective value: 78830.0
# 2024-08-17 15:20:41,753 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:41,754] Trial 7 finished with value: 78830.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 3, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:41,757 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:41,757 - INFO - Returning cached result.
# 2024-08-17 15:20:41,758 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 10, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'lb_tree_search'], 'search_branching': 8, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 0}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:41,758 - INFO - Starting solver with random_seed: 1341106792, max_time_in_seconds: 0.5
# 2024-08-17 15:20:42,262 - INFO - Solver found a solution with objective value: 132073.0
# 2024-08-17 15:20:42,263 - INFO - Starting solver with random_seed: 474157978, max_time_in_seconds: 0.5
# 2024-08-17 15:20:42,774 - INFO - Solver found a solution with objective value: 79185.0
# 2024-08-17 15:20:42,774 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:42,775] Trial 8 finished with value: 79185.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:42,778 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:42,778 - INFO - Returning cached result.
# 2024-08-17 15:20:42,779 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:42,779 - INFO - Starting solver with random_seed: 134317332, max_time_in_seconds: 0.5
# 2024-08-17 15:20:43,290 - INFO - Solver found a solution with objective value: 130323.0
# 2024-08-17 15:20:43,290 - INFO - Starting solver with random_seed: 1123901407, max_time_in_seconds: 0.5
# 2024-08-17 15:20:43,801 - INFO - Solver found a solution with objective value: 132294.0
# 2024-08-17 15:20:43,802 - INFO - Starting solver with random_seed: 1202730739, max_time_in_seconds: 0.5
# 2024-08-17 15:20:44,313 - INFO - Solver found a solution with objective value: 132290.0
# 2024-08-17 15:20:44,314 - INFO - Starting solver with random_seed: 32374379, max_time_in_seconds: 0.5
# 2024-08-17 15:20:44,824 - INFO - Solver found a solution with objective value: 131311.0
# 2024-08-17 15:20:44,825 - INFO - Starting solver with random_seed: 1160658102, max_time_in_seconds: 0.5
# 2024-08-17 15:20:45,336 - INFO - Solver found a solution with objective value: 132115.0
# 2024-08-17 15:20:45,337 - INFO - Starting solver with random_seed: 1321101511, max_time_in_seconds: 0.5
# 2024-08-17 15:20:45,848 - INFO - Solver found a solution with objective value: 132294.0
# 2024-08-17 15:20:45,848 - INFO - Starting solver with random_seed: 1755939509, max_time_in_seconds: 0.5
# 2024-08-17 15:20:46,361 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:46,361 - INFO - Starting solver with random_seed: 203504172, max_time_in_seconds: 0.5
# 2024-08-17 15:20:46,869 - INFO - Solver found a solution with objective value: 132245.0
# 2024-08-17 15:20:46,870 - INFO - Starting solver with random_seed: 2057066257, max_time_in_seconds: 0.5
# 2024-08-17 15:20:47,379 - INFO - Solver found a solution with objective value: 131634.0
# 2024-08-17 15:20:47,380 - INFO - Starting solver with random_seed: 376728550, max_time_in_seconds: 0.5
# 2024-08-17 15:20:47,889 - INFO - Solver found a solution with objective value: 129097.0
# 2024-08-17 15:20:47,890 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:47,891] Trial 9 finished with value: 129097.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 0}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:47,935 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:47,935 - INFO - Returning cached result.
# 2024-08-17 15:20:47,935 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'ignore_subsolvers': ['quick_restart_no_lp'], 'search_branching': 6, 'use_lns_only': True, 'optimize_with_core': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:47,936 - INFO - Starting solver with random_seed: 1899991519, max_time_in_seconds: 0.5
# 2024-08-17 15:20:48,446 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-17 15:20:48,447 - INFO - Starting solver with random_seed: 1649139571, max_time_in_seconds: 0.5
# 2024-08-17 15:20:48,957 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-17 15:20:48,958 - INFO - Starting solver with random_seed: 323555181, max_time_in_seconds: 0.5
# 2024-08-17 15:20:49,468 - INFO - Solver found a solution with objective value: 128438.0
# 2024-08-17 15:20:49,468 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:49,469] Trial 10 finished with value: 128438.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 6, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:49,513 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:49,514 - INFO - Returning cached result.
# 2024-08-17 15:20:49,514 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp'], 'repair_hint': True, 'use_lns_only': True, 'optimize_with_core': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 128}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:49,514 - INFO - Starting solver with random_seed: 322990557, max_time_in_seconds: 0.5
# 2024-08-17 15:20:50,024 - INFO - Solver found a solution with objective value: 132365.0
# 2024-08-17 15:20:50,025 - INFO - Starting solver with random_seed: 1196891275, max_time_in_seconds: 0.5
# 2024-08-17 15:20:50,535 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-17 15:20:50,535 - INFO - Starting solver with random_seed: 1605270232, max_time_in_seconds: 0.5
# 2024-08-17 15:20:51,046 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:51,046 - INFO - Starting solver with random_seed: 1476842937, max_time_in_seconds: 0.5
# 2024-08-17 15:20:51,557 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-17 15:20:51,557 - INFO - Starting solver with random_seed: 1701763074, max_time_in_seconds: 0.5
# 2024-08-17 15:20:52,068 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-17 15:20:52,069 - INFO - Starting solver with random_seed: 925808772, max_time_in_seconds: 0.5
# 2024-08-17 15:20:52,579 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-17 15:20:52,580 - INFO - Starting solver with random_seed: 1477588651, max_time_in_seconds: 0.5
# 2024-08-17 15:20:53,090 - INFO - Solver found a solution with objective value: 132275.0
# 2024-08-17 15:20:53,091 - INFO - Starting solver with random_seed: 1724009786, max_time_in_seconds: 0.5
# 2024-08-17 15:20:53,600 - INFO - Solver found a solution with objective value: 132215.0
# 2024-08-17 15:20:53,601 - INFO - Starting solver with random_seed: 2119103648, max_time_in_seconds: 0.5
# 2024-08-17 15:20:54,112 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:20:54,112 - INFO - Starting solver with random_seed: 1043224205, max_time_in_seconds: 0.5
# 2024-08-17 15:20:54,622 - INFO - Solver found a solution with objective value: 127933.0
# 2024-08-17 15:20:54,623 - INFO - Returning knockout result.
# [I 2024-08-17 15:20:54,624] Trial 11 finished with value: 127933.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 129976.0.
# 2024-08-17 15:20:54,667 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-17 15:20:54,668 - INFO - Returning cached result.
# 2024-08-17 15:20:54,668 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed'], 'search_branching': 2, 'repair_hint': True, 'use_lns_only': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'diversify_lns_params': True, 'polish_lp_solution': True}, num_runs: 10, knockout_score: 130014.3
# 2024-08-17 15:20:54,668 - INFO - Starting solver with random_seed: 861319899, max_time_in_seconds: 0.5
# 2024-08-17 15:20:55,179 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-17 15:20:55,179 - INFO - Starting solver with random_seed: 1252776718, max_time_in_seconds: 0.5
# 2024-08-17 15:20:55,691 - INFO - Solver found a solution with objective value: 132120.0
# ...
# 2024-08-17 15:26:35,827 - INFO - Starting solver with random_seed: 874499510, max_time_in_seconds: 0.5
# 2024-08-17 15:26:36,342 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:36,343 - INFO - Starting solver with random_seed: 423115988, max_time_in_seconds: 0.5
# 2024-08-17 15:26:36,857 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:36,857 - INFO - Starting solver with random_seed: 1910639023, max_time_in_seconds: 0.5
# 2024-08-17 15:26:37,371 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:37,372 - INFO - Starting solver with random_seed: 231383845, max_time_in_seconds: 0.5
# 2024-08-17 15:26:37,887 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:37,888 - INFO - Starting solver with random_seed: 184104797, max_time_in_seconds: 0.5
# 2024-08-17 15:26:38,403 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:38,404 - INFO - Starting solver with random_seed: 1984551110, max_time_in_seconds: 0.5
# 2024-08-17 15:26:38,918 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:38,919 - INFO - Starting solver with random_seed: 658087466, max_time_in_seconds: 0.5
# 2024-08-17 15:26:39,438 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:39,439 - INFO - Starting solver with random_seed: 1991090137, max_time_in_seconds: 0.5
# 2024-08-17 15:26:39,954 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:39,955 - INFO - Starting solver with random_seed: 1844809073, max_time_in_seconds: 0.5
# 2024-08-17 15:26:40,471 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:40,472 - INFO - Starting solver with random_seed: 50931691, max_time_in_seconds: 0.5
# 2024-08-17 15:26:40,986 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:40,987 - INFO - Starting solver with random_seed: 523117475, max_time_in_seconds: 0.5
# 2024-08-17 15:26:41,501 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:41,502 - INFO - Starting solver with random_seed: 41121998, max_time_in_seconds: 0.5
# 2024-08-17 15:26:42,016 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:42,017 - INFO - Starting solver with random_seed: 1285235697, max_time_in_seconds: 0.5
# 2024-08-17 15:26:42,530 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:42,531 - INFO - Starting solver with random_seed: 1898807299, max_time_in_seconds: 0.5
# 2024-08-17 15:26:43,045 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:43,045 - INFO - Starting solver with random_seed: 1911821270, max_time_in_seconds: 0.5
# 2024-08-17 15:26:43,558 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:43,559 - INFO - Starting solver with random_seed: 407486089, max_time_in_seconds: 0.5
# 2024-08-17 15:26:44,075 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:44,075 - INFO - Starting solver with random_seed: 1774054289, max_time_in_seconds: 0.5
# 2024-08-17 15:26:44,590 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:44,590 - INFO - Starting solver with random_seed: 1342092061, max_time_in_seconds: 0.5
# 2024-08-17 15:26:45,105 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:45,105 - INFO - Starting solver with random_seed: 1340979767, max_time_in_seconds: 0.5
# 2024-08-17 15:26:45,618 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:45,619 - INFO - Starting solver with random_seed: 1465460710, max_time_in_seconds: 0.5
# 2024-08-17 15:26:46,134 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:46,135 - INFO - Starting solver with random_seed: 241657324, max_time_in_seconds: 0.5
# 2024-08-17 15:26:46,648 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:46,649 - INFO - Starting solver with random_seed: 1566189678, max_time_in_seconds: 0.5
# 2024-08-17 15:26:47,164 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:47,165 - INFO - Starting solver with random_seed: 30546921, max_time_in_seconds: 0.5
# 2024-08-17 15:26:47,681 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:47,681 - INFO - Starting solver with random_seed: 584304891, max_time_in_seconds: 0.5
# 2024-08-17 15:26:48,196 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:48,197 - INFO - Starting solver with random_seed: 475609145, max_time_in_seconds: 0.5
# 2024-08-17 15:26:48,711 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:48,712 - INFO - Starting solver with random_seed: 1695809362, max_time_in_seconds: 0.5
# 2024-08-17 15:26:49,230 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:49,231 - INFO - Starting solver with random_seed: 1997029771, max_time_in_seconds: 0.5
# 2024-08-17 15:26:49,760 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:49,761 - INFO - Starting solver with random_seed: 934505437, max_time_in_seconds: 0.5
# 2024-08-17 15:26:50,287 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:50,287 - INFO - Starting solver with random_seed: 1924102716, max_time_in_seconds: 0.5
# 2024-08-17 15:26:50,804 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:50,805 - INFO - Starting solver with random_seed: 832169083, max_time_in_seconds: 0.5
# 2024-08-17 15:26:51,322 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:51,322 - INFO - Starting solver with random_seed: 386785879, max_time_in_seconds: 0.5
# 2024-08-17 15:26:51,852 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:51,852 - INFO - Starting solver with random_seed: 934927641, max_time_in_seconds: 0.5
# 2024-08-17 15:26:52,365 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:52,366 - INFO - Starting solver with random_seed: 489534205, max_time_in_seconds: 0.5
# 2024-08-17 15:26:52,881 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:52,882 - INFO - Starting solver with random_seed: 723979299, max_time_in_seconds: 0.5
# 2024-08-17 15:26:53,394 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:53,395 - INFO - Starting solver with random_seed: 528151342, max_time_in_seconds: 0.5
# 2024-08-17 15:26:53,912 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:53,913 - INFO - Starting solver with random_seed: 1688711403, max_time_in_seconds: 0.5
# 2024-08-17 15:26:54,437 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:54,438 - INFO - Starting solver with random_seed: 1181638832, max_time_in_seconds: 0.5
# 2024-08-17 15:26:54,951 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-17 15:26:54,952 - INFO - Evaluation completed and result cached.
# 2024-08-17 15:26:54,952 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter                     ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ preferred_variable_order      │   1   │    29.58%    │       0       │
# │ 2   │ binary_minimization_algorithm │   3   │    6.27%     │       1       │
# │ 3   │ max_presolve_iterations       │   2   │    2.87%     │       3       │
# │ 4   │ search_branching              │   7   │    36.57%    │       0       │
# │ 5   │ fp_rounding                   │   1   │    4.75%     │       2       │
# │ 6   │ linearization_level           │   0   │    4.30%     │       1       │
# │ 7   │ cut_level                     │   0   │    15.67%    │       1       │
# └─────┴───────────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. preferred_variable_order Sets the initial order in which variables are selected during the search. The options
# are:
#
#  • 0 (IN_ORDER): Select variables in the order they appear in the problem definition.
#  • 1 (IN_REVERSE_ORDER): Select variables in reverse order.
#  • 2 (IN_RANDOM_ORDER): Select variables randomly.
#
# The order of variable selection can have a significant impact on the efficiency of the search, though, this is only
# the initial order and the solver will actually try to learn a better order. The search will restart frequently such
# that this initial order should only influence the beginning of the search.
#
# 2. binary_minimization_algorithm Specifies the algorithm used for binary clause minimization during conflict
# analysis. The options are:
#
#  • 0 NO_BINARY_MINIMIZATION.
#  • 1 BINARY_MINIMIZATION_FIRST
#  • 2 BINARY_MINIMIZATION_WITH_REACHABILITY
#  • 3 EXPERIMENTAL_BINARY_MINIMIZATION
#  • 4 BINARY_MINIMIZATION_FIRST_WITH_TRANSITIVE_REDUCTION
#
# 3. max_presolve_iterations Sets the maximum number of iterations that the presolve phase will execute. Presolve
# simplifies the problem by eliminating redundant constraints and variables before the main search begins. More
# iterations can lead to a more simplified problem but at the cost of longer presolve times.
#
# 4. search_branching Defines the branching strategy the solver uses to navigate the search tree. The options are:
#
#  • 0 (AUTOMATIC_SEARCH): The solver automatically selects the most appropriate strategy.
#  • 1 (FIXED_SEARCH): Follows a fixed variable order, as specified by the user or the problem model.
#  • 2 (PORTFOLIO_SEARCH): Uses a combination of multiple strategies to explore the search space.
#  • 3 (LP_SEARCH): Branches based on the LP relaxation of the problem, leveraging the reduced costs of variables.
#  • 4 (PSEUDO_COST_SEARCH): Branches using pseudo-costs, which are estimates of the impact of branching decisions
#    based on past experiences.
#  • 5 (PORTFOLIO_WITH_QUICK_RESTART_SEARCH): Quickly explores different heuristics with low conflict limits, aiming
#    to find a good initial solution.
#  • 6 (HINT_SEARCH): Prioritizes decisions based on hints provided by the user or the problem model.
#  • 7 (PARTIAL_FIXED_SEARCH): Begins with a fixed strategy, then switches to automatic search for the remaining
#    decisions.
#  • 8 (RANDOMIZED_SEARCH): Introduces randomization into branching decisions to diversify the search.
#
# 5. fp_rounding Specifies the rounding method used in the feasibility pump, a heuristic for quickly finding integer
# feasible solutions. The options are:
#
#  • 0 (NEAREST_INTEGER): Rounds values to the nearest integer.
#  • 1 (LOCK_BASED): Rounds based on the direction with fewer constraints ("locks").
#  • 2 (PROPAGATION_ASSISTED): Rounds with consideration of bound propagation, improving solution quality by
#    integrating more logical deductions.
#  • 3 (ACTIVE_LOCK_BASED): Similar to lock-based rounding, but focuses on active constraints from the last LP solve.
#
# 6. linearization_level Controls the extent to which integer constraints are transformed into Boolean variables for
# LP relaxation. The levels are:
#
#  • 0: No linearization, the solver does not use LP relaxation.
#  • 1: Basic linearization, including linear constraints and fully encoded Boolean variables.
#  • 2: More comprehensive linearization, including Boolean constraints.
#
# Increasing the linearization level can tighten the relaxation, but it also increases the complexity of the model.
#
# 7. cut_level Sets the level of effort the solver will invest in generating cutting planes, which are linear
# constraints added to remove infeasible regions. Properly applied, cuts can significantly reduce the search space
# and help the solver find an optimal solution more quickly.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                                    ┃      Mean ┃      Min ┃      Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━┩
# │ Objective [MAX] with Default Parameters   │ 132081.58 │ 130268.0 │ 132805.0 │       40 │
# │ Objective [MAX] with Optimized Parameters │  132805.0 │ 132805.0 │ 132805.0 │       40 │
# └───────────────────────────────────────────┴───────────┴──────────┴──────────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-17 15:26:54,974 - INFO - Hyperparameter tuning completed.
# 2024-08-17 15:26:54,975 - INFO - Tuning for quality within time limit completed.
