# %%
from cpsat_autotune import (
    tune_for_quality_within_timelimit,
    import_model,
    tune_time_to_optimal,
)

# %%
model = import_model("models/model_proto_-1368620059351071685.pb")

# %%
best = tune_time_to_optimal(
    model,
    max_time_in_seconds=3,  # Enter a time limit slightly above what the solver with default parameters needs
    n_samples_for_trial=5,  # Number of samples for each trial
    n_samples_for_verification=20,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-16 18:30:02,246 - INFO - Starting tuning for time to optimal.
# 2024-08-16 18:30:02,247 - INFO - Initialized Metric with direction: minimize
# 2024-08-16 18:30:02,247 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-16 18:30:02,248 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:30:02,248 - INFO - Starting solver with random_seed: 576924853, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:03,938 - INFO - Solver completed in 1.689252 seconds with status: 4
# 2024-08-16 18:30:03,938 - INFO - Starting solver with random_seed: 1864003571, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:05,350 - INFO - Solver completed in 1.41109 seconds with status: 4
# 2024-08-16 18:30:05,350 - INFO - Starting solver with random_seed: 125659648, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:07,009 - INFO - Solver completed in 1.658594 seconds with status: 4
# 2024-08-16 18:30:07,010 - INFO - Starting solver with random_seed: 419463849, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:08,668 - INFO - Solver completed in 1.658229 seconds with status: 4
# 2024-08-16 18:30:08,669 - INFO - Starting solver with random_seed: 1318347122, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:10,532 - INFO - Solver completed in 1.862863 seconds with status: 4
# 2024-08-16 18:30:10,533 - INFO - Starting solver with random_seed: 36568266, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:12,272 - INFO - Solver completed in 1.738413 seconds with status: 4
# 2024-08-16 18:30:12,272 - INFO - Starting solver with random_seed: 890876735, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:13,879 - INFO - Solver completed in 1.606264 seconds with status: 4
# 2024-08-16 18:30:13,879 - INFO - Starting solver with random_seed: 2046358531, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:15,431 - INFO - Solver completed in 1.550987 seconds with status: 4
# 2024-08-16 18:30:15,431 - INFO - Starting solver with random_seed: 528781919, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:16,774 - INFO - Solver completed in 1.342747 seconds with status: 4
# 2024-08-16 18:30:16,775 - INFO - Starting solver with random_seed: 507759362, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:18,982 - INFO - Solver completed in 2.206537 seconds with status: 4
# 2024-08-16 18:30:18,983 - INFO - Starting solver with random_seed: 1807947279, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:20,631 - INFO - Solver completed in 1.648512 seconds with status: 4
# 2024-08-16 18:30:20,632 - INFO - Starting solver with random_seed: 1267747835, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:22,356 - INFO - Solver completed in 1.723301 seconds with status: 4
# 2024-08-16 18:30:22,356 - INFO - Starting solver with random_seed: 918737904, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:23,862 - INFO - Solver completed in 1.50512 seconds with status: 4
# 2024-08-16 18:30:23,862 - INFO - Starting solver with random_seed: 987948561, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:25,744 - INFO - Solver completed in 1.881762 seconds with status: 4
# 2024-08-16 18:30:25,745 - INFO - Starting solver with random_seed: 1103639136, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:27,729 - INFO - Solver completed in 1.983675 seconds with status: 4
# 2024-08-16 18:30:27,730 - INFO - Starting solver with random_seed: 159682331, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:29,401 - INFO - Solver completed in 1.671295 seconds with status: 4
# 2024-08-16 18:30:29,402 - INFO - Starting solver with random_seed: 953968676, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:30,734 - INFO - Solver completed in 1.332305 seconds with status: 4
# 2024-08-16 18:30:30,735 - INFO - Starting solver with random_seed: 1941257885, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:32,886 - INFO - Solver completed in 2.150446 seconds with status: 4
# 2024-08-16 18:30:32,886 - INFO - Starting solver with random_seed: 1974787239, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:34,243 - INFO - Solver completed in 1.356149 seconds with status: 4
# 2024-08-16 18:30:34,244 - INFO - Starting solver with random_seed: 1755988783, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:35,862 - INFO - Solver completed in 1.617964 seconds with status: 4
# 2024-08-16 18:30:35,863 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:30:35,863 - INFO - Baseline evaluation completed: min=1.332305, mean=1.67977525, max=2.206537
# [I 2024-08-16 18:30:35,864] A new study created in memory with name: no-name-fa04df14-ab5a-4bbc-b227-ebe2d6c2a14a
# 2024-08-16 18:30:35,864 - INFO - Starting Optuna optimization.
# 2024-08-16 18:30:35,866 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:30:35,866 - INFO - Returning cached result.
# 2024-08-16 18:30:35,867 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:30:35,867 - INFO - Starting solver with random_seed: 1207064454, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:37,714 - INFO - Solver completed in 1.84683 seconds with status: 4
# 2024-08-16 18:30:37,715 - INFO - Starting solver with random_seed: 935146145, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:39,132 - INFO - Solver completed in 1.416963 seconds with status: 4
# 2024-08-16 18:30:39,133 - INFO - Starting solver with random_seed: 967226042, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:41,035 - INFO - Solver completed in 1.901618 seconds with status: 4
# 2024-08-16 18:30:41,036 - INFO - Starting solver with random_seed: 1993745343, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:43,021 - INFO - Solver completed in 1.984576 seconds with status: 4
# 2024-08-16 18:30:43,021 - INFO - Starting solver with random_seed: 680769854, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:44,380 - INFO - Solver completed in 1.358598 seconds with status: 4
# 2024-08-16 18:30:44,381 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:30:44,382] Trial 0 finished with value: 1.701717 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 1.701717.
# 2024-08-16 18:30:44,385 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:30:44,386 - INFO - Returning cached result.
# 2024-08-16 18:30:44,386 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'probing'], 'search_branching': 8, 'repair_hint': True, 'use_lb_relax_lns': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:30:44,386 - INFO - Starting solver with random_seed: 1257016075, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:46,468 - INFO - Solver completed in 2.081324 seconds with status: 4
# 2024-08-16 18:30:46,469 - INFO - Starting solver with random_seed: 870227910, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:48,443 - INFO - Solver completed in 1.973767 seconds with status: 4
# 2024-08-16 18:30:48,443 - INFO - Starting solver with random_seed: 1760021525, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:50,584 - INFO - Solver completed in 2.140781 seconds with status: 4
# 2024-08-16 18:30:50,585 - INFO - Starting solver with random_seed: 742266814, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:53,607 - INFO - Solver completed in 3.02143 seconds with status: 2
# 2024-08-16 18:30:53,607 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 18:30:53,608 - INFO - Returning knockout result.
# [I 2024-08-16 18:30:53,609] Trial 1 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 8, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 1.701717.
# 2024-08-16 18:30:53,612 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:30:53,612 - INFO - Returning cached result.
# 2024-08-16 18:30:53,612 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'quick_restart'], 'search_branching': 4, 'optimize_with_core': True, 'fp_rounding': 0, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:30:53,613 - INFO - Starting solver with random_seed: 2062117820, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:56,485 - INFO - Solver completed in 2.872114 seconds with status: 4
# 2024-08-16 18:30:56,486 - INFO - Returning knockout result.
# [I 2024-08-16 18:30:56,487] Trial 2 finished with value: 2.872114 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 0 with value: 1.701717.
# 2024-08-16 18:30:56,490 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:30:56,490 - INFO - Returning cached result.
# 2024-08-16 18:30:56,491 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs'], 'search_branching': 5, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 0, 'add_objective_cut': True, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:30:56,491 - INFO - Starting solver with random_seed: 1183166304, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:58,219 - INFO - Solver completed in 1.727766 seconds with status: 4
# 2024-08-16 18:30:58,220 - INFO - Starting solver with random_seed: 1520262729, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:30:59,163 - INFO - Solver completed in 0.943314 seconds with status: 4
# 2024-08-16 18:30:59,164 - INFO - Starting solver with random_seed: 1995500788, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:00,650 - INFO - Solver completed in 1.486204 seconds with status: 4
# 2024-08-16 18:31:00,651 - INFO - Starting solver with random_seed: 78397903, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:01,666 - INFO - Solver completed in 1.015267 seconds with status: 4
# 2024-08-16 18:31:01,667 - INFO - Starting solver with random_seed: 367497512, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:03,306 - INFO - Solver completed in 1.637887 seconds with status: 4
# 2024-08-16 18:31:03,306 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:31:03,308] Trial 3 finished with value: 1.3620876 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 5, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:03,311 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:03,311 - INFO - Returning cached result.
# 2024-08-16 18:31:03,311 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['no_lp', 'max_lp', 'pseudo_costs', 'quick_restart_no_lp'], 'search_branching': 1, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 2, 'add_objective_cut': True, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:03,311 - INFO - Starting solver with random_seed: 1963151676, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:06,329 - INFO - Solver completed in 3.017639 seconds with status: 2
# 2024-08-16 18:31:06,330 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 18:31:06,330 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:06,331] Trial 4 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 1, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:06,337 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:06,337 - INFO - Returning cached result.
# 2024-08-16 18:31:06,338 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 5, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:06,338 - INFO - Starting solver with random_seed: 11001876, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:09,367 - INFO - Solver completed in 3.028693 seconds with status: 2
# 2024-08-16 18:31:09,367 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 18:31:09,368 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:09,368] Trial 5 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 5, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 0}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:09,371 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:09,372 - INFO - Returning cached result.
# 2024-08-16 18:31:09,372 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 2, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:09,373 - INFO - Starting solver with random_seed: 1811629601, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:12,388 - INFO - Solver completed in 3.015546 seconds with status: 2
# 2024-08-16 18:31:12,389 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 18:31:12,389 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:12,390] Trial 6 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 2, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:12,393 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:12,394 - INFO - Returning cached result.
# 2024-08-16 18:31:12,394 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 5, 'repair_hint': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:12,394 - INFO - Starting solver with random_seed: 5507455, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:15,406 - INFO - Solver completed in 3.011375 seconds with status: 2
# 2024-08-16 18:31:15,406 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 18:31:15,407 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:15,408] Trial 7 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 5, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:15,411 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:15,412 - INFO - Returning cached result.
# 2024-08-16 18:31:15,412 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp'], 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:15,412 - INFO - Starting solver with random_seed: 1666420968, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:16,963 - INFO - Solver completed in 1.550586 seconds with status: 4
# 2024-08-16 18:31:16,964 - INFO - Starting solver with random_seed: 1497880972, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:18,710 - INFO - Solver completed in 1.745938 seconds with status: 4
# 2024-08-16 18:31:18,711 - INFO - Starting solver with random_seed: 1165059697, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:19,768 - INFO - Solver completed in 1.057194 seconds with status: 4
# 2024-08-16 18:31:19,769 - INFO - Starting solver with random_seed: 1539188426, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:22,153 - INFO - Solver completed in 2.384111 seconds with status: 4
# 2024-08-16 18:31:22,154 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:22,155] Trial 8 finished with value: 2.384111 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:22,160 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:22,160 - INFO - Returning cached result.
# 2024-08-16 18:31:22,160 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:22,161 - INFO - Starting solver with random_seed: 989971123, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:25,177 - INFO - Solver completed in 3.016024 seconds with status: 2
# 2024-08-16 18:31:25,178 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 18:31:25,178 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:25,179] Trial 9 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:25,221 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:25,222 - INFO - Returning cached result.
# 2024-08-16 18:31:25,222 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'reduced_costs', 'lb_tree_search'], 'search_branching': 6, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'linearization_level': 0, 'add_objective_cut': True}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:25,222 - INFO - Starting solver with random_seed: 1209694651, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:28,236 - INFO - Solver completed in 3.013493 seconds with status: 2
# 2024-08-16 18:31:28,237 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 18:31:28,237 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:28,239] Trial 10 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 6, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:28,282 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:28,283 - INFO - Returning cached result.
# 2024-08-16 18:31:28,283 - INFO - Evaluating with params: {'presolve_bve_threshold': 100, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': [], 'feasibility_jump_linearization_level': 1}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:28,284 - INFO - Starting solver with random_seed: 2110373880, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:30,727 - INFO - Solver completed in 2.443247 seconds with status: 4
# 2024-08-16 18:31:30,728 - INFO - Returning knockout result.
# [I 2024-08-16 18:31:30,729] Trial 11 finished with value: 2.443247 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 3 with value: 1.3620876.
# 2024-08-16 18:31:30,774 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:30,774 - INFO - Returning cached result.
# 2024-08-16 18:31:30,774 - INFO - Evaluating with params: {'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'fp_rounding': 1, 'add_objective_cut': True}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:30,775 - INFO - Starting solver with random_seed: 1412470416, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:31,409 - INFO - Solver completed in 0.633893 seconds with status: 4
# 2024-08-16 18:31:31,409 - INFO - Starting solver with random_seed: 1422500971, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:32,438 - INFO - Solver completed in 1.028176 seconds with status: 4
# 2024-08-16 18:31:32,438 - INFO - Starting solver with random_seed: 42596540, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:33,345 - INFO - Solver completed in 0.906083 seconds with status: 4
# 2024-08-16 18:31:33,345 - INFO - Starting solver with random_seed: 2085818360, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:33,941 - INFO - Solver completed in 0.59531 seconds with status: 4
# 2024-08-16 18:31:33,942 - INFO - Starting solver with random_seed: 97735560, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:34,880 - INFO - Solver completed in 0.938345 seconds with status: 4
# 2024-08-16 18:31:34,881 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:31:34,882] Trial 12 finished with value: 0.8203614 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 12 with value: 0.8203614.
# 2024-08-16 18:31:34,932 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:34,932 - INFO - Returning cached result.
# 2024-08-16 18:31:34,932 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': [], 'search_branching': 3, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'linearization_level': 0, 'add_objective_cut': True, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:34,933 - INFO - Starting solver with random_seed: 571613163, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:35,594 - INFO - Solver completed in 0.660525 seconds with status: 4
# 2024-08-16 18:31:35,594 - INFO - Starting solver with random_seed: 847726123, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:36,569 - INFO - Solver completed in 0.974242 seconds with status: 4
# 2024-08-16 18:31:36,569 - INFO - Starting solver with random_seed: 629252740, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:37,635 - INFO - Solver completed in 1.065679 seconds with status: 4
# 2024-08-16 18:31:37,636 - INFO - Starting solver with random_seed: 854068795, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:38,331 - INFO - Solver completed in 0.694541 seconds with status: 4
# 2024-08-16 18:31:38,332 - INFO - Starting solver with random_seed: 958100446, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:39,528 - INFO - Solver completed in 1.196251 seconds with status: 4
# 2024-08-16 18:31:39,529 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:31:39,530] Trial 13 finished with value: 0.9182475999999999 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 12 with value: 0.8203614.
# 2024-08-16 18:31:39,581 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:39,582 - INFO - Returning cached result.
# 2024-08-16 18:31:39,582 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['default_lp', 'lb_tree_search'], 'search_branching': 3, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'add_objective_cut': True, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 2.2939602
# 2024-08-16 18:31:39,582 - INFO - Starting solver with random_seed: 1735740639, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:40,335 - INFO - Solver completed in 0.752671 seconds with status: 4
# 2024-08-16 18:31:40,336 - INFO - Starting solver with random_seed: 92393937, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:41,454 - INFO - Solver completed in 1.118099 seconds with status: 4
# 2024-08-16 18:31:41,455 - INFO - Starting solver with random_seed: 149293442, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:42,390 - INFO - Solver completed in 0.934637 seconds with status: 4
# 2024-08-16 18:31:42,391 - INFO - Starting solver with random_seed: 139389812, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:43,579 - INFO - Solver completed in 1.187717 seconds with status: 4
# 2024-08-16 18:31:43,579 - INFO - Starting solver with random_seed: 1455199489, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:31:44,804 - INFO - Solver completed in 1.224192 seconds with status: 4
# 2024-08-16 18:31:44,805 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:31:44,806] Trial 14 finished with value: 1.0434632000000001 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 12 with value: 0.8203614.
# 2024-08-16 18:31:44,867 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:31:44,868 - INFO - Returning cached result.
# ...
# 2024-08-16 18:34:43,488 - INFO - Starting solver with random_seed: 1709483505, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:44,064 - INFO - Solver completed in 0.575867 seconds with status: 4
# 2024-08-16 18:34:44,065 - INFO - Starting solver with random_seed: 2054904419, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:44,746 - INFO - Solver completed in 0.68062 seconds with status: 4
# 2024-08-16 18:34:44,747 - INFO - Starting solver with random_seed: 1555949704, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:45,468 - INFO - Solver completed in 0.721417 seconds with status: 4
# 2024-08-16 18:34:45,470 - INFO - Starting solver with random_seed: 1552837380, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:46,141 - INFO - Solver completed in 0.671004 seconds with status: 4
# 2024-08-16 18:34:46,142 - INFO - Starting solver with random_seed: 2141742007, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:46,956 - INFO - Solver completed in 0.813943 seconds with status: 4
# 2024-08-16 18:34:46,957 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:34:46,957 - INFO - Parameter 'add_objective_cut' can be dropped from the optimized parameters.
# 2024-08-16 18:34:46,958 - INFO - Evaluating resetting parameter 'cut_level' to default...
# 2024-08-16 18:34:46,958 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': [], 'search_branching': 7, 'fp_rounding': 1, 'add_objective_cut': True, 'symmetry_level': 0}, num_runs: 5, knockout_score: None
# 2024-08-16 18:34:46,958 - INFO - Starting solver with random_seed: 975468841, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:48,180 - INFO - Solver completed in 1.22117 seconds with status: 4
# 2024-08-16 18:34:48,181 - INFO - Starting solver with random_seed: 1726717520, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:49,106 - INFO - Solver completed in 0.925565 seconds with status: 4
# 2024-08-16 18:34:49,107 - INFO - Starting solver with random_seed: 1075237293, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:49,933 - INFO - Solver completed in 0.825411 seconds with status: 4
# 2024-08-16 18:34:49,934 - INFO - Starting solver with random_seed: 1910606527, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:50,927 - INFO - Solver completed in 0.993624 seconds with status: 4
# 2024-08-16 18:34:50,928 - INFO - Starting solver with random_seed: 2090301247, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:51,815 - INFO - Solver completed in 0.886186 seconds with status: 4
# 2024-08-16 18:34:51,816 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:34:51,816 - INFO - Parameter 'cut_level' is essential for performance.
# 2024-08-16 18:34:51,816 - INFO - Evaluating resetting parameter 'symmetry_level' to default...
# 2024-08-16 18:34:51,817 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': [], 'search_branching': 7, 'fp_rounding': 1, 'add_objective_cut': True, 'cut_level': 0}, num_runs: 5, knockout_score: None
# 2024-08-16 18:34:51,817 - INFO - Starting solver with random_seed: 1030767392, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:52,360 - INFO - Solver completed in 0.543302 seconds with status: 4
# 2024-08-16 18:34:52,361 - INFO - Starting solver with random_seed: 669856692, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:53,314 - INFO - Solver completed in 0.95287 seconds with status: 4
# 2024-08-16 18:34:53,315 - INFO - Starting solver with random_seed: 964302019, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:54,024 - INFO - Solver completed in 0.707931 seconds with status: 4
# 2024-08-16 18:34:54,024 - INFO - Starting solver with random_seed: 1760776891, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:54,735 - INFO - Solver completed in 0.710578 seconds with status: 4
# 2024-08-16 18:34:54,736 - INFO - Starting solver with random_seed: 1058212448, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:55,272 - INFO - Solver completed in 0.535504 seconds with status: 4
# 2024-08-16 18:34:55,272 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:34:55,273 - INFO - Parameter 'symmetry_level' can be dropped from the optimized parameters.
# 2024-08-16 18:34:55,273 - INFO - Evaluating with params: {'binary_minimization_algorithm': 3, 'cp_model_probing_level': 1, 'search_branching': 7, 'cut_level': 0}, num_runs: 20, knockout_score: None
# 2024-08-16 18:34:55,273 - INFO - Starting solver with random_seed: 964648924, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:56,031 - INFO - Solver completed in 0.757592 seconds with status: 4
# 2024-08-16 18:34:56,032 - INFO - Starting solver with random_seed: 818818612, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:56,909 - INFO - Solver completed in 0.876446 seconds with status: 4
# 2024-08-16 18:34:56,910 - INFO - Starting solver with random_seed: 473500222, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:57,537 - INFO - Solver completed in 0.626593 seconds with status: 4
# 2024-08-16 18:34:57,537 - INFO - Starting solver with random_seed: 842899778, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:58,184 - INFO - Solver completed in 0.646746 seconds with status: 4
# 2024-08-16 18:34:58,185 - INFO - Starting solver with random_seed: 1776885676, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:58,968 - INFO - Solver completed in 0.782706 seconds with status: 4
# 2024-08-16 18:34:58,969 - INFO - Starting solver with random_seed: 723406558, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:34:59,685 - INFO - Solver completed in 0.71617 seconds with status: 4
# 2024-08-16 18:34:59,686 - INFO - Starting solver with random_seed: 1759670741, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:00,426 - INFO - Solver completed in 0.74003 seconds with status: 4
# 2024-08-16 18:35:00,427 - INFO - Starting solver with random_seed: 732671141, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:01,216 - INFO - Solver completed in 0.789092 seconds with status: 4
# 2024-08-16 18:35:01,217 - INFO - Starting solver with random_seed: 775095126, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:01,762 - INFO - Solver completed in 0.54485 seconds with status: 4
# 2024-08-16 18:35:01,763 - INFO - Starting solver with random_seed: 1712698397, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:02,605 - INFO - Solver completed in 0.841805 seconds with status: 4
# 2024-08-16 18:35:02,606 - INFO - Starting solver with random_seed: 1348596930, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:03,347 - INFO - Solver completed in 0.740987 seconds with status: 4
# 2024-08-16 18:35:03,348 - INFO - Starting solver with random_seed: 1508143602, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:04,238 - INFO - Solver completed in 0.890078 seconds with status: 4
# 2024-08-16 18:35:04,239 - INFO - Starting solver with random_seed: 1647455994, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:04,958 - INFO - Solver completed in 0.71833 seconds with status: 4
# 2024-08-16 18:35:04,958 - INFO - Starting solver with random_seed: 1766427199, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:05,717 - INFO - Solver completed in 0.758419 seconds with status: 4
# 2024-08-16 18:35:05,718 - INFO - Starting solver with random_seed: 1866929026, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:06,445 - INFO - Solver completed in 0.726748 seconds with status: 4
# 2024-08-16 18:35:06,446 - INFO - Starting solver with random_seed: 1821260344, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:07,299 - INFO - Solver completed in 0.852196 seconds with status: 4
# 2024-08-16 18:35:07,299 - INFO - Starting solver with random_seed: 146675542, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:08,200 - INFO - Solver completed in 0.900012 seconds with status: 4
# 2024-08-16 18:35:08,201 - INFO - Starting solver with random_seed: 1635035350, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:09,021 - INFO - Solver completed in 0.819804 seconds with status: 4
# 2024-08-16 18:35:09,021 - INFO - Starting solver with random_seed: 456457037, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:09,795 - INFO - Solver completed in 0.772731 seconds with status: 4
# 2024-08-16 18:35:09,795 - INFO - Starting solver with random_seed: 1141153780, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 18:35:10,545 - INFO - Solver completed in 0.74983 seconds with status: 4
# 2024-08-16 18:35:10,546 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:35:10,546 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter                     ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ binary_minimization_algorithm │   3   │    14.41%    │       1       │
# │ 2   │ cp_model_probing_level        │   1   │    19.12%    │       2       │
# │ 3   │ search_branching              │   7   │    20.91%    │       0       │
# │ 4   │ cut_level                     │   0   │    45.56%    │       1       │
# └─────┴───────────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. binary_minimization_algorithm Specifies the algorithm used for binary clause minimization during conflict
# analysis. The options are:
#
#  • 0 NO_BINARY_MINIMIZATION.
#  • 1 BINARY_MINIMIZATION_FIRST
#  • 2 BINARY_MINIMIZATION_WITH_REACHABILITY
#  • 3 EXPERIMENTAL_BINARY_MINIMIZATION
#  • 4 BINARY_MINIMIZATION_FIRST_WITH_TRANSITIVE_REDUCTION
#
# 2. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
#
# 3. search_branching Defines the branching strategy the solver uses to navigate the search tree. The options are:
#
#  • 0 (AUTOMATIC_SEARCH): The solver automatically selects the most appropriate strategy.
#  • 1 (FIXED_SEARCH): Follows a fixed variable order, as specified by the user or the problem model.
#  • 2 (PORTFOLIO_SEARCH): Uses a combination of multiple strategies to explore the search space.
#  • 3 (LP_SEARCH): Branches based on the LP relaxation of the problem, leveraging the reduced costs of variables.
#  • 4 (PSEUDO_COST_SEARCH): Branches using pseudo-costs, which are estimates of the impact of branching decisions
#    based on past experiences.
#  • 5 (PORTFOLIO_WITH_QUICK_RESTART_SEARCH): Quickly explores different heuristics with low conflict limits, aiming
#    to find a good initial solution.
#  • 6 (HINT_SEARCH): Prioritizes decisions based on hints provided by the user or the problem model.
#  • 7 (PARTIAL_FIXED_SEARCH): Begins with a fixed strategy, then switches to automatic search for the remaining
#    decisions.
#  • 8 (RANDOMIZED_SEARCH): Introduces randomization into branching decisions to diversify the search.
#
# 4. cut_level Sets the level of effort the solver will invest in generating cutting planes, which are linear
# constraints added to remove infeasible regions. Properly applied, cuts can significantly reduce the search space
# and help the solver find an optimal solution more quickly.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                 ┃ Mean ┃  Min ┃  Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━━━┩
# │ Default Metric Value   │ 1.68 │ 1.33 │ 2.21 │       20 │
# │ Optimized Metric Value │ 0.76 │ 0.54 │  0.9 │       20 │
# └────────────────────────┴──────┴──────┴──────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-16 18:35:10,569 - INFO - Hyperparameter tuning completed.
# 2024-08-16 18:35:10,570 - INFO - Tuning for time to optimal completed.

# %%
best = tune_for_quality_within_timelimit(
    model,
    max_time_in_seconds=0.5,
    obj_for_timeout=0,
    direction="maximize",
    n_samples_for_trial=5,  # Number of samples for each trial
    n_samples_for_verification=20,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-16 18:35:10,577 - INFO - Starting tuning for quality within time limit. Direction: maximize
# 2024-08-16 18:35:10,577 - INFO - Initialized Metric with direction: maximize
# 2024-08-16 18:35:10,578 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-16 18:35:10,578 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:10,578 - INFO - Starting solver with random_seed: 726297170, max_time_in_seconds: 0.5
# 2024-08-16 18:35:11,095 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-16 18:35:11,096 - INFO - Starting solver with random_seed: 411682486, max_time_in_seconds: 0.5
# 2024-08-16 18:35:11,613 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-16 18:35:11,613 - INFO - Starting solver with random_seed: 1848261505, max_time_in_seconds: 0.5
# 2024-08-16 18:35:12,129 - INFO - Solver found a solution with objective value: 131665.0
# 2024-08-16 18:35:12,130 - INFO - Starting solver with random_seed: 2043889888, max_time_in_seconds: 0.5
# 2024-08-16 18:35:12,647 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:12,647 - INFO - Starting solver with random_seed: 561838468, max_time_in_seconds: 0.5
# 2024-08-16 18:35:13,164 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:13,165 - INFO - Starting solver with random_seed: 1188260777, max_time_in_seconds: 0.5
# 2024-08-16 18:35:13,681 - INFO - Solver found a solution with objective value: 132275.0
# 2024-08-16 18:35:13,681 - INFO - Starting solver with random_seed: 1808573449, max_time_in_seconds: 0.5
# 2024-08-16 18:35:14,197 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 18:35:14,198 - INFO - Starting solver with random_seed: 155227434, max_time_in_seconds: 0.5
# 2024-08-16 18:35:14,716 - INFO - Solver found a solution with objective value: 131107.0
# 2024-08-16 18:35:14,716 - INFO - Starting solver with random_seed: 874146289, max_time_in_seconds: 0.5
# 2024-08-16 18:35:15,233 - INFO - Solver found a solution with objective value: 131358.0
# 2024-08-16 18:35:15,233 - INFO - Starting solver with random_seed: 1845459598, max_time_in_seconds: 0.5
# 2024-08-16 18:35:15,752 - INFO - Solver found a solution with objective value: 131960.0
# 2024-08-16 18:35:15,752 - INFO - Starting solver with random_seed: 1234518519, max_time_in_seconds: 0.5
# 2024-08-16 18:35:16,269 - INFO - Solver found a solution with objective value: 132720.0
# 2024-08-16 18:35:16,270 - INFO - Starting solver with random_seed: 1160585870, max_time_in_seconds: 0.5
# 2024-08-16 18:35:16,793 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:16,794 - INFO - Starting solver with random_seed: 213326497, max_time_in_seconds: 0.5
# 2024-08-16 18:35:17,314 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-16 18:35:17,315 - INFO - Starting solver with random_seed: 792380704, max_time_in_seconds: 0.5
# 2024-08-16 18:35:17,832 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:17,833 - INFO - Starting solver with random_seed: 635690184, max_time_in_seconds: 0.5
# 2024-08-16 18:35:18,350 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:18,351 - INFO - Starting solver with random_seed: 2084274909, max_time_in_seconds: 0.5
# 2024-08-16 18:35:18,867 - INFO - Solver found a solution with objective value: 131589.0
# 2024-08-16 18:35:18,868 - INFO - Starting solver with random_seed: 424860493, max_time_in_seconds: 0.5
# 2024-08-16 18:35:19,398 - INFO - Solver found a solution with objective value: 131760.0
# 2024-08-16 18:35:19,399 - INFO - Starting solver with random_seed: 1814160450, max_time_in_seconds: 0.5
# 2024-08-16 18:35:19,918 - INFO - Solver found a solution with objective value: 131905.0
# 2024-08-16 18:35:19,918 - INFO - Starting solver with random_seed: 520659309, max_time_in_seconds: 0.5
# 2024-08-16 18:35:20,440 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:20,441 - INFO - Starting solver with random_seed: 1777505537, max_time_in_seconds: 0.5
# 2024-08-16 18:35:20,967 - INFO - Solver found a solution with objective value: 130855.0
# 2024-08-16 18:35:20,967 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:35:20,968 - INFO - Baseline evaluation completed: min=130855.0, mean=132184.6, max=132805.0
# [I 2024-08-16 18:35:20,968] A new study created in memory with name: no-name-6e34e61e-072a-4507-9b8c-1cc51fc8ee12
# 2024-08-16 18:35:20,969 - INFO - Starting Optuna optimization.
# 2024-08-16 18:35:20,970 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:20,971 - INFO - Returning cached result.
# 2024-08-16 18:35:20,971 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:20,971 - INFO - Starting solver with random_seed: 2097001120, max_time_in_seconds: 0.5
# 2024-08-16 18:35:21,489 - INFO - Solver found a solution with objective value: 131650.0
# 2024-08-16 18:35:21,490 - INFO - Starting solver with random_seed: 1333851666, max_time_in_seconds: 0.5
# 2024-08-16 18:35:22,009 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:22,009 - INFO - Starting solver with random_seed: 395671573, max_time_in_seconds: 0.5
# 2024-08-16 18:35:22,527 - INFO - Solver found a solution with objective value: 130855.0
# 2024-08-16 18:35:22,527 - INFO - Starting solver with random_seed: 652714130, max_time_in_seconds: 0.5
# 2024-08-16 18:35:23,043 - INFO - Solver found a solution with objective value: 130941.0
# 2024-08-16 18:35:23,043 - INFO - Starting solver with random_seed: 1464556516, max_time_in_seconds: 0.5
# 2024-08-16 18:35:23,563 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-16 18:35:23,563 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:23,564] Trial 0 finished with value: 131731.2 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 131731.2.
# 2024-08-16 18:35:23,567 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:23,568 - INFO - Returning cached result.
# 2024-08-16 18:35:23,568 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['fixed', 'no_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 4, 'use_lns_only': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:23,569 - INFO - Starting solver with random_seed: 936146934, max_time_in_seconds: 0.5
# 2024-08-16 18:35:24,079 - INFO - Solver found a solution with objective value: 132349.0
# 2024-08-16 18:35:24,080 - INFO - Starting solver with random_seed: 660576731, max_time_in_seconds: 0.5
# 2024-08-16 18:35:24,593 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:24,594 - INFO - Starting solver with random_seed: 2135635082, max_time_in_seconds: 0.5
# 2024-08-16 18:35:25,112 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:25,113 - INFO - Starting solver with random_seed: 38613307, max_time_in_seconds: 0.5
# 2024-08-16 18:35:25,625 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 18:35:25,626 - INFO - Starting solver with random_seed: 672675855, max_time_in_seconds: 0.5
# 2024-08-16 18:35:26,143 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:26,144 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:26,145] Trial 1 finished with value: 132635.6 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:26,148 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:26,148 - INFO - Returning cached result.
# 2024-08-16 18:35:26,149 - INFO - Evaluating with params: {'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['default_lp', 'max_lp', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 4, 'use_lns_only': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:26,149 - INFO - Starting solver with random_seed: 595064138, max_time_in_seconds: 0.5
# 2024-08-16 18:35:26,659 - INFO - Solver found a solution with objective value: 131723.0
# 2024-08-16 18:35:26,660 - INFO - Starting solver with random_seed: 1208526621, max_time_in_seconds: 0.5
# 2024-08-16 18:35:27,171 - INFO - Solver found a solution with objective value: 132224.0
# 2024-08-16 18:35:27,171 - INFO - Starting solver with random_seed: 1226073676, max_time_in_seconds: 0.5
# 2024-08-16 18:35:27,683 - INFO - Solver found a solution with objective value: 131875.0
# 2024-08-16 18:35:27,683 - INFO - Starting solver with random_seed: 1859463593, max_time_in_seconds: 0.5
# 2024-08-16 18:35:28,198 - INFO - Solver found a solution with objective value: 132289.0
# 2024-08-16 18:35:28,199 - INFO - Starting solver with random_seed: 1467418052, max_time_in_seconds: 0.5
# 2024-08-16 18:35:28,709 - INFO - Solver found a solution with objective value: 132124.0
# 2024-08-16 18:35:28,710 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:28,710] Trial 2 finished with value: 132047.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:28,714 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:28,714 - INFO - Returning cached result.
# 2024-08-16 18:35:28,714 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 4, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:28,715 - INFO - Starting solver with random_seed: 126787860, max_time_in_seconds: 0.5
# 2024-08-16 18:35:29,227 - INFO - Solver found a solution with objective value: 131747.0
# 2024-08-16 18:35:29,228 - INFO - Starting solver with random_seed: 810564574, max_time_in_seconds: 0.5
# 2024-08-16 18:35:29,740 - INFO - Solver found a solution with objective value: 132725.0
# 2024-08-16 18:35:29,741 - INFO - Starting solver with random_seed: 2013876813, max_time_in_seconds: 0.5
# 2024-08-16 18:35:30,253 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-16 18:35:30,254 - INFO - Starting solver with random_seed: 325974361, max_time_in_seconds: 0.5
# 2024-08-16 18:35:30,767 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:30,767 - INFO - Starting solver with random_seed: 954462201, max_time_in_seconds: 0.5
# 2024-08-16 18:35:31,280 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:31,281 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:31,282] Trial 3 finished with value: 132513.4 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:31,286 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:31,286 - INFO - Returning cached result.
# 2024-08-16 18:35:31,286 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'max_presolve_iterations': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 1, 'repair_hint': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'add_objective_cut': True}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:31,287 - INFO - Starting solver with random_seed: 650494339, max_time_in_seconds: 0.5
# 2024-08-16 18:35:31,797 - INFO - Solver found a solution with objective value: 132100.0
# 2024-08-16 18:35:31,798 - INFO - Starting solver with random_seed: 476430129, max_time_in_seconds: 0.5
# 2024-08-16 18:35:32,304 - INFO - Solver found a solution with objective value: 125855.0
# 2024-08-16 18:35:32,305 - INFO - Returning knockout result.
# [I 2024-08-16 18:35:32,306] Trial 4 finished with value: 125855.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:32,309 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:32,309 - INFO - Returning cached result.
# 2024-08-16 18:35:32,310 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'reduced_costs', 'quick_restart_no_lp', 'probing'], 'search_branching': 3, 'optimize_with_core': True, 'diversify_lns_params': True, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:32,310 - INFO - Starting solver with random_seed: 844626200, max_time_in_seconds: 0.5
# 2024-08-16 18:35:32,827 - INFO - Solver found a solution with objective value: 130943.0
# 2024-08-16 18:35:32,828 - INFO - Starting solver with random_seed: 1574161588, max_time_in_seconds: 0.5
# 2024-08-16 18:35:33,344 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-16 18:35:33,345 - INFO - Starting solver with random_seed: 1040405670, max_time_in_seconds: 0.5
# 2024-08-16 18:35:33,868 - INFO - Solver found a solution with objective value: 130199.0
# 2024-08-16 18:35:33,868 - INFO - Returning knockout result.
# [I 2024-08-16 18:35:33,869] Trial 5 finished with value: 130199.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 3, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:33,873 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:33,873 - INFO - Returning cached result.
# 2024-08-16 18:35:33,873 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'ignore_subsolvers': ['default_lp', 'fixed', 'max_lp', 'lb_tree_search', 'probing'], 'search_branching': 4, 'repair_hint': True, 'use_lb_relax_lns': True, 'optimize_with_core': True, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:33,874 - INFO - Starting solver with random_seed: 1372729376, max_time_in_seconds: 0.5
# 2024-08-16 18:35:34,390 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:34,390 - INFO - Starting solver with random_seed: 1863219182, max_time_in_seconds: 0.5
# 2024-08-16 18:35:34,909 - INFO - Solver found a solution with objective value: 131983.0
# 2024-08-16 18:35:34,910 - INFO - Starting solver with random_seed: 542135411, max_time_in_seconds: 0.5
# 2024-08-16 18:35:35,427 - INFO - Solver found a solution with objective value: 131375.0
# 2024-08-16 18:35:35,428 - INFO - Starting solver with random_seed: 1551255494, max_time_in_seconds: 0.5
# 2024-08-16 18:35:35,945 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:35,945 - INFO - Starting solver with random_seed: 1949809612, max_time_in_seconds: 0.5
# 2024-08-16 18:35:36,461 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:36,462 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:36,463] Trial 6 finished with value: 132354.6 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 4, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:36,467 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:36,467 - INFO - Returning cached result.
# 2024-08-16 18:35:36,468 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['reduced_costs', 'quick_restart'], 'search_branching': 4, 'repair_hint': True, 'use_lns_only': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'fp_rounding': 3, 'diversify_lns_params': True, 'cut_level': 0, 'symmetry_level': 0}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:36,468 - INFO - Starting solver with random_seed: 1254801712, max_time_in_seconds: 0.5
# 2024-08-16 18:35:36,978 - INFO - Solver found a solution with objective value: 132105.0
# 2024-08-16 18:35:36,979 - INFO - Starting solver with random_seed: 1877068936, max_time_in_seconds: 0.5
# 2024-08-16 18:35:37,489 - INFO - Solver found a solution with objective value: 128985.0
# 2024-08-16 18:35:37,490 - INFO - Returning knockout result.
# [I 2024-08-16 18:35:37,491] Trial 7 finished with value: 128985.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:37,497 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:37,497 - INFO - Returning cached result.
# 2024-08-16 18:35:37,497 - INFO - Evaluating with params: {'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 1, 'repair_hint': True, 'use_lns_only': True, 'optimize_with_core': True, 'polish_lp_solution': True, 'add_objective_cut': True, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:37,498 - INFO - Starting solver with random_seed: 1645062397, max_time_in_seconds: 0.5
# 2024-08-16 18:35:38,013 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 18:35:38,014 - INFO - Starting solver with random_seed: 1837473868, max_time_in_seconds: 0.5
# 2024-08-16 18:35:38,527 - INFO - Solver found a solution with objective value: 132215.0
# 2024-08-16 18:35:38,528 - INFO - Starting solver with random_seed: 1183286844, max_time_in_seconds: 0.5
# 2024-08-16 18:35:39,038 - INFO - Solver found a solution with objective value: 127671.0
# 2024-08-16 18:35:39,039 - INFO - Returning knockout result.
# [I 2024-08-16 18:35:39,040] Trial 8 finished with value: 127671.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:39,043 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:39,043 - INFO - Returning cached result.
# 2024-08-16 18:35:39,043 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'quick_restart', 'lb_tree_search'], 'search_branching': 5, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:39,044 - INFO - Starting solver with random_seed: 1098752599, max_time_in_seconds: 0.5
# 2024-08-16 18:35:39,557 - INFO - Solver found a solution with objective value: 79384.0
# 2024-08-16 18:35:39,558 - INFO - Returning knockout result.
# [I 2024-08-16 18:35:39,559] Trial 9 finished with value: 79384.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 5, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 0}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:39,603 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:39,604 - INFO - Returning cached result.
# 2024-08-16 18:35:39,604 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp'], 'search_branching': 8, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:39,604 - INFO - Starting solver with random_seed: 5492247, max_time_in_seconds: 0.5
# 2024-08-16 18:35:40,117 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-16 18:35:40,118 - INFO - Starting solver with random_seed: 1510676909, max_time_in_seconds: 0.5
# 2024-08-16 18:35:40,632 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-16 18:35:40,633 - INFO - Starting solver with random_seed: 160753440, max_time_in_seconds: 0.5
# 2024-08-16 18:35:41,144 - INFO - Solver found a solution with objective value: 132325.0
# 2024-08-16 18:35:41,145 - INFO - Starting solver with random_seed: 306341736, max_time_in_seconds: 0.5
# 2024-08-16 18:35:41,658 - INFO - Solver found a solution with objective value: 132384.0
# 2024-08-16 18:35:41,659 - INFO - Starting solver with random_seed: 25766263, max_time_in_seconds: 0.5
# 2024-08-16 18:35:42,176 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:42,177 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:42,178] Trial 10 finished with value: 132480.8 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:42,232 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:42,233 - INFO - Returning cached result.
# 2024-08-16 18:35:42,233 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 7, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'linearization_level': 2, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:42,233 - INFO - Starting solver with random_seed: 1448549990, max_time_in_seconds: 0.5
# 2024-08-16 18:35:42,750 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:42,750 - INFO - Starting solver with random_seed: 466675863, max_time_in_seconds: 0.5
# 2024-08-16 18:35:43,265 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:43,265 - INFO - Starting solver with random_seed: 1085784933, max_time_in_seconds: 0.5
# 2024-08-16 18:35:43,777 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:43,778 - INFO - Starting solver with random_seed: 213453153, max_time_in_seconds: 0.5
# 2024-08-16 18:35:44,290 - INFO - Solver found a solution with objective value: 132120.0
# 2024-08-16 18:35:44,291 - INFO - Starting solver with random_seed: 582732783, max_time_in_seconds: 0.5
# 2024-08-16 18:35:44,804 - INFO - Solver found a solution with objective value: 130177.0
# 2024-08-16 18:35:44,804 - INFO - Returning knockout result.
# [I 2024-08-16 18:35:44,805] Trial 11 finished with value: 130177.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 7, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:44,851 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:44,852 - INFO - Returning cached result.
# 2024-08-16 18:35:44,852 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 6, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:44,852 - INFO - Starting solver with random_seed: 815467820, max_time_in_seconds: 0.5
# 2024-08-16 18:35:45,365 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:45,366 - INFO - Starting solver with random_seed: 2045732476, max_time_in_seconds: 0.5
# 2024-08-16 18:35:45,877 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 18:35:45,878 - INFO - Starting solver with random_seed: 1821552161, max_time_in_seconds: 0.5
# 2024-08-16 18:35:46,390 - INFO - Solver found a solution with objective value: 130675.0
# 2024-08-16 18:35:46,391 - INFO - Starting solver with random_seed: 1608706527, max_time_in_seconds: 0.5
# 2024-08-16 18:35:46,903 - INFO - Solver found a solution with objective value: 132149.0
# 2024-08-16 18:35:46,903 - INFO - Starting solver with random_seed: 758428120, max_time_in_seconds: 0.5
# 2024-08-16 18:35:47,415 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:35:47,416 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:47,416] Trial 12 finished with value: 132169.6 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:47,460 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:47,461 - INFO - Returning cached result.
# 2024-08-16 18:35:47,461 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 2, 'use_lns_only': True, 'use_lb_relax_lns': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:47,461 - INFO - Starting solver with random_seed: 1712938797, max_time_in_seconds: 0.5
# 2024-08-16 18:35:47,975 - INFO - Solver found a solution with objective value: 131390.0
# 2024-08-16 18:35:47,976 - INFO - Starting solver with random_seed: 1935818628, max_time_in_seconds: 0.5
# 2024-08-16 18:35:48,490 - INFO - Solver found a solution with objective value: 132359.0
# 2024-08-16 18:35:48,490 - INFO - Starting solver with random_seed: 2005719659, max_time_in_seconds: 0.5
# 2024-08-16 18:35:49,003 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 18:35:49,003 - INFO - Starting solver with random_seed: 1086337112, max_time_in_seconds: 0.5
# 2024-08-16 18:35:49,520 - INFO - Solver found a solution with objective value: 131203.0
# 2024-08-16 18:35:49,520 - INFO - Starting solver with random_seed: 1223398560, max_time_in_seconds: 0.5
# 2024-08-16 18:35:50,055 - INFO - Solver found a solution with objective value: 132375.0
# 2024-08-16 18:35:50,055 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 18:35:50,056] Trial 13 finished with value: 131948.2 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 1 with value: 132635.6.
# 2024-08-16 18:35:50,102 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 18:35:50,102 - INFO - Returning cached result.
# 2024-08-16 18:35:50,103 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 4, 'use_lns_only': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 5, knockout_score: 130660.0
# 2024-08-16 18:35:50,103 - INFO - Starting solver with random_seed: 1936056207, max_time_in_seconds: 0.5
# 2024-08-16 18:35:50,613 - INFO - Solver found a solution with objective value: 130325.0
# 2024-08-16 18:35:50,614 - INFO - Returning knockout result.
# ...
# 2024-08-16 18:37:17,923 - INFO - Starting solver with random_seed: 2005662750, max_time_in_seconds: 0.5
# 2024-08-16 18:37:18,435 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:18,435 - INFO - Starting solver with random_seed: 1389761474, max_time_in_seconds: 0.5
# 2024-08-16 18:37:18,950 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:18,951 - INFO - Starting solver with random_seed: 319352692, max_time_in_seconds: 0.5
# 2024-08-16 18:37:19,469 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:19,470 - INFO - Starting solver with random_seed: 452618484, max_time_in_seconds: 0.5
# 2024-08-16 18:37:19,992 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:19,993 - INFO - Starting solver with random_seed: 2018963871, max_time_in_seconds: 0.5
# 2024-08-16 18:37:20,514 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:20,515 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:37:20,515 - INFO - Parameter 'diversify_lns_params' can be dropped from the optimized parameters.
# 2024-08-16 18:37:20,515 - INFO - Evaluating resetting parameter 'linearization_level' to default...
# 2024-08-16 18:37:20,516 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'add_objective_cut': True, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: None
# 2024-08-16 18:37:20,516 - INFO - Starting solver with random_seed: 1108114377, max_time_in_seconds: 0.5
# 2024-08-16 18:37:21,031 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:21,032 - INFO - Starting solver with random_seed: 1656313308, max_time_in_seconds: 0.5
# 2024-08-16 18:37:21,545 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:21,546 - INFO - Starting solver with random_seed: 607967187, max_time_in_seconds: 0.5
# 2024-08-16 18:37:22,060 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:22,060 - INFO - Starting solver with random_seed: 233264192, max_time_in_seconds: 0.5
# 2024-08-16 18:37:22,581 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:22,581 - INFO - Starting solver with random_seed: 1516591476, max_time_in_seconds: 0.5
# 2024-08-16 18:37:23,094 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:23,095 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:37:23,096 - INFO - Parameter 'linearization_level' can be dropped from the optimized parameters.
# 2024-08-16 18:37:23,096 - INFO - Evaluating resetting parameter 'add_objective_cut' to default...
# 2024-08-16 18:37:23,096 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 0, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: None
# 2024-08-16 18:37:23,097 - INFO - Starting solver with random_seed: 1965056298, max_time_in_seconds: 0.5
# 2024-08-16 18:37:23,612 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:23,613 - INFO - Starting solver with random_seed: 549649616, max_time_in_seconds: 0.5
# 2024-08-16 18:37:24,127 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:24,128 - INFO - Starting solver with random_seed: 1886756633, max_time_in_seconds: 0.5
# 2024-08-16 18:37:24,640 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:24,641 - INFO - Starting solver with random_seed: 612821805, max_time_in_seconds: 0.5
# 2024-08-16 18:37:25,158 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:25,159 - INFO - Starting solver with random_seed: 1231660234, max_time_in_seconds: 0.5
# 2024-08-16 18:37:25,673 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:25,673 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:37:25,673 - INFO - Parameter 'add_objective_cut' can be dropped from the optimized parameters.
# 2024-08-16 18:37:25,674 - INFO - Evaluating resetting parameter 'cut_level' to default...
# 2024-08-16 18:37:25,674 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 0, 'add_objective_cut': True, 'symmetry_level': 1}, num_runs: 5, knockout_score: None
# 2024-08-16 18:37:25,674 - INFO - Starting solver with random_seed: 385257130, max_time_in_seconds: 0.5
# 2024-08-16 18:37:26,190 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:26,190 - INFO - Starting solver with random_seed: 203096385, max_time_in_seconds: 0.5
# 2024-08-16 18:37:26,708 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:26,709 - INFO - Starting solver with random_seed: 774810495, max_time_in_seconds: 0.5
# 2024-08-16 18:37:27,225 - INFO - Solver found a solution with objective value: 131938.0
# 2024-08-16 18:37:27,226 - INFO - Starting solver with random_seed: 992402757, max_time_in_seconds: 0.5
# 2024-08-16 18:37:27,741 - INFO - Solver found a solution with objective value: 132465.0
# 2024-08-16 18:37:27,741 - INFO - Starting solver with random_seed: 20130377, max_time_in_seconds: 0.5
# 2024-08-16 18:37:28,264 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:28,264 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:37:28,265 - INFO - Parameter 'cut_level' is essential for performance.
# 2024-08-16 18:37:28,265 - INFO - Evaluating resetting parameter 'symmetry_level' to default...
# 2024-08-16 18:37:28,265 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0}, num_runs: 5, knockout_score: None
# 2024-08-16 18:37:28,266 - INFO - Starting solver with random_seed: 109085492, max_time_in_seconds: 0.5
# 2024-08-16 18:37:28,779 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:28,780 - INFO - Starting solver with random_seed: 635669943, max_time_in_seconds: 0.5
# 2024-08-16 18:37:29,294 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:29,295 - INFO - Starting solver with random_seed: 568782726, max_time_in_seconds: 0.5
# 2024-08-16 18:37:29,808 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:29,809 - INFO - Starting solver with random_seed: 363169546, max_time_in_seconds: 0.5
# 2024-08-16 18:37:30,322 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:30,323 - INFO - Starting solver with random_seed: 1933882172, max_time_in_seconds: 0.5
# 2024-08-16 18:37:30,838 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:30,839 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:37:30,839 - INFO - Parameter 'symmetry_level' can be dropped from the optimized parameters.
# 2024-08-16 18:37:30,839 - INFO - Evaluating with params: {'cp_model_probing_level': 0, 'cut_level': 0}, num_runs: 20, knockout_score: None
# 2024-08-16 18:37:30,840 - INFO - Starting solver with random_seed: 13540941, max_time_in_seconds: 0.5
# 2024-08-16 18:37:31,359 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-16 18:37:31,360 - INFO - Starting solver with random_seed: 372381692, max_time_in_seconds: 0.5
# 2024-08-16 18:37:31,857 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:31,857 - INFO - Starting solver with random_seed: 115133401, max_time_in_seconds: 0.5
# 2024-08-16 18:37:32,191 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:32,192 - INFO - Starting solver with random_seed: 1951138, max_time_in_seconds: 0.5
# 2024-08-16 18:37:32,570 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:32,571 - INFO - Starting solver with random_seed: 527328323, max_time_in_seconds: 0.5
# 2024-08-16 18:37:32,987 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:32,988 - INFO - Starting solver with random_seed: 1925997027, max_time_in_seconds: 0.5
# 2024-08-16 18:37:33,384 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:33,385 - INFO - Starting solver with random_seed: 2093492745, max_time_in_seconds: 0.5
# 2024-08-16 18:37:33,917 - INFO - Solver found a solution with objective value: 132350.0
# 2024-08-16 18:37:33,918 - INFO - Starting solver with random_seed: 666011292, max_time_in_seconds: 0.5
# 2024-08-16 18:37:34,387 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:34,387 - INFO - Starting solver with random_seed: 1065693727, max_time_in_seconds: 0.5
# 2024-08-16 18:37:34,804 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:34,805 - INFO - Starting solver with random_seed: 36542261, max_time_in_seconds: 0.5
# 2024-08-16 18:37:35,266 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:35,267 - INFO - Starting solver with random_seed: 1965517704, max_time_in_seconds: 0.5
# 2024-08-16 18:37:35,688 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:35,688 - INFO - Starting solver with random_seed: 2023925120, max_time_in_seconds: 0.5
# 2024-08-16 18:37:36,135 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:36,136 - INFO - Starting solver with random_seed: 448434308, max_time_in_seconds: 0.5
# 2024-08-16 18:37:36,650 - INFO - Solver found a solution with objective value: 132468.0
# 2024-08-16 18:37:36,650 - INFO - Starting solver with random_seed: 1403579113, max_time_in_seconds: 0.5
# 2024-08-16 18:37:37,013 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:37,014 - INFO - Starting solver with random_seed: 821667065, max_time_in_seconds: 0.5
# 2024-08-16 18:37:37,531 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-16 18:37:37,532 - INFO - Starting solver with random_seed: 1243979989, max_time_in_seconds: 0.5
# 2024-08-16 18:37:37,950 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:37,951 - INFO - Starting solver with random_seed: 590997401, max_time_in_seconds: 0.5
# 2024-08-16 18:37:38,467 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-16 18:37:38,468 - INFO - Starting solver with random_seed: 1907923522, max_time_in_seconds: 0.5
# 2024-08-16 18:37:38,983 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:38,984 - INFO - Starting solver with random_seed: 840210473, max_time_in_seconds: 0.5
# 2024-08-16 18:37:39,498 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:39,499 - INFO - Starting solver with random_seed: 515931733, max_time_in_seconds: 0.5
# 2024-08-16 18:37:40,004 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 18:37:40,005 - INFO - Evaluation completed and result cached.
# 2024-08-16 18:37:40,005 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter              ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ cp_model_probing_level │   0   │    21.98%    │       2       │
# │ 2   │ cut_level              │   0   │    78.02%    │       1       │
# └─────┴────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
#
# 2. cut_level Sets the level of effort the solver will invest in generating cutting planes, which are linear
# constraints added to remove infeasible regions. Properly applied, cuts can significantly reduce the search space
# and help the solver find an optimal solution more quickly.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                 ┃     Mean ┃      Min ┃      Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━┩
# │ Default Metric Value   │ 132184.6 │ 130855.0 │ 132805.0 │       20 │
# │ Optimized Metric Value │ 132705.3 │ 132350.0 │ 132805.0 │       20 │
# └────────────────────────┴──────────┴──────────┴──────────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-16 18:37:40,017 - INFO - Hyperparameter tuning completed.
# 2024-08-16 18:37:40,018 - INFO - Tuning for quality within time limit completed.
