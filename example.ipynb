# %%
from cpsat_autotune import (
    tune_for_quality_within_timelimit,
    import_model,
    tune_time_to_optimal,
)

# %%
model = import_model("models/model_proto_-1368620059351071685.pb")

# %%
best = tune_time_to_optimal(
    model,
    max_time_in_seconds=3,  # Enter a time limit slightly above what the solver with default parameters needs
    n_samples_for_trial=5,  # Number of samples for each trial
    n_samples_for_verification=20,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-16 23:20:43,848 - INFO - Starting tuning to minimize time to optimal solution.
# 2024-08-16 23:20:43,849 - INFO - Initialized Metric with direction: minimize
# 2024-08-16 23:20:43,849 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-16 23:20:43,850 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:20:43,850 - INFO - Starting solver with random_seed: 2110125566, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:45,412 - INFO - Solver completed in 1.5613 seconds with status: 4
# 2024-08-16 23:20:45,413 - INFO - Starting solver with random_seed: 1192535936, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:47,112 - INFO - Solver completed in 1.698687 seconds with status: 4
# 2024-08-16 23:20:47,112 - INFO - Starting solver with random_seed: 75591852, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:48,391 - INFO - Solver completed in 1.278235 seconds with status: 4
# 2024-08-16 23:20:48,391 - INFO - Starting solver with random_seed: 99770377, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:49,840 - INFO - Solver completed in 1.448191 seconds with status: 4
# 2024-08-16 23:20:49,841 - INFO - Starting solver with random_seed: 795009064, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:50,653 - INFO - Solver completed in 0.81232 seconds with status: 4
# 2024-08-16 23:20:50,654 - INFO - Starting solver with random_seed: 30400722, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:53,613 - INFO - Solver completed in 2.959044 seconds with status: 4
# 2024-08-16 23:20:53,614 - INFO - Starting solver with random_seed: 1393159196, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:56,493 - INFO - Solver completed in 2.879118 seconds with status: 4
# 2024-08-16 23:20:56,494 - INFO - Starting solver with random_seed: 437071286, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:58,411 - INFO - Solver completed in 1.916685 seconds with status: 4
# 2024-08-16 23:20:58,412 - INFO - Starting solver with random_seed: 1035012054, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:20:59,812 - INFO - Solver completed in 1.400418 seconds with status: 4
# 2024-08-16 23:20:59,813 - INFO - Starting solver with random_seed: 832454006, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:01,452 - INFO - Solver completed in 1.638809 seconds with status: 4
# 2024-08-16 23:21:01,453 - INFO - Starting solver with random_seed: 652691936, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:03,767 - INFO - Solver completed in 2.313955 seconds with status: 4
# 2024-08-16 23:21:03,768 - INFO - Starting solver with random_seed: 88116186, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:05,224 - INFO - Solver completed in 1.456345 seconds with status: 4
# 2024-08-16 23:21:05,225 - INFO - Starting solver with random_seed: 1852278150, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:07,305 - INFO - Solver completed in 2.079921 seconds with status: 4
# 2024-08-16 23:21:07,306 - INFO - Starting solver with random_seed: 1924512405, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:09,334 - INFO - Solver completed in 2.02777 seconds with status: 4
# 2024-08-16 23:21:09,334 - INFO - Starting solver with random_seed: 1049415539, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:11,146 - INFO - Solver completed in 1.811056 seconds with status: 4
# 2024-08-16 23:21:11,146 - INFO - Starting solver with random_seed: 1440656445, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:12,907 - INFO - Solver completed in 1.760403 seconds with status: 4
# 2024-08-16 23:21:12,908 - INFO - Starting solver with random_seed: 251224293, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:14,471 - INFO - Solver completed in 1.563246 seconds with status: 4
# 2024-08-16 23:21:14,472 - INFO - Starting solver with random_seed: 1328319092, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:16,456 - INFO - Solver completed in 1.983949 seconds with status: 4
# 2024-08-16 23:21:16,457 - INFO - Starting solver with random_seed: 1701282712, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:17,912 - INFO - Solver completed in 1.454841 seconds with status: 4
# 2024-08-16 23:21:17,912 - INFO - Starting solver with random_seed: 1543201465, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:19,360 - INFO - Solver completed in 1.447152 seconds with status: 4
# 2024-08-16 23:21:19,360 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:21:19,368 - INFO - Baseline evaluation completed: min=0.81232, mean=1.7745722499999999, max=2.959044
# [I 2024-08-16 23:21:19,368] A new study created in memory with name: no-name-c56a3404-395e-4f6b-a93a-a88df5e9926c
# 2024-08-16 23:21:19,369 - INFO - Starting Optuna optimization.
# 2024-08-16 23:21:19,370 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:19,371 - INFO - Returning cached result.
# 2024-08-16 23:21:19,371 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:19,371 - INFO - Starting solver with random_seed: 557664996, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:20,776 - INFO - Solver completed in 1.40392 seconds with status: 4
# 2024-08-16 23:21:20,776 - INFO - Starting solver with random_seed: 2096914359, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:22,288 - INFO - Solver completed in 1.511359 seconds with status: 4
# 2024-08-16 23:21:22,289 - INFO - Starting solver with random_seed: 367923573, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:23,369 - INFO - Solver completed in 1.080246 seconds with status: 4
# 2024-08-16 23:21:23,370 - INFO - Starting solver with random_seed: 2089116455, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:25,078 - INFO - Solver completed in 1.707606 seconds with status: 4
# 2024-08-16 23:21:25,078 - INFO - Starting solver with random_seed: 987502012, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:26,433 - INFO - Solver completed in 1.354594 seconds with status: 4
# 2024-08-16 23:21:26,434 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:21:26,435] Trial 0 finished with value: 1.4115449999999998 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:26,445 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:26,446 - INFO - Returning cached result.
# 2024-08-16 23:21:26,446 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 7, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:26,446 - INFO - Starting solver with random_seed: 1632978949, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:29,467 - INFO - Solver completed in 3.020579 seconds with status: 2
# 2024-08-16 23:21:29,468 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:29,468 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:29,469] Trial 1 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 7, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:29,472 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:29,472 - INFO - Returning cached result.
# 2024-08-16 23:21:29,473 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'repair_hint': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:29,473 - INFO - Starting solver with random_seed: 1765589935, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:32,487 - INFO - Solver completed in 3.013415 seconds with status: 2
# 2024-08-16 23:21:32,487 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:32,487 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:32,488] Trial 2 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:32,492 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:32,493 - INFO - Returning cached result.
# 2024-08-16 23:21:32,493 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'lb_tree_search', 'probing'], 'search_branching': 1, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'symmetry_level': 0}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:32,493 - INFO - Starting solver with random_seed: 1710390133, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:34,462 - INFO - Solver completed in 1.968788 seconds with status: 4
# 2024-08-16 23:21:34,463 - INFO - Starting solver with random_seed: 337489730, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:37,480 - INFO - Solver completed in 3.016743 seconds with status: 2
# 2024-08-16 23:21:37,481 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:37,481 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:37,482] Trial 3 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 0}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:37,486 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:37,486 - INFO - Returning cached result.
# 2024-08-16 23:21:37,486 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 7, 'use_objective_lb_search': True, 'optimize_with_core': True, 'fp_rounding': 3, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:37,487 - INFO - Starting solver with random_seed: 181681066, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:38,806 - INFO - Solver completed in 1.318952 seconds with status: 4
# 2024-08-16 23:21:38,807 - INFO - Starting solver with random_seed: 1451035604, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:41,826 - INFO - Solver completed in 3.019513 seconds with status: 2
# 2024-08-16 23:21:41,827 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:41,827 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:41,828] Trial 4 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 7, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:41,831 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:41,832 - INFO - Returning cached result.
# 2024-08-16 23:21:41,832 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 6, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:41,832 - INFO - Starting solver with random_seed: 331880722, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:44,849 - INFO - Solver completed in 3.016883 seconds with status: 2
# 2024-08-16 23:21:44,850 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:44,850 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:44,851] Trial 5 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:44,854 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:44,854 - INFO - Returning cached result.
# 2024-08-16 23:21:44,855 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'reduced_costs', 'lb_tree_search', 'probing'], 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 2, 'add_objective_cut': True}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:44,855 - INFO - Starting solver with random_seed: 1848806344, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:47,879 - INFO - Solver completed in 3.023531 seconds with status: 2
# 2024-08-16 23:21:47,879 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:47,880 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:47,881] Trial 6 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:47,884 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:47,884 - INFO - Returning cached result.
# 2024-08-16 23:21:47,884 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 4, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'add_objective_cut': True, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:47,885 - INFO - Starting solver with random_seed: 1937763592, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:50,902 - INFO - Solver completed in 3.016986 seconds with status: 2
# 2024-08-16 23:21:50,902 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:50,903 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:50,904] Trial 7 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 4, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:50,907 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:50,907 - INFO - Returning cached result.
# 2024-08-16 23:21:50,907 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'quick_restart'], 'search_branching': 2, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:50,908 - INFO - Starting solver with random_seed: 794280270, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:53,930 - INFO - Solver completed in 3.022054 seconds with status: 2
# 2024-08-16 23:21:53,931 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:53,931 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:53,932] Trial 8 finished with value: 30.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:53,935 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:53,936 - INFO - Returning cached result.
# 2024-08-16 23:21:53,936 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'quick_restart'], 'search_branching': 3, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:53,936 - INFO - Starting solver with random_seed: 904541735, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:56,954 - INFO - Solver completed in 3.017171 seconds with status: 2
# 2024-08-16 23:21:56,954 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:21:56,955 - INFO - Returning knockout result.
# [I 2024-08-16 23:21:56,957] Trial 9 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:21:57,011 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:21:57,011 - INFO - Returning cached result.
# 2024-08-16 23:21:57,011 - INFO - Evaluating with params: {'clause_cleanup_protection': 2, 'max_presolve_iterations': 2, 'ignore_subsolvers': ['quick_restart_no_lp'], 'search_branching': 8, 'repair_hint': True, 'diversify_lns_params': True, 'polish_lp_solution': True, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:21:57,012 - INFO - Starting solver with random_seed: 1709137247, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:21:59,744 - INFO - Solver completed in 2.732118 seconds with status: 4
# 2024-08-16 23:21:59,745 - INFO - Starting solver with random_seed: 260645881, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:02,769 - INFO - Solver completed in 3.023553 seconds with status: 2
# 2024-08-16 23:22:02,769 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:22:02,769 - INFO - Returning knockout result.
# [I 2024-08-16 23:22:02,771] Trial 10 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:22:02,819 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:22:02,820 - INFO - Returning cached result.
# 2024-08-16 23:22:02,820 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 7, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'cut_level': 2, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:22:02,821 - INFO - Starting solver with random_seed: 440038513, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:05,125 - INFO - Solver completed in 2.30396 seconds with status: 4
# 2024-08-16 23:22:05,125 - INFO - Starting solver with random_seed: 1112517023, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:08,148 - INFO - Solver completed in 3.022497 seconds with status: 2
# 2024-08-16 23:22:08,149 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:22:08,149 - INFO - Returning knockout result.
# [I 2024-08-16 23:22:08,150] Trial 11 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 7, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:22:08,195 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:22:08,195 - INFO - Returning cached result.
# 2024-08-16 23:22:08,196 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 5, 'optimize_with_core': True, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:22:08,196 - INFO - Starting solver with random_seed: 1349918291, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:11,217 - INFO - Solver completed in 3.020518 seconds with status: 2
# 2024-08-16 23:22:11,217 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:22:11,217 - INFO - Returning knockout result.
# [I 2024-08-16 23:22:11,219] Trial 12 finished with value: 30.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 5, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:22:11,262 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:22:11,263 - INFO - Returning cached result.
# 2024-08-16 23:22:11,263 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'binary_minimization_algorithm': 3, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 7, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:22:11,263 - INFO - Starting solver with random_seed: 149879206, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:12,413 - INFO - Solver completed in 1.149701 seconds with status: 4
# 2024-08-16 23:22:12,414 - INFO - Starting solver with random_seed: 1012530201, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:14,445 - INFO - Solver completed in 2.030607 seconds with status: 4
# 2024-08-16 23:22:14,445 - INFO - Starting solver with random_seed: 1271273937, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:15,891 - INFO - Solver completed in 1.444953 seconds with status: 4
# 2024-08-16 23:22:15,891 - INFO - Starting solver with random_seed: 408521429, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:17,631 - INFO - Solver completed in 1.739146 seconds with status: 4
# 2024-08-16 23:22:17,631 - INFO - Starting solver with random_seed: 1477714287, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:18,639 - INFO - Solver completed in 1.007069 seconds with status: 4
# 2024-08-16 23:22:18,639 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:22:18,640] Trial 13 finished with value: 1.4742951999999998 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 7, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:22:18,684 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:22:18,684 - INFO - Returning cached result.
# 2024-08-16 23:22:18,685 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'binary_minimization_algorithm': 3, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'ignore_subsolvers': ['default_lp', 'max_lp', 'pseudo_costs', 'quick_restart_no_lp'], 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:22:18,685 - INFO - Starting solver with random_seed: 701584452, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:21,704 - INFO - Solver completed in 3.018595 seconds with status: 2
# 2024-08-16 23:22:21,704 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-16 23:22:21,705 - INFO - Returning knockout result.
# [I 2024-08-16 23:22:21,706] Trial 14 finished with value: 30.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:22:21,753 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:22:21,753 - INFO - Returning cached result.
# 2024-08-16 23:22:21,754 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'binary_minimization_algorithm': 3, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['no_lp', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 3, 'diversify_lns_params': True, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 3.1737164
# 2024-08-16 23:22:21,754 - INFO - Starting solver with random_seed: 661620169, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:23,391 - INFO - Solver completed in 1.636895 seconds with status: 4
# 2024-08-16 23:22:23,392 - INFO - Starting solver with random_seed: 698354135, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:24,886 - INFO - Solver completed in 1.494296 seconds with status: 4
# 2024-08-16 23:22:24,887 - INFO - Starting solver with random_seed: 2005283782, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:26,639 - INFO - Solver completed in 1.752253 seconds with status: 4
# 2024-08-16 23:22:26,640 - INFO - Starting solver with random_seed: 234302337, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:28,192 - INFO - Solver completed in 1.551761 seconds with status: 4
# 2024-08-16 23:22:28,193 - INFO - Starting solver with random_seed: 958444931, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:22:29,997 - INFO - Solver completed in 1.804314 seconds with status: 4
# 2024-08-16 23:22:29,998 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:22:29,999] Trial 15 finished with value: 1.6479038 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 0 with value: 1.4115449999999998.
# 2024-08-16 23:22:30,045 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:22:30,045 - INFO - Returning cached result.
# ...
# 2024-08-16 23:25:49,779 - INFO - Starting solver with random_seed: 946578664, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:50,478 - INFO - Solver completed in 0.698908 seconds with status: 4
# 2024-08-16 23:25:50,479 - INFO - Starting solver with random_seed: 277257537, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:51,383 - INFO - Solver completed in 0.904024 seconds with status: 4
# 2024-08-16 23:25:51,384 - INFO - Starting solver with random_seed: 1211400230, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:51,967 - INFO - Solver completed in 0.582851 seconds with status: 4
# 2024-08-16 23:25:51,968 - INFO - Starting solver with random_seed: 289241587, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:52,607 - INFO - Solver completed in 0.638507 seconds with status: 4
# 2024-08-16 23:25:52,607 - INFO - Starting solver with random_seed: 1954011591, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:53,123 - INFO - Solver completed in 0.515639 seconds with status: 4
# 2024-08-16 23:25:53,124 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:25:53,124 - INFO - Parameter 'cut_level' can be dropped from the optimized parameters.
# 2024-08-16 23:25:53,124 - INFO - Evaluating resetting parameter 'max_all_diff_cut_size' to default...
# 2024-08-16 23:25:53,124 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 7, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'symmetry_level': 0}, num_runs: 5, knockout_score: None
# 2024-08-16 23:25:53,125 - INFO - Starting solver with random_seed: 1889886236, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:53,733 - INFO - Solver completed in 0.60821 seconds with status: 4
# 2024-08-16 23:25:53,734 - INFO - Starting solver with random_seed: 548436395, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:54,862 - INFO - Solver completed in 1.127924 seconds with status: 4
# 2024-08-16 23:25:54,863 - INFO - Starting solver with random_seed: 288858270, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:55,540 - INFO - Solver completed in 0.67711 seconds with status: 4
# 2024-08-16 23:25:55,541 - INFO - Starting solver with random_seed: 165181236, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:56,449 - INFO - Solver completed in 0.907628 seconds with status: 4
# 2024-08-16 23:25:56,449 - INFO - Starting solver with random_seed: 1079271723, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:57,164 - INFO - Solver completed in 0.714263 seconds with status: 4
# 2024-08-16 23:25:57,164 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:25:57,165 - INFO - Parameter 'max_all_diff_cut_size' can be dropped from the optimized parameters.
# 2024-08-16 23:25:57,165 - INFO - Evaluating resetting parameter 'symmetry_level' to default...
# 2024-08-16 23:25:57,165 - INFO - Evaluating with params: {'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 7, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-16 23:25:57,166 - INFO - Starting solver with random_seed: 1991659593, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:58,186 - INFO - Solver completed in 1.020472 seconds with status: 4
# 2024-08-16 23:25:58,187 - INFO - Starting solver with random_seed: 2045631294, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:58,868 - INFO - Solver completed in 0.680696 seconds with status: 4
# 2024-08-16 23:25:58,869 - INFO - Starting solver with random_seed: 654812284, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:25:59,692 - INFO - Solver completed in 0.822857 seconds with status: 4
# 2024-08-16 23:25:59,692 - INFO - Starting solver with random_seed: 1101486989, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:00,575 - INFO - Solver completed in 0.882572 seconds with status: 4
# 2024-08-16 23:26:00,576 - INFO - Starting solver with random_seed: 699076722, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:01,307 - INFO - Solver completed in 0.730644 seconds with status: 4
# 2024-08-16 23:26:01,308 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:26:01,308 - INFO - Parameter 'symmetry_level' can be dropped from the optimized parameters.
# 2024-08-16 23:26:01,308 - INFO - Evaluating with params: {'clause_cleanup_protection': 2, 'cp_model_probing_level': 0, 'search_branching': 7, 'feasibility_jump_linearization_level': 1}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:01,309 - INFO - Starting solver with random_seed: 1733125686, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:01,822 - INFO - Solver completed in 0.512941 seconds with status: 4
# 2024-08-16 23:26:01,822 - INFO - Starting solver with random_seed: 736134582, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:02,371 - INFO - Solver completed in 0.547981 seconds with status: 4
# 2024-08-16 23:26:02,371 - INFO - Starting solver with random_seed: 1931181071, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:02,961 - INFO - Solver completed in 0.589171 seconds with status: 4
# 2024-08-16 23:26:02,961 - INFO - Starting solver with random_seed: 1371530256, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:03,652 - INFO - Solver completed in 0.690844 seconds with status: 4
# 2024-08-16 23:26:03,653 - INFO - Starting solver with random_seed: 1216500231, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:04,234 - INFO - Solver completed in 0.580347 seconds with status: 4
# 2024-08-16 23:26:04,234 - INFO - Starting solver with random_seed: 971237502, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:04,810 - INFO - Solver completed in 0.575753 seconds with status: 4
# 2024-08-16 23:26:04,811 - INFO - Starting solver with random_seed: 1265846838, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:05,295 - INFO - Solver completed in 0.483476 seconds with status: 4
# 2024-08-16 23:26:05,295 - INFO - Starting solver with random_seed: 1577637317, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:05,817 - INFO - Solver completed in 0.520974 seconds with status: 4
# 2024-08-16 23:26:05,817 - INFO - Starting solver with random_seed: 1816734199, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:06,368 - INFO - Solver completed in 0.550616 seconds with status: 4
# 2024-08-16 23:26:06,369 - INFO - Starting solver with random_seed: 1714958836, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:06,871 - INFO - Solver completed in 0.502111 seconds with status: 4
# 2024-08-16 23:26:06,872 - INFO - Starting solver with random_seed: 1442833910, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:07,490 - INFO - Solver completed in 0.617444 seconds with status: 4
# 2024-08-16 23:26:07,490 - INFO - Starting solver with random_seed: 218975534, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:08,266 - INFO - Solver completed in 0.77502 seconds with status: 4
# 2024-08-16 23:26:08,266 - INFO - Starting solver with random_seed: 782850524, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:08,695 - INFO - Solver completed in 0.428454 seconds with status: 4
# 2024-08-16 23:26:08,696 - INFO - Starting solver with random_seed: 315131277, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:09,248 - INFO - Solver completed in 0.552251 seconds with status: 4
# 2024-08-16 23:26:09,249 - INFO - Starting solver with random_seed: 854781182, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:09,787 - INFO - Solver completed in 0.537615 seconds with status: 4
# 2024-08-16 23:26:09,787 - INFO - Starting solver with random_seed: 1609864347, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:10,418 - INFO - Solver completed in 0.630237 seconds with status: 4
# 2024-08-16 23:26:10,418 - INFO - Starting solver with random_seed: 1518697274, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:11,034 - INFO - Solver completed in 0.6159 seconds with status: 4
# 2024-08-16 23:26:11,035 - INFO - Starting solver with random_seed: 716363954, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:11,873 - INFO - Solver completed in 0.837205 seconds with status: 4
# 2024-08-16 23:26:11,873 - INFO - Starting solver with random_seed: 1285247800, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:12,271 - INFO - Solver completed in 0.396859 seconds with status: 4
# 2024-08-16 23:26:12,271 - INFO - Starting solver with random_seed: 1560682822, max_time_in_seconds: 3, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-16 23:26:13,005 - INFO - Solver completed in 0.733833 seconds with status: 4
# 2024-08-16 23:26:13,006 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:26:13,006 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter                            ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ clause_cleanup_protection            │   2   │    9.72%     │       0       │
# │ 2   │ cp_model_probing_level               │   0   │    38.57%    │       2       │
# │ 3   │ search_branching                     │   7   │    46.37%    │       0       │
# │ 4   │ feasibility_jump_linearization_level │   1   │    5.34%     │       2       │
# └─────┴──────────────────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. clause_cleanup_protection Specifies the level of protection against clause cleanup. The options are:
#
#  • 0 PROTECTION_NONE
#  • 1 PROTECTION_ALWAYS
#  • 2 PROTECTION_LBD
#
# 2. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
#
# 3. search_branching Defines the branching strategy the solver uses to navigate the search tree. The options are:
#
#  • 0 (AUTOMATIC_SEARCH): The solver automatically selects the most appropriate strategy.
#  • 1 (FIXED_SEARCH): Follows a fixed variable order, as specified by the user or the problem model.
#  • 2 (PORTFOLIO_SEARCH): Uses a combination of multiple strategies to explore the search space.
#  • 3 (LP_SEARCH): Branches based on the LP relaxation of the problem, leveraging the reduced costs of variables.
#  • 4 (PSEUDO_COST_SEARCH): Branches using pseudo-costs, which are estimates of the impact of branching decisions
#    based on past experiences.
#  • 5 (PORTFOLIO_WITH_QUICK_RESTART_SEARCH): Quickly explores different heuristics with low conflict limits, aiming
#    to find a good initial solution.
#  • 6 (HINT_SEARCH): Prioritizes decisions based on hints provided by the user or the problem model.
#  • 7 (PARTIAL_FIXED_SEARCH): Begins with a fixed strategy, then switches to automatic search for the remaining
#    decisions.
#  • 8 (RANDOMIZED_SEARCH): Introduces randomization into branching decisions to diversify the search.
#
# 4. feasibility_jump_linearization_level Linearization level for feasibility jump.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                 ┃ Mean ┃  Min ┃  Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━━━┩
# │ Default Metric Value   │ 1.77 │ 0.81 │ 2.96 │       20 │
# │ Optimized Metric Value │ 0.58 │  0.4 │ 0.84 │       20 │
# └────────────────────────┴──────┴──────┴──────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-16 23:26:13,035 - INFO - Hyperparameter tuning completed.
# 2024-08-16 23:26:13,036 - INFO - Tuning for time to optimal completed.

# %%
best = tune_for_quality_within_timelimit(
    model,
    max_time_in_seconds=0.5,
    obj_for_timeout=0,
    direction="maximize",
    n_samples_for_trial=5,  # Number of samples for each trial
    n_samples_for_verification=20,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-16 23:26:13,042 - INFO - Starting tuning for quality within time limit. Direction: maximize
# 2024-08-16 23:26:13,042 - INFO - Initialized Metric with direction: maximize
# 2024-08-16 23:26:13,043 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-16 23:26:13,043 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:13,044 - INFO - Starting solver with random_seed: 1004924649, max_time_in_seconds: 0.5
# 2024-08-16 23:26:13,560 - INFO - Solver found a solution with objective value: 131945.0
# 2024-08-16 23:26:13,560 - INFO - Starting solver with random_seed: 1466181255, max_time_in_seconds: 0.5
# 2024-08-16 23:26:14,077 - INFO - Solver found a solution with objective value: 131029.0
# 2024-08-16 23:26:14,077 - INFO - Starting solver with random_seed: 441107595, max_time_in_seconds: 0.5
# 2024-08-16 23:26:14,593 - INFO - Solver found a solution with objective value: 132140.0
# 2024-08-16 23:26:14,594 - INFO - Starting solver with random_seed: 1120868696, max_time_in_seconds: 0.5
# 2024-08-16 23:26:15,115 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:15,115 - INFO - Starting solver with random_seed: 871178060, max_time_in_seconds: 0.5
# 2024-08-16 23:26:15,633 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:15,634 - INFO - Starting solver with random_seed: 72334543, max_time_in_seconds: 0.5
# 2024-08-16 23:26:16,154 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:16,154 - INFO - Starting solver with random_seed: 1012834434, max_time_in_seconds: 0.5
# 2024-08-16 23:26:16,670 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-16 23:26:16,670 - INFO - Starting solver with random_seed: 1786114169, max_time_in_seconds: 0.5
# 2024-08-16 23:26:17,189 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:17,190 - INFO - Starting solver with random_seed: 809619474, max_time_in_seconds: 0.5
# 2024-08-16 23:26:17,709 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:17,710 - INFO - Starting solver with random_seed: 615016388, max_time_in_seconds: 0.5
# 2024-08-16 23:26:18,227 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:18,227 - INFO - Starting solver with random_seed: 821709887, max_time_in_seconds: 0.5
# 2024-08-16 23:26:18,743 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:18,743 - INFO - Starting solver with random_seed: 431064562, max_time_in_seconds: 0.5
# 2024-08-16 23:26:19,263 - INFO - Solver found a solution with objective value: 131354.0
# 2024-08-16 23:26:19,263 - INFO - Starting solver with random_seed: 385814216, max_time_in_seconds: 0.5
# 2024-08-16 23:26:19,782 - INFO - Solver found a solution with objective value: 130018.0
# 2024-08-16 23:26:19,783 - INFO - Starting solver with random_seed: 1602384765, max_time_in_seconds: 0.5
# 2024-08-16 23:26:20,299 - INFO - Solver found a solution with objective value: 130139.0
# 2024-08-16 23:26:20,300 - INFO - Starting solver with random_seed: 273276264, max_time_in_seconds: 0.5
# 2024-08-16 23:26:20,817 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:20,817 - INFO - Starting solver with random_seed: 959297823, max_time_in_seconds: 0.5
# 2024-08-16 23:26:21,333 - INFO - Solver found a solution with objective value: 131715.0
# 2024-08-16 23:26:21,334 - INFO - Starting solver with random_seed: 232896818, max_time_in_seconds: 0.5
# 2024-08-16 23:26:21,849 - INFO - Solver found a solution with objective value: 131369.0
# 2024-08-16 23:26:21,850 - INFO - Starting solver with random_seed: 80139825, max_time_in_seconds: 0.5
# 2024-08-16 23:26:22,373 - INFO - Solver found a solution with objective value: 132484.0
# 2024-08-16 23:26:22,374 - INFO - Starting solver with random_seed: 1811119183, max_time_in_seconds: 0.5
# 2024-08-16 23:26:22,891 - INFO - Solver found a solution with objective value: 131189.0
# 2024-08-16 23:26:22,892 - INFO - Starting solver with random_seed: 1621495986, max_time_in_seconds: 0.5
# 2024-08-16 23:26:23,425 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:23,426 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:26:23,426 - INFO - Baseline evaluation completed: min=130018.0, mean=132055.6, max=132805.0
# [I 2024-08-16 23:26:23,427] A new study created in memory with name: no-name-cf78dd1f-8105-4ba1-939c-077182aa58c6
# 2024-08-16 23:26:23,427 - INFO - Starting Optuna optimization.
# 2024-08-16 23:26:23,429 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:23,429 - INFO - Returning cached result.
# 2024-08-16 23:26:23,429 - INFO - Evaluating with params: {'ignore_subsolvers': []}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:23,429 - INFO - Starting solver with random_seed: 1172989445, max_time_in_seconds: 0.5
# 2024-08-16 23:26:23,947 - INFO - Solver found a solution with objective value: 131974.0
# 2024-08-16 23:26:23,947 - INFO - Starting solver with random_seed: 2082784781, max_time_in_seconds: 0.5
# 2024-08-16 23:26:24,464 - INFO - Solver found a solution with objective value: 132420.0
# 2024-08-16 23:26:24,465 - INFO - Starting solver with random_seed: 867130286, max_time_in_seconds: 0.5
# 2024-08-16 23:26:24,980 - INFO - Solver found a solution with objective value: 131790.0
# 2024-08-16 23:26:24,981 - INFO - Starting solver with random_seed: 789619172, max_time_in_seconds: 0.5
# 2024-08-16 23:26:25,498 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:25,498 - INFO - Starting solver with random_seed: 1048695958, max_time_in_seconds: 0.5
# 2024-08-16 23:26:26,015 - INFO - Solver found a solution with objective value: 130344.0
# 2024-08-16 23:26:26,016 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:26,017] Trial 0 finished with value: 131866.6 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 0 with value: 131866.6.
# 2024-08-16 23:26:26,020 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:26,020 - INFO - Returning cached result.
# 2024-08-16 23:26:26,021 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 3, 'repair_hint': True, 'use_lb_relax_lns': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 0}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:26,021 - INFO - Starting solver with random_seed: 1437101144, max_time_in_seconds: 0.5
# 2024-08-16 23:26:26,529 - INFO - Solver found a solution with objective value: 132715.0
# 2024-08-16 23:26:26,529 - INFO - Starting solver with random_seed: 258707285, max_time_in_seconds: 0.5
# 2024-08-16 23:26:26,979 - INFO - Solver found a solution with objective value: 132364.0
# 2024-08-16 23:26:26,979 - INFO - Starting solver with random_seed: 1781734189, max_time_in_seconds: 0.5
# 2024-08-16 23:26:27,497 - INFO - Solver found a solution with objective value: 131920.0
# 2024-08-16 23:26:27,498 - INFO - Starting solver with random_seed: 1485821253, max_time_in_seconds: 0.5
# 2024-08-16 23:26:28,009 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:28,010 - INFO - Starting solver with random_seed: 921633478, max_time_in_seconds: 0.5
# 2024-08-16 23:26:28,516 - INFO - Solver found a solution with objective value: 131675.0
# 2024-08-16 23:26:28,517 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:28,518] Trial 1 finished with value: 132295.8 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 1 with value: 132295.8.
# 2024-08-16 23:26:28,522 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:28,522 - INFO - Returning cached result.
# 2024-08-16 23:26:28,522 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'quick_restart'], 'search_branching': 8, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'diversify_lns_params': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:28,523 - INFO - Starting solver with random_seed: 1019144943, max_time_in_seconds: 0.5
# 2024-08-16 23:26:29,038 - INFO - Solver found a solution with objective value: 130737.0
# 2024-08-16 23:26:29,039 - INFO - Starting solver with random_seed: 155629536, max_time_in_seconds: 0.5
# 2024-08-16 23:26:29,555 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:29,556 - INFO - Starting solver with random_seed: 106245188, max_time_in_seconds: 0.5
# 2024-08-16 23:26:30,073 - INFO - Solver found a solution with objective value: 128920.0
# 2024-08-16 23:26:30,074 - INFO - Returning knockout result.
# [I 2024-08-16 23:26:30,075] Trial 2 finished with value: 128920.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 0, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 1 with value: 132295.8.
# 2024-08-16 23:26:30,078 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:30,079 - INFO - Returning cached result.
# 2024-08-16 23:26:30,079 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 100, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 2, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'add_objective_cut': True, 'symmetry_level': 1}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:30,079 - INFO - Starting solver with random_seed: 1431516930, max_time_in_seconds: 0.5
# 2024-08-16 23:26:30,592 - INFO - Solver found a solution with objective value: 127697.0
# 2024-08-16 23:26:30,593 - INFO - Returning knockout result.
# [I 2024-08-16 23:26:30,595] Trial 3 finished with value: 127697.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 2, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1}. Best is trial 1 with value: 132295.8.
# 2024-08-16 23:26:30,598 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:30,598 - INFO - Returning cached result.
# 2024-08-16 23:26:30,598 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 1, 'repair_hint': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 2}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:30,598 - INFO - Starting solver with random_seed: 761643978, max_time_in_seconds: 0.5
# 2024-08-16 23:26:31,121 - INFO - Solver found a solution with objective value: 132453.0
# 2024-08-16 23:26:31,122 - INFO - Starting solver with random_seed: 2073866604, max_time_in_seconds: 0.5
# 2024-08-16 23:26:31,634 - INFO - Solver found a solution with objective value: 132093.0
# 2024-08-16 23:26:31,634 - INFO - Starting solver with random_seed: 2005679207, max_time_in_seconds: 0.5
# 2024-08-16 23:26:32,149 - INFO - Solver found a solution with objective value: 131269.0
# 2024-08-16 23:26:32,149 - INFO - Starting solver with random_seed: 61209865, max_time_in_seconds: 0.5
# 2024-08-16 23:26:32,664 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-16 23:26:32,665 - INFO - Starting solver with random_seed: 513938709, max_time_in_seconds: 0.5
# 2024-08-16 23:26:33,177 - INFO - Solver found a solution with objective value: 132368.0
# 2024-08-16 23:26:33,177 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:33,178] Trial 4 finished with value: 132133.6 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 1 with value: 132295.8.
# 2024-08-16 23:26:33,181 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:33,181 - INFO - Returning cached result.
# 2024-08-16 23:26:33,182 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 4, 'use_lns_only': True, 'use_lb_relax_lns': True, 'feasibility_jump_linearization_level': 0, 'diversify_lns_params': True, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:33,182 - INFO - Starting solver with random_seed: 1273432323, max_time_in_seconds: 0.5
# 2024-08-16 23:26:33,707 - INFO - Solver found a solution with objective value: 127783.0
# 2024-08-16 23:26:33,707 - INFO - Returning knockout result.
# [I 2024-08-16 23:26:33,708] Trial 5 finished with value: 127783.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 1 with value: 132295.8.
# 2024-08-16 23:26:33,711 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:33,712 - INFO - Returning cached result.
# 2024-08-16 23:26:33,712 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 3, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:33,712 - INFO - Starting solver with random_seed: 102251382, max_time_in_seconds: 0.5
# 2024-08-16 23:26:34,234 - INFO - Solver found a solution with objective value: 132314.0
# 2024-08-16 23:26:34,234 - INFO - Starting solver with random_seed: 836982153, max_time_in_seconds: 0.5
# 2024-08-16 23:26:34,747 - INFO - Solver found a solution with objective value: 129512.0
# 2024-08-16 23:26:34,748 - INFO - Returning knockout result.
# [I 2024-08-16 23:26:34,749] Trial 6 finished with value: 129512.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1}. Best is trial 1 with value: 132295.8.
# 2024-08-16 23:26:34,753 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:34,753 - INFO - Returning cached result.
# 2024-08-16 23:26:34,753 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:34,754 - INFO - Starting solver with random_seed: 500694818, max_time_in_seconds: 0.5
# 2024-08-16 23:26:35,267 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:35,267 - INFO - Starting solver with random_seed: 2125284305, max_time_in_seconds: 0.5
# 2024-08-16 23:26:35,779 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:35,779 - INFO - Starting solver with random_seed: 569732880, max_time_in_seconds: 0.5
# 2024-08-16 23:26:36,290 - INFO - Solver found a solution with objective value: 132199.0
# 2024-08-16 23:26:36,290 - INFO - Starting solver with random_seed: 1262528107, max_time_in_seconds: 0.5
# 2024-08-16 23:26:36,806 - INFO - Solver found a solution with objective value: 131609.0
# 2024-08-16 23:26:36,807 - INFO - Starting solver with random_seed: 936585506, max_time_in_seconds: 0.5
# 2024-08-16 23:26:37,319 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:37,320 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:37,320] Trial 7 finished with value: 132444.6 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 1}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:37,323 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:37,324 - INFO - Returning cached result.
# 2024-08-16 23:26:37,324 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 8, 'use_lns_only': True, 'use_lb_relax_lns': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 2}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:37,324 - INFO - Starting solver with random_seed: 2074870222, max_time_in_seconds: 0.5
# 2024-08-16 23:26:37,837 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 23:26:37,837 - INFO - Starting solver with random_seed: 176883498, max_time_in_seconds: 0.5
# 2024-08-16 23:26:38,351 - INFO - Solver found a solution with objective value: 132128.0
# 2024-08-16 23:26:38,352 - INFO - Starting solver with random_seed: 166319436, max_time_in_seconds: 0.5
# 2024-08-16 23:26:38,862 - INFO - Solver found a solution with objective value: 128858.0
# 2024-08-16 23:26:38,863 - INFO - Returning knockout result.
# [I 2024-08-16 23:26:38,864] Trial 8 finished with value: 128858.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 2}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:38,867 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:38,867 - INFO - Returning cached result.
# 2024-08-16 23:26:38,867 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 6, 'use_lns_only': True, 'use_objective_lb_search': True, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 0, 'max_all_diff_cut_size': 128}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:38,868 - INFO - Starting solver with random_seed: 2105625768, max_time_in_seconds: 0.5
# 2024-08-16 23:26:39,377 - INFO - Solver found a solution with objective value: 132370.0
# 2024-08-16 23:26:39,378 - INFO - Starting solver with random_seed: 13102526, max_time_in_seconds: 0.5
# 2024-08-16 23:26:39,888 - INFO - Solver found a solution with objective value: 132385.0
# 2024-08-16 23:26:39,889 - INFO - Starting solver with random_seed: 5777313, max_time_in_seconds: 0.5
# 2024-08-16 23:26:40,399 - INFO - Solver found a solution with objective value: 131130.0
# 2024-08-16 23:26:40,400 - INFO - Starting solver with random_seed: 1592876804, max_time_in_seconds: 0.5
# 2024-08-16 23:26:40,909 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 23:26:40,910 - INFO - Starting solver with random_seed: 1286418693, max_time_in_seconds: 0.5
# 2024-08-16 23:26:41,420 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:41,421 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:41,422] Trial 9 finished with value: 132220.8 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 2}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:41,464 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:41,464 - INFO - Returning cached result.
# 2024-08-16 23:26:41,464 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:41,464 - INFO - Starting solver with random_seed: 1951362345, max_time_in_seconds: 0.5
# 2024-08-16 23:26:41,974 - INFO - Solver found a solution with objective value: 132375.0
# 2024-08-16 23:26:41,975 - INFO - Starting solver with random_seed: 1304690803, max_time_in_seconds: 0.5
# 2024-08-16 23:26:42,484 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:42,485 - INFO - Starting solver with random_seed: 2111205307, max_time_in_seconds: 0.5
# 2024-08-16 23:26:42,997 - INFO - Solver found a solution with objective value: 131219.0
# 2024-08-16 23:26:42,997 - INFO - Starting solver with random_seed: 235940737, max_time_in_seconds: 0.5
# 2024-08-16 23:26:43,508 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:26:43,509 - INFO - Starting solver with random_seed: 1995755097, max_time_in_seconds: 0.5
# 2024-08-16 23:26:44,020 - INFO - Solver found a solution with objective value: 132325.0
# 2024-08-16 23:26:44,021 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:44,022] Trial 10 finished with value: 132305.8 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:44,066 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:44,066 - INFO - Returning cached result.
# 2024-08-16 23:26:44,067 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:44,067 - INFO - Returning cached result.
# [I 2024-08-16 23:26:44,068] Trial 11 finished with value: 132305.8 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:44,112 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:44,113 - INFO - Returning cached result.
# 2024-08-16 23:26:44,113 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:44,113 - INFO - Starting solver with random_seed: 1358270574, max_time_in_seconds: 0.5
# 2024-08-16 23:26:44,627 - INFO - Solver found a solution with objective value: 132384.0
# 2024-08-16 23:26:44,627 - INFO - Starting solver with random_seed: 1807799199, max_time_in_seconds: 0.5
# 2024-08-16 23:26:45,137 - INFO - Solver found a solution with objective value: 129413.0
# 2024-08-16 23:26:45,138 - INFO - Returning knockout result.
# [I 2024-08-16 23:26:45,139] Trial 12 finished with value: 129413.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:45,188 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:45,188 - INFO - Returning cached result.
# 2024-08-16 23:26:45,188 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 7, 'repair_hint': True, 'use_lns_only': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:45,189 - INFO - Starting solver with random_seed: 699278747, max_time_in_seconds: 0.5
# 2024-08-16 23:26:45,703 - INFO - Solver found a solution with objective value: 131609.0
# 2024-08-16 23:26:45,704 - INFO - Starting solver with random_seed: 328632344, max_time_in_seconds: 0.5
# 2024-08-16 23:26:46,215 - INFO - Solver found a solution with objective value: 132405.0
# 2024-08-16 23:26:46,216 - INFO - Starting solver with random_seed: 1474844894, max_time_in_seconds: 0.5
# 2024-08-16 23:26:46,727 - INFO - Solver found a solution with objective value: 132145.0
# 2024-08-16 23:26:46,728 - INFO - Starting solver with random_seed: 80051046, max_time_in_seconds: 0.5
# 2024-08-16 23:26:47,238 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-16 23:26:47,239 - INFO - Starting solver with random_seed: 231078181, max_time_in_seconds: 0.5
# 2024-08-16 23:26:47,750 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-16 23:26:47,750 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:47,751] Trial 13 finished with value: 132235.4 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 7, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:47,794 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-16 23:26:47,795 - INFO - Returning cached result.
# 2024-08-16 23:26:47,795 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 5, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 0}, num_runs: 5, knockout_score: 129739.3
# 2024-08-16 23:26:47,796 - INFO - Starting solver with random_seed: 2055345403, max_time_in_seconds: 0.5
# 2024-08-16 23:26:48,307 - INFO - Solver found a solution with objective value: 132144.0
# 2024-08-16 23:26:48,308 - INFO - Starting solver with random_seed: 177236118, max_time_in_seconds: 0.5
# 2024-08-16 23:26:48,820 - INFO - Solver found a solution with objective value: 132149.0
# 2024-08-16 23:26:48,820 - INFO - Starting solver with random_seed: 1552992622, max_time_in_seconds: 0.5
# 2024-08-16 23:26:49,332 - INFO - Solver found a solution with objective value: 132275.0
# 2024-08-16 23:26:49,333 - INFO - Starting solver with random_seed: 49690632, max_time_in_seconds: 0.5
# 2024-08-16 23:26:49,844 - INFO - Solver found a solution with objective value: 132219.0
# 2024-08-16 23:26:49,844 - INFO - Starting solver with random_seed: 1796675232, max_time_in_seconds: 0.5
# 2024-08-16 23:26:50,356 - INFO - Solver found a solution with objective value: 132093.0
# 2024-08-16 23:26:50,356 - INFO - Evaluation completed and result cached.
# [I 2024-08-16 23:26:50,357] Trial 14 finished with value: 132176.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 5, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 0}. Best is trial 7 with value: 132444.6.
# 2024-08-16 23:26:50,401 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# ...
# 2024-08-16 23:29:00,613 - INFO - Solver found a solution with objective value: 132085.0
# 2024-08-16 23:29:00,613 - INFO - Starting solver with random_seed: 535634542, max_time_in_seconds: 0.5
# 2024-08-16 23:29:01,125 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:01,126 - INFO - Starting solver with random_seed: 441563127, max_time_in_seconds: 0.5
# 2024-08-16 23:29:01,638 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:01,639 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:29:01,639 - INFO - Parameter 'linearization_level' can be dropped from the optimized parameters.
# 2024-08-16 23:29:01,639 - INFO - Evaluating resetting parameter 'add_objective_cut' to default...
# 2024-08-16 23:29:01,639 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: None
# 2024-08-16 23:29:01,640 - INFO - Starting solver with random_seed: 160655011, max_time_in_seconds: 0.5
# 2024-08-16 23:29:02,152 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:02,153 - INFO - Starting solver with random_seed: 1819779622, max_time_in_seconds: 0.5
# 2024-08-16 23:29:02,665 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:02,666 - INFO - Starting solver with random_seed: 467775846, max_time_in_seconds: 0.5
# 2024-08-16 23:29:03,178 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:03,179 - INFO - Starting solver with random_seed: 691716752, max_time_in_seconds: 0.5
# 2024-08-16 23:29:03,691 - INFO - Solver found a solution with objective value: 132199.0
# 2024-08-16 23:29:03,692 - INFO - Starting solver with random_seed: 1540830040, max_time_in_seconds: 0.5
# 2024-08-16 23:29:04,205 - INFO - Solver found a solution with objective value: 132765.0
# 2024-08-16 23:29:04,206 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:29:04,206 - INFO - Parameter 'add_objective_cut' can be dropped from the optimized parameters.
# 2024-08-16 23:29:04,206 - INFO - Evaluating resetting parameter 'cut_level' to default...
# 2024-08-16 23:29:04,207 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 5, knockout_score: None
# 2024-08-16 23:29:04,207 - INFO - Starting solver with random_seed: 1046999563, max_time_in_seconds: 0.5
# 2024-08-16 23:29:04,718 - INFO - Solver found a solution with objective value: 132414.0
# 2024-08-16 23:29:04,719 - INFO - Starting solver with random_seed: 1130498101, max_time_in_seconds: 0.5
# 2024-08-16 23:29:05,231 - INFO - Solver found a solution with objective value: 132375.0
# 2024-08-16 23:29:05,232 - INFO - Starting solver with random_seed: 1192331248, max_time_in_seconds: 0.5
# 2024-08-16 23:29:05,745 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:05,746 - INFO - Starting solver with random_seed: 735609093, max_time_in_seconds: 0.5
# 2024-08-16 23:29:06,258 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:06,258 - INFO - Starting solver with random_seed: 203243098, max_time_in_seconds: 0.5
# 2024-08-16 23:29:06,771 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:06,772 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:29:06,772 - INFO - Parameter 'cut_level' can be dropped from the optimized parameters.
# 2024-08-16 23:29:06,772 - INFO - Evaluating resetting parameter 'max_all_diff_cut_size' to default...
# 2024-08-16 23:29:06,773 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 1}, num_runs: 5, knockout_score: None
# 2024-08-16 23:29:06,773 - INFO - Starting solver with random_seed: 1309189046, max_time_in_seconds: 0.5
# 2024-08-16 23:29:07,286 - INFO - Solver found a solution with objective value: 131994.0
# 2024-08-16 23:29:07,286 - INFO - Starting solver with random_seed: 1764551037, max_time_in_seconds: 0.5
# 2024-08-16 23:29:07,799 - INFO - Solver found a solution with objective value: 132595.0
# 2024-08-16 23:29:07,800 - INFO - Starting solver with random_seed: 949930922, max_time_in_seconds: 0.5
# 2024-08-16 23:29:08,312 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:08,312 - INFO - Starting solver with random_seed: 1797164056, max_time_in_seconds: 0.5
# 2024-08-16 23:29:08,823 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:08,824 - INFO - Starting solver with random_seed: 1019856202, max_time_in_seconds: 0.5
# 2024-08-16 23:29:09,336 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:09,336 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:29:09,337 - INFO - Parameter 'max_all_diff_cut_size' can be dropped from the optimized parameters.
# 2024-08-16 23:29:09,337 - INFO - Evaluating resetting parameter 'symmetry_level' to default...
# 2024-08-16 23:29:09,337 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 5, knockout_score: None
# 2024-08-16 23:29:09,338 - INFO - Starting solver with random_seed: 856770991, max_time_in_seconds: 0.5
# 2024-08-16 23:29:09,849 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:09,849 - INFO - Starting solver with random_seed: 2109980675, max_time_in_seconds: 0.5
# 2024-08-16 23:29:10,362 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:10,362 - INFO - Starting solver with random_seed: 1051709884, max_time_in_seconds: 0.5
# 2024-08-16 23:29:10,874 - INFO - Solver found a solution with objective value: 132375.0
# 2024-08-16 23:29:10,875 - INFO - Starting solver with random_seed: 1543430087, max_time_in_seconds: 0.5
# 2024-08-16 23:29:11,386 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:11,387 - INFO - Starting solver with random_seed: 475658163, max_time_in_seconds: 0.5
# 2024-08-16 23:29:11,898 - INFO - Solver found a solution with objective value: 132805.0
# 2024-08-16 23:29:11,899 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:29:11,900 - INFO - Parameter 'symmetry_level' can be dropped from the optimized parameters.
# 2024-08-16 23:29:11,900 - INFO - Evaluating with params: {'use_lns_only': True}, num_runs: 20, knockout_score: None
# 2024-08-16 23:29:11,900 - INFO - Starting solver with random_seed: 626470829, max_time_in_seconds: 0.5
# 2024-08-16 23:29:12,434 - INFO - Solver found a solution with objective value: 131999.0
# 2024-08-16 23:29:12,435 - INFO - Starting solver with random_seed: 431873175, max_time_in_seconds: 0.5
# 2024-08-16 23:29:12,946 - INFO - Solver found a solution with objective value: 132283.0
# 2024-08-16 23:29:12,947 - INFO - Starting solver with random_seed: 870584509, max_time_in_seconds: 0.5
# 2024-08-16 23:29:13,460 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-16 23:29:13,461 - INFO - Starting solver with random_seed: 1701973712, max_time_in_seconds: 0.5
# 2024-08-16 23:29:13,976 - INFO - Solver found a solution with objective value: 131995.0
# 2024-08-16 23:29:13,977 - INFO - Starting solver with random_seed: 212102025, max_time_in_seconds: 0.5
# 2024-08-16 23:29:14,486 - INFO - Solver found a solution with objective value: 132420.0
# 2024-08-16 23:29:14,487 - INFO - Starting solver with random_seed: 340811513, max_time_in_seconds: 0.5
# 2024-08-16 23:29:15,000 - INFO - Solver found a solution with objective value: 132220.0
# 2024-08-16 23:29:15,001 - INFO - Starting solver with random_seed: 1010120050, max_time_in_seconds: 0.5
# 2024-08-16 23:29:15,511 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-16 23:29:15,512 - INFO - Starting solver with random_seed: 418101606, max_time_in_seconds: 0.5
# 2024-08-16 23:29:16,023 - INFO - Solver found a solution with objective value: 132470.0
# 2024-08-16 23:29:16,023 - INFO - Starting solver with random_seed: 1698755942, max_time_in_seconds: 0.5
# 2024-08-16 23:29:16,538 - INFO - Solver found a solution with objective value: 132349.0
# 2024-08-16 23:29:16,539 - INFO - Starting solver with random_seed: 1727404515, max_time_in_seconds: 0.5
# 2024-08-16 23:29:17,073 - INFO - Solver found a solution with objective value: 132509.0
# 2024-08-16 23:29:17,074 - INFO - Starting solver with random_seed: 1258506138, max_time_in_seconds: 0.5
# 2024-08-16 23:29:17,591 - INFO - Solver found a solution with objective value: 131583.0
# 2024-08-16 23:29:17,592 - INFO - Starting solver with random_seed: 1998714593, max_time_in_seconds: 0.5
# 2024-08-16 23:29:18,113 - INFO - Solver found a solution with objective value: 127767.0
# 2024-08-16 23:29:18,114 - INFO - Starting solver with random_seed: 90757098, max_time_in_seconds: 0.5
# 2024-08-16 23:29:18,625 - INFO - Solver found a solution with objective value: 132470.0
# 2024-08-16 23:29:18,626 - INFO - Starting solver with random_seed: 1364219637, max_time_in_seconds: 0.5
# 2024-08-16 23:29:19,138 - INFO - Solver found a solution with objective value: 128844.0
# 2024-08-16 23:29:19,138 - INFO - Starting solver with random_seed: 302306506, max_time_in_seconds: 0.5
# 2024-08-16 23:29:19,651 - INFO - Solver found a solution with objective value: 132335.0
# 2024-08-16 23:29:19,652 - INFO - Starting solver with random_seed: 862080542, max_time_in_seconds: 0.5
# 2024-08-16 23:29:20,164 - INFO - Solver found a solution with objective value: 128334.0
# 2024-08-16 23:29:20,165 - INFO - Starting solver with random_seed: 1882012835, max_time_in_seconds: 0.5
# 2024-08-16 23:29:20,692 - INFO - Solver found a solution with objective value: 132485.0
# 2024-08-16 23:29:20,692 - INFO - Starting solver with random_seed: 80175857, max_time_in_seconds: 0.5
# 2024-08-16 23:29:21,201 - INFO - Solver found a solution with objective value: 131333.0
# 2024-08-16 23:29:21,202 - INFO - Starting solver with random_seed: 1189191603, max_time_in_seconds: 0.5
# 2024-08-16 23:29:21,712 - INFO - Solver found a solution with objective value: 132375.0
# 2024-08-16 23:29:21,712 - INFO - Starting solver with random_seed: 1384944775, max_time_in_seconds: 0.5
# 2024-08-16 23:29:22,223 - INFO - Solver found a solution with objective value: 132715.0
# 2024-08-16 23:29:22,224 - INFO - Evaluation completed and result cached.
# 2024-08-16 23:29:22,224 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter    ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ use_lns_only │ True  │   100.00%    │     False     │
# └─────┴──────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. use_lns_only When enabled, the solver uses only Large Neighborhood Search (LNS) heuristics, without performing a
# full global search. LNS is beneficial in scenarios where finding improvements quickly is more important than
# exploring all possibilities for an optimal solution.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                 ┃     Mean ┃      Min ┃      Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━┩
# │ Default Metric Value   │ 132055.6 │ 130018.0 │ 132805.0 │       20 │
# │ Optimized Metric Value │ 131675.2 │ 127767.0 │ 132715.0 │       20 │
# └────────────────────────┴──────────┴──────────┴──────────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-16 23:29:22,234 - INFO - Hyperparameter tuning completed.
# 2024-08-16 23:29:22,235 - INFO - Tuning for quality within time limit completed.
