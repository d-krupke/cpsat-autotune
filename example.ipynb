# %%
from cpsat_autotune import (
    tune_for_quality_within_timelimit,
    import_model,
    tune_time_to_optimal,
    tune_for_gap_within_timelimit
)

# %%
model = import_model("models/packing_model.pb")

# %%
best = tune_time_to_optimal(
    model,
    max_time_in_seconds=5,  # Enter a time limit slightly above what the solver with default parameters needs
    n_samples_for_trial=5,  # Number of samples for each trial
    n_samples_for_verification=20,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-29 19:47:47,058 - INFO - Starting tuning to minimize time to optimal solution.
# 2024-08-29 19:47:47,059 - INFO - Initialized Metric with direction: minimize
# 2024-08-29 19:47:47,059 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-29 19:47:47,059 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:47:47,060 - INFO - Starting solver with random_seed: 1921403228, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:47:50,781 - INFO - Solver completed in 3.72131 seconds with status: 4
# 2024-08-29 19:47:50,782 - INFO - Starting solver with random_seed: 1899129778, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:47:51,704 - INFO - Solver completed in 0.921955 seconds with status: 4
# 2024-08-29 19:47:51,705 - INFO - Starting solver with random_seed: 809366781, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:47:56,746 - INFO - Solver completed in 5.040694 seconds with status: 0
# 2024-08-29 19:47:56,746 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:47:56,747 - INFO - Starting solver with random_seed: 632559775, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:47:57,405 - INFO - Solver completed in 0.658114 seconds with status: 4
# 2024-08-29 19:47:57,406 - INFO - Starting solver with random_seed: 298089780, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:47:59,211 - INFO - Solver completed in 1.805401 seconds with status: 4
# 2024-08-29 19:47:59,212 - INFO - Starting solver with random_seed: 1316193353, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:02,712 - INFO - Solver completed in 3.499972 seconds with status: 4
# 2024-08-29 19:48:02,713 - INFO - Starting solver with random_seed: 689014513, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:06,232 - INFO - Solver completed in 3.518548 seconds with status: 4
# 2024-08-29 19:48:06,232 - INFO - Starting solver with random_seed: 258406982, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:11,269 - INFO - Solver completed in 5.036703 seconds with status: 0
# 2024-08-29 19:48:11,270 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:48:11,270 - INFO - Starting solver with random_seed: 1345120819, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:13,759 - INFO - Solver completed in 2.488611 seconds with status: 4
# 2024-08-29 19:48:13,759 - INFO - Starting solver with random_seed: 1508874598, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:17,065 - INFO - Solver completed in 3.305046 seconds with status: 4
# 2024-08-29 19:48:17,065 - INFO - Starting solver with random_seed: 1318745014, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:22,092 - INFO - Solver completed in 5.026462 seconds with status: 0
# 2024-08-29 19:48:22,093 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:48:22,093 - INFO - Starting solver with random_seed: 1099683426, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:27,134 - INFO - Solver completed in 5.040281 seconds with status: 0
# 2024-08-29 19:48:27,134 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:48:27,135 - INFO - Starting solver with random_seed: 1000838201, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:32,176 - INFO - Solver completed in 5.041423 seconds with status: 0
# 2024-08-29 19:48:32,177 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:48:32,177 - INFO - Starting solver with random_seed: 287326686, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:33,780 - INFO - Solver completed in 1.60316 seconds with status: 4
# 2024-08-29 19:48:33,781 - INFO - Starting solver with random_seed: 1255578333, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:36,448 - INFO - Solver completed in 2.666221 seconds with status: 4
# 2024-08-29 19:48:36,448 - INFO - Starting solver with random_seed: 441872315, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:38,793 - INFO - Solver completed in 2.344131 seconds with status: 4
# 2024-08-29 19:48:38,793 - INFO - Starting solver with random_seed: 1146452394, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:40,822 - INFO - Solver completed in 2.028679 seconds with status: 4
# 2024-08-29 19:48:40,823 - INFO - Starting solver with random_seed: 1174804936, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:43,099 - INFO - Solver completed in 2.275175 seconds with status: 4
# 2024-08-29 19:48:43,099 - INFO - Starting solver with random_seed: 583448353, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:46,585 - INFO - Solver completed in 3.485915 seconds with status: 4
# 2024-08-29 19:48:46,586 - INFO - Starting solver with random_seed: 995834855, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:46,745 - INFO - Solver completed in 0.159137 seconds with status: 4
# 2024-08-29 19:48:46,746 - INFO - Evaluation completed and result cached.
# 2024-08-29 19:48:46,746 - INFO - Baseline evaluation completed: min=0.159137, mean=14.224068749999997, max=50.0
# [I 2024-08-29 19:48:46,747] A new study created in memory with name: no-name-bf25d51d-1dd8-44c6-8db9-e6d31f055a9a
# 2024-08-29 19:48:46,747 - INFO - Starting Optuna optimization.
# 2024-08-29 19:48:46,749 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:48:46,749 - INFO - Returning cached result.
# 2024-08-29 19:48:46,749 - INFO - Evaluating with params: {}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:48:46,749 - INFO - Returning cached result.
# 2024-08-29 19:48:46,750 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-29 19:48:46,750 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: 54.9840863
# 2024-08-29 19:48:46,750 - INFO - Returning cached result.
# [I 2024-08-29 19:48:46,751] Trial 0 finished with value: 14.224068749999997 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2, 'num_workers': 0, 'use_strong_propagation_in_disjunctive': False, 'use_area_energetic_reasoning_in_no_overlap_2d': False, 'use_energetic_reasoning_in_no_overlap_2d': False, 'use_timetabling_in_no_overlap_2d': False, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 0}. Best is trial 0 with value: 14.224068749999997.
# 2024-08-29 19:48:46,755 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:48:46,756 - INFO - Returning cached result.
# 2024-08-29 19:48:46,756 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'max_presolve_iterations': 1, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'linearization_level': 0, 'add_objective_cut': True, 'num_workers': 4, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:48:46,756 - INFO - Starting solver with random_seed: 514091496, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:51,767 - INFO - Solver completed in 5.010911 seconds with status: 0
# 2024-08-29 19:48:51,768 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:48:51,768 - INFO - Starting solver with random_seed: 1018482413, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:48:56,779 - INFO - Solver completed in 5.010896 seconds with status: 0
# 2024-08-29 19:48:56,780 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:48:56,780 - INFO - Starting solver with random_seed: 1424200684, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:01,788 - INFO - Solver completed in 5.007123 seconds with status: 0
# 2024-08-29 19:49:01,788 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:01,789 - INFO - Starting solver with random_seed: 2133199429, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:06,795 - INFO - Solver completed in 5.005929 seconds with status: 0
# 2024-08-29 19:49:06,795 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:06,796 - INFO - Starting solver with random_seed: 1834993372, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:11,802 - INFO - Solver completed in 5.005845 seconds with status: 0
# 2024-08-29 19:49:11,802 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:11,803 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:49:11,804] Trial 1 finished with value: 50.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2, 'num_workers': 2, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': False, 'use_timetabling_in_no_overlap_2d': False, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 0}. Best is trial 0 with value: 14.224068749999997.
# 2024-08-29 19:49:11,807 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:49:11,807 - INFO - Returning cached result.
# 2024-08-29 19:49:11,808 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['default_lp', 'fixed', 'no_lp', 'max_lp', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'max_all_diff_cut_size': 128, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 5000}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:49:11,808 - INFO - Starting solver with random_seed: 642718166, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:16,825 - INFO - Solver completed in 5.016664 seconds with status: 0
# 2024-08-29 19:49:16,825 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:16,826 - INFO - Starting solver with random_seed: 464609345, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:21,837 - INFO - Solver completed in 5.011003 seconds with status: 0
# 2024-08-29 19:49:21,837 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:21,838 - INFO - Starting solver with random_seed: 1493583823, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:26,849 - INFO - Solver completed in 5.010784 seconds with status: 0
# 2024-08-29 19:49:26,849 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:26,850 - INFO - Starting solver with random_seed: 2555711, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:31,865 - INFO - Solver completed in 5.015358 seconds with status: 0
# 2024-08-29 19:49:31,866 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:31,866 - INFO - Starting solver with random_seed: 1302467012, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:36,879 - INFO - Solver completed in 5.01248 seconds with status: 0
# 2024-08-29 19:49:36,880 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:36,880 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:49:36,881] Trial 2 finished with value: 50.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 6, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 2, 'num_workers': 0, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': False, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 2}. Best is trial 0 with value: 14.224068749999997.
# 2024-08-29 19:49:36,885 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:49:36,885 - INFO - Returning cached result.
# 2024-08-29 19:49:36,885 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'probing'], 'search_branching': 2, 'use_objective_shaving_search': True, 'fp_rounding': 1, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128, 'symmetry_level': 0, 'num_workers': 8, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:49:36,886 - INFO - Starting solver with random_seed: 1140067482, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:37,283 - INFO - Solver completed in 0.397165 seconds with status: 4
# 2024-08-29 19:49:37,284 - INFO - Starting solver with random_seed: 1484906499, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:42,290 - INFO - Solver completed in 5.006529 seconds with status: 0
# 2024-08-29 19:49:42,291 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:42,291 - INFO - Starting solver with random_seed: 1764521257, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:47,246 - INFO - Solver completed in 4.953756 seconds with status: 4
# 2024-08-29 19:49:47,246 - INFO - Starting solver with random_seed: 287288625, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:52,258 - INFO - Solver completed in 5.011133 seconds with status: 0
# 2024-08-29 19:49:52,258 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:49:52,259 - INFO - Starting solver with random_seed: 838162573, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:56,129 - INFO - Solver completed in 3.870138 seconds with status: 4
# 2024-08-29 19:49:56,129 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:49:56,131] Trial 3 finished with value: 21.8442118 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 2, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 0, 'num_workers': 1, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 0}. Best is trial 0 with value: 14.224068749999997.
# 2024-08-29 19:49:56,134 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:49:56,134 - INFO - Returning cached result.
# 2024-08-29 19:49:56,134 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['no_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'repair_hint': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'polish_lp_solution': True, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1, 'num_workers': 8, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 5000}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:49:56,135 - INFO - Starting solver with random_seed: 2008939339, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:49:58,406 - INFO - Solver completed in 2.27111 seconds with status: 4
# 2024-08-29 19:49:58,407 - INFO - Starting solver with random_seed: 131130049, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:03,424 - INFO - Solver completed in 5.016484 seconds with status: 0
# 2024-08-29 19:50:03,424 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:50:03,425 - INFO - Starting solver with random_seed: 1651580795, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:08,435 - INFO - Solver completed in 5.00996 seconds with status: 0
# 2024-08-29 19:50:08,435 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:50:08,436 - INFO - Starting solver with random_seed: 314459467, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:10,769 - INFO - Solver completed in 2.333408 seconds with status: 4
# 2024-08-29 19:50:10,770 - INFO - Starting solver with random_seed: 1595673157, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:15,784 - INFO - Solver completed in 5.013616 seconds with status: 0
# 2024-08-29 19:50:15,784 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:50:15,785 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:50:15,786] Trial 4 finished with value: 30.920903599999995 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1, 'num_workers': 1, 'use_strong_propagation_in_disjunctive': False, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 2}. Best is trial 0 with value: 14.224068749999997.
# 2024-08-29 19:50:15,789 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:50:15,789 - INFO - Returning cached result.
# 2024-08-29 19:50:15,789 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 7, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 0, 'use_strong_propagation_in_disjunctive': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 5000}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:50:15,790 - INFO - Starting solver with random_seed: 327139281, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:16,225 - INFO - Solver completed in 0.434364 seconds with status: 4
# 2024-08-29 19:50:16,225 - INFO - Starting solver with random_seed: 1757418446, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:16,261 - INFO - Solver completed in 0.035656 seconds with status: 4
# 2024-08-29 19:50:16,262 - INFO - Starting solver with random_seed: 1850019303, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:16,338 - INFO - Solver completed in 0.076087 seconds with status: 4
# 2024-08-29 19:50:16,339 - INFO - Starting solver with random_seed: 1276711896, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:16,789 - INFO - Solver completed in 0.44981 seconds with status: 4
# 2024-08-29 19:50:16,789 - INFO - Starting solver with random_seed: 582233946, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:17,013 - INFO - Solver completed in 0.222857 seconds with status: 4
# 2024-08-29 19:50:17,013 - INFO - Evaluation completed and result cached.
# 2024-08-29 19:50:17,013 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-29 19:50:17,014 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'no_lp', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 7, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 0, 'use_strong_propagation_in_disjunctive': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 5000}, num_runs: 20, knockout_score: 54.9840863
# 2024-08-29 19:50:17,014 - INFO - Starting solver with random_seed: 934756061, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:17,065 - INFO - Solver completed in 0.05082 seconds with status: 4
# 2024-08-29 19:50:17,066 - INFO - Starting solver with random_seed: 1207660790, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:17,142 - INFO - Solver completed in 0.076402 seconds with status: 4
# 2024-08-29 19:50:17,143 - INFO - Starting solver with random_seed: 602137618, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:17,609 - INFO - Solver completed in 0.46563 seconds with status: 4
# 2024-08-29 19:50:17,610 - INFO - Starting solver with random_seed: 3223310, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:17,759 - INFO - Solver completed in 0.149306 seconds with status: 4
# 2024-08-29 19:50:17,760 - INFO - Starting solver with random_seed: 52688446, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:17,791 - INFO - Solver completed in 0.030993 seconds with status: 4
# 2024-08-29 19:50:17,792 - INFO - Starting solver with random_seed: 596289121, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:17,994 - INFO - Solver completed in 0.202309 seconds with status: 4
# 2024-08-29 19:50:17,995 - INFO - Starting solver with random_seed: 1712157697, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:18,143 - INFO - Solver completed in 0.148216 seconds with status: 4
# 2024-08-29 19:50:18,144 - INFO - Starting solver with random_seed: 1605133919, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:18,257 - INFO - Solver completed in 0.112376 seconds with status: 4
# 2024-08-29 19:50:18,257 - INFO - Starting solver with random_seed: 1240103069, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:18,331 - INFO - Solver completed in 0.072951 seconds with status: 4
# 2024-08-29 19:50:18,331 - INFO - Starting solver with random_seed: 831143319, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:18,638 - INFO - Solver completed in 0.30623 seconds with status: 4
# 2024-08-29 19:50:18,638 - INFO - Starting solver with random_seed: 1833416320, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:18,836 - INFO - Solver completed in 0.197654 seconds with status: 4
# 2024-08-29 19:50:18,837 - INFO - Starting solver with random_seed: 1278034300, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:19,318 - INFO - Solver completed in 0.480377 seconds with status: 4
# 2024-08-29 19:50:19,318 - INFO - Starting solver with random_seed: 319573661, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:20,816 - INFO - Solver completed in 1.497639 seconds with status: 4
# 2024-08-29 19:50:20,817 - INFO - Starting solver with random_seed: 446526071, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:21,256 - INFO - Solver completed in 0.439005 seconds with status: 4
# 2024-08-29 19:50:21,256 - INFO - Starting solver with random_seed: 327933936, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:21,531 - INFO - Solver completed in 0.27408 seconds with status: 4
# 2024-08-29 19:50:21,531 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:50:21,532] Trial 5 finished with value: 0.28613809999999995 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 7, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0, 'num_workers': 0, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': False, 'use_energetic_reasoning_in_no_overlap_2d': False, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 2}. Best is trial 5 with value: 0.28613809999999995.
# 2024-08-29 19:50:21,536 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:50:21,536 - INFO - Returning cached result.
# 2024-08-29 19:50:21,537 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'max_lp', 'quick_restart', 'probing'], 'search_branching': 5, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 32, 'num_workers': 8, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 2500}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:50:21,537 - INFO - Starting solver with random_seed: 1346098810, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:25,274 - INFO - Solver completed in 3.736417 seconds with status: 4
# 2024-08-29 19:50:25,274 - INFO - Starting solver with random_seed: 1864217300, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:25,975 - INFO - Solver completed in 0.700755 seconds with status: 4
# 2024-08-29 19:50:25,976 - INFO - Starting solver with random_seed: 346130936, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:28,762 - INFO - Solver completed in 2.785353 seconds with status: 4
# 2024-08-29 19:50:28,762 - INFO - Starting solver with random_seed: 1770423649, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:29,362 - INFO - Solver completed in 0.599012 seconds with status: 4
# 2024-08-29 19:50:29,362 - INFO - Starting solver with random_seed: 916817928, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:30,646 - INFO - Solver completed in 1.283127 seconds with status: 4
# 2024-08-29 19:50:30,646 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:50:30,647] Trial 6 finished with value: 1.8209328 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 5, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 2, 'num_workers': 1, 'use_strong_propagation_in_disjunctive': True, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': False, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 1}. Best is trial 5 with value: 0.28613809999999995.
# 2024-08-29 19:50:30,652 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:50:30,653 - INFO - Returning cached result.
# 2024-08-29 19:50:30,653 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 2, 'feasibility_jump_linearization_level': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 0, 'num_workers': 4, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 2500}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:50:30,653 - INFO - Starting solver with random_seed: 154232547, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:32,249 - INFO - Solver completed in 1.595189 seconds with status: 4
# 2024-08-29 19:50:32,249 - INFO - Starting solver with random_seed: 632461962, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:33,960 - INFO - Solver completed in 1.710354 seconds with status: 4
# 2024-08-29 19:50:33,961 - INFO - Starting solver with random_seed: 865657965, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:38,966 - INFO - Solver completed in 5.00551 seconds with status: 0
# 2024-08-29 19:50:38,967 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:50:38,967 - INFO - Starting solver with random_seed: 1924683030, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:40,431 - INFO - Solver completed in 1.463703 seconds with status: 4
# 2024-08-29 19:50:40,432 - INFO - Starting solver with random_seed: 336490285, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:45,444 - INFO - Solver completed in 5.011759 seconds with status: 0
# 2024-08-29 19:50:45,444 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:50:45,445 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:50:45,446] Trial 7 finished with value: 20.9538492 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 2, 'repair_hint': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 0, 'num_workers': 2, 'use_strong_propagation_in_disjunctive': False, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': False, 'use_timetabling_in_no_overlap_2d': False, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 1}. Best is trial 5 with value: 0.28613809999999995.
# 2024-08-29 19:50:45,451 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:50:45,451 - INFO - Returning cached result.
# 2024-08-29 19:50:45,452 - INFO - Evaluating with params: {'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'max_presolve_iterations': 2, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 5, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'fp_rounding': 3, 'polish_lp_solution': True, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 0, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 2500}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:50:45,452 - INFO - Starting solver with random_seed: 403180547, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:50,463 - INFO - Solver completed in 5.01049 seconds with status: 0
# 2024-08-29 19:50:50,464 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:50:50,464 - INFO - Starting solver with random_seed: 343101711, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:53,818 - INFO - Solver completed in 3.353672 seconds with status: 4
# 2024-08-29 19:50:53,819 - INFO - Starting solver with random_seed: 1027847149, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:54,933 - INFO - Solver completed in 1.113524 seconds with status: 4
# 2024-08-29 19:50:54,933 - INFO - Starting solver with random_seed: 1395652943, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:50:59,951 - INFO - Solver completed in 5.017933 seconds with status: 0
# 2024-08-29 19:50:59,952 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:50:59,952 - INFO - Starting solver with random_seed: 1060759632, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:51:03,032 - INFO - Solver completed in 3.079039 seconds with status: 4
# 2024-08-29 19:51:03,032 - INFO - Evaluation completed and result cached.
# [I 2024-08-29 19:51:03,034] Trial 8 finished with value: 21.509247 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 5, 'repair_hint': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 0, 'num_workers': 0, 'use_strong_propagation_in_disjunctive': False, 'use_area_energetic_reasoning_in_no_overlap_2d': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 1}. Best is trial 5 with value: 0.28613809999999995.
# 2024-08-29 19:51:03,039 - INFO - Evaluating with params: {}, num_runs: 20, knockout_score: None
# 2024-08-29 19:51:03,039 - INFO - Returning cached result.
# 2024-08-29 19:51:03,040 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 0, 'ignore_subsolvers': ['fixed', 'max_lp', 'quick_restart_no_lp', 'probing'], 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'polish_lp_solution': True, 'cut_level': 2, 'max_all_diff_cut_size': 128, 'symmetry_level': 1, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 2500}, num_runs: 5, knockout_score: 54.9840863
# 2024-08-29 19:51:03,040 - INFO - Starting solver with random_seed: 1371969060, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:51:08,059 - INFO - Solver completed in 5.018246 seconds with status: 0
# 2024-08-29 19:51:08,059 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:51:08,060 - INFO - Starting solver with random_seed: 570195421, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:51:13,078 - INFO - Solver completed in 5.018012 seconds with status: 0
# 2024-08-29 19:51:13,079 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:51:13,079 - INFO - Starting solver with random_seed: 363799185, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:51:18,110 - INFO - Solver completed in 5.03082 seconds with status: 0
# 2024-08-29 19:51:18,111 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:51:18,111 - INFO - Starting solver with random_seed: 32562687, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:51:23,136 - INFO - Solver completed in 5.024952 seconds with status: 0
# 2024-08-29 19:51:23,137 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:51:23,137 - INFO - Starting solver with random_seed: 1998418647, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:51:28,154 - INFO - Solver completed in 5.016888 seconds with status: 0
# 2024-08-29 19:51:28,155 - WARNING - Solver did not find an optimal solution within the time limit.
# ...
# 2024-08-29 19:56:29,324 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'reduced_costs', 'quick_restart'], 'search_branching': 7, 'repair_hint': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 0, 'use_strong_propagation_in_disjunctive': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'max_pairs_pairwise_reasoning_in_no_overlap_2d': 5000}, num_runs: 5, knockout_score: None
# 2024-08-29 19:56:29,325 - INFO - Starting solver with random_seed: 111441725, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:34,343 - INFO - Solver completed in 5.018083 seconds with status: 0
# 2024-08-29 19:56:34,343 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:56:34,344 - INFO - Starting solver with random_seed: 1662126465, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:39,366 - INFO - Solver completed in 5.021844 seconds with status: 0
# 2024-08-29 19:56:39,366 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:56:39,367 - INFO - Starting solver with random_seed: 1156104533, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:44,386 - INFO - Solver completed in 5.0187 seconds with status: 0
# 2024-08-29 19:56:44,386 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:56:44,387 - INFO - Starting solver with random_seed: 1144070404, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:49,408 - INFO - Solver completed in 5.020732 seconds with status: 0
# 2024-08-29 19:56:49,408 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:56:49,409 - INFO - Starting solver with random_seed: 1479702557, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:54,430 - INFO - Solver completed in 5.021033 seconds with status: 0
# 2024-08-29 19:56:54,430 - WARNING - Solver did not find an optimal solution within the time limit.
# 2024-08-29 19:56:54,431 - INFO - Evaluation completed and result cached.
# 2024-08-29 19:56:54,431 - INFO - Parameter 'use_timetabling_in_no_overlap_2d' is essential for performance.
# 2024-08-29 19:56:54,431 - INFO - Evaluating resetting parameter 'max_pairs_pairwise_reasoning_in_no_overlap_2d' to default...
# 2024-08-29 19:56:54,432 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'reduced_costs', 'quick_restart'], 'search_branching': 7, 'repair_hint': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 0, 'use_strong_propagation_in_disjunctive': True, 'use_energetic_reasoning_in_no_overlap_2d': True, 'use_timetabling_in_no_overlap_2d': True}, num_runs: 5, knockout_score: None
# 2024-08-29 19:56:54,432 - INFO - Starting solver with random_seed: 762757149, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:54,447 - INFO - Solver completed in 0.014539 seconds with status: 4
# 2024-08-29 19:56:54,447 - INFO - Starting solver with random_seed: 726375965, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:54,616 - INFO - Solver completed in 0.168901 seconds with status: 4
# 2024-08-29 19:56:54,617 - INFO - Starting solver with random_seed: 1782885297, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:54,626 - INFO - Solver completed in 0.008554 seconds with status: 4
# 2024-08-29 19:56:54,627 - INFO - Starting solver with random_seed: 1314142446, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:54,718 - INFO - Solver completed in 0.091076 seconds with status: 4
# 2024-08-29 19:56:54,719 - INFO - Starting solver with random_seed: 1888109980, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:54,947 - INFO - Solver completed in 0.228125 seconds with status: 4
# 2024-08-29 19:56:54,947 - INFO - Evaluation completed and result cached.
# 2024-08-29 19:56:54,948 - INFO - Parameter 'max_pairs_pairwise_reasoning_in_no_overlap_2d' can be dropped from the optimized parameters.
# 2024-08-29 19:56:54,948 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'fp_rounding': 0, 'use_timetabling_in_no_overlap_2d': True}, num_runs: 20, knockout_score: None
# 2024-08-29 19:56:54,948 - INFO - Starting solver with random_seed: 721667193, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:55,162 - INFO - Solver completed in 0.213687 seconds with status: 4
# 2024-08-29 19:56:55,163 - INFO - Starting solver with random_seed: 202236925, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:55,269 - INFO - Solver completed in 0.105666 seconds with status: 4
# 2024-08-29 19:56:55,269 - INFO - Starting solver with random_seed: 1298430411, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:55,307 - INFO - Solver completed in 0.036929 seconds with status: 4
# 2024-08-29 19:56:55,307 - INFO - Starting solver with random_seed: 1307699660, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:56,016 - INFO - Solver completed in 0.708906 seconds with status: 4
# 2024-08-29 19:56:56,017 - INFO - Starting solver with random_seed: 1725242713, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:56,163 - INFO - Solver completed in 0.145552 seconds with status: 4
# 2024-08-29 19:56:56,164 - INFO - Starting solver with random_seed: 1683409488, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:56,522 - INFO - Solver completed in 0.358178 seconds with status: 4
# 2024-08-29 19:56:56,523 - INFO - Starting solver with random_seed: 1633023193, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:56,924 - INFO - Solver completed in 0.401379 seconds with status: 4
# 2024-08-29 19:56:56,925 - INFO - Starting solver with random_seed: 2011049970, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:57,482 - INFO - Solver completed in 0.556696 seconds with status: 4
# 2024-08-29 19:56:57,482 - INFO - Starting solver with random_seed: 1259723296, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:58,023 - INFO - Solver completed in 0.540007 seconds with status: 4
# 2024-08-29 19:56:58,023 - INFO - Starting solver with random_seed: 1010492378, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:58,130 - INFO - Solver completed in 0.106228 seconds with status: 4
# 2024-08-29 19:56:58,131 - INFO - Starting solver with random_seed: 487448104, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:58,456 - INFO - Solver completed in 0.325128 seconds with status: 4
# 2024-08-29 19:56:58,457 - INFO - Starting solver with random_seed: 541417950, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:58,684 - INFO - Solver completed in 0.226693 seconds with status: 4
# 2024-08-29 19:56:58,684 - INFO - Starting solver with random_seed: 544653871, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:56:59,141 - INFO - Solver completed in 0.456576 seconds with status: 4
# 2024-08-29 19:56:59,142 - INFO - Starting solver with random_seed: 111694778, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:57:00,014 - INFO - Solver completed in 0.872376 seconds with status: 4
# 2024-08-29 19:57:00,015 - INFO - Starting solver with random_seed: 1187291804, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:57:00,046 - INFO - Solver completed in 0.031196 seconds with status: 4
# 2024-08-29 19:57:00,047 - INFO - Starting solver with random_seed: 1597842561, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:57:01,020 - INFO - Solver completed in 0.973179 seconds with status: 4
# 2024-08-29 19:57:01,021 - INFO - Starting solver with random_seed: 1502730637, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:57:01,039 - INFO - Solver completed in 0.017266 seconds with status: 4
# 2024-08-29 19:57:01,039 - INFO - Starting solver with random_seed: 39095181, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:57:01,059 - INFO - Solver completed in 0.019138 seconds with status: 4
# 2024-08-29 19:57:01,059 - INFO - Starting solver with random_seed: 641743470, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:57:01,275 - INFO - Solver completed in 0.215567 seconds with status: 4
# 2024-08-29 19:57:01,276 - INFO - Starting solver with random_seed: 727407560, max_time_in_seconds: 5, relative_gap_limit: 0.0, absolute_gap_limit: 0.0
# 2024-08-29 19:57:01,303 - INFO - Solver completed in 0.026781 seconds with status: 4
# 2024-08-29 19:57:01,303 - INFO - Evaluation completed and result cached.
# 2024-08-29 19:57:01,304 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter                        ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ preferred_variable_order         │   2   │    0.80%     │       0       │
# │ 2   │ presolve_bve_threshold           │ 1000  │    0.38%     │      500      │
# │ 3   │ max_presolve_iterations          │  10   │    0.31%     │       3       │
# │ 4   │ fp_rounding                      │   0   │    0.39%     │       2       │
# │ 5   │ use_timetabling_in_no_overlap_2d │ True  │    98.12%    │     False     │
# └─────┴──────────────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. preferred_variable_order Sets the initial order in which variables are selected during the search. The options
# are:
#
#  • 0 (IN_ORDER): Select variables in the order they appear in the problem definition.
#  • 1 (IN_REVERSE_ORDER): Select variables in reverse order.
#  • 2 (IN_RANDOM_ORDER): Select variables randomly.
#
# The order of variable selection can have a significant impact on the efficiency of the search, though, this is only
# the initial order and the solver will actually try to learn a better order. The search will restart frequently such
# that this initial order should only influence the beginning of the search.
#
# 2. presolve_bve_threshold Determines the threshold for Bounded Variable Elimination (BVE) during presolve. BVE
# eliminates variables that can be easily solved based on their limited impact. Lower thresholds speed up presolve
# but may result in less thorough simplification of the problem.
#
# 3. max_presolve_iterations Sets the maximum number of iterations that the presolve phase will execute. Presolve
# simplifies the problem by eliminating redundant constraints and variables before the main search begins. More
# iterations can lead to a more simplified problem but at the cost of longer presolve times.
#
# 4. fp_rounding Specifies the rounding method used in the feasibility pump, a heuristic for quickly finding integer
# feasible solutions. The options are:
#
#  • 0 (NEAREST_INTEGER): Rounds values to the nearest integer.
#  • 1 (LOCK_BASED): Rounds based on the direction with fewer constraints ("locks").
#  • 2 (PROPAGATION_ASSISTED): Rounds with consideration of bound propagation, improving solution quality by
#    integrating more logical deductions.
#  • 3 (ACTIVE_LOCK_BASED): Similar to lock-based rounding, but focuses on active constraints from the last LP solve.
#
# 5. use_timetabling_in_no_overlap_2d Reinforce the no_overlap_2d constraint with propagators from the cumulative
# constraints.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                                    ┃  Mean ┃  Min ┃  Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━━━┩
# │ Time in seconds with Default Parameters   │ 14.22 │ 0.16 │ 50.0 │       20 │
# │ Time in seconds with Optimized Parameters │  0.32 │ 0.02 │ 0.97 │       20 │
# └───────────────────────────────────────────┴───────┴──────┴──────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-29 19:57:01,335 - INFO - Hyperparameter tuning completed.
# 2024-08-29 19:57:01,336 - INFO - Tuning for time to optimal completed.

# %%
best = tune_for_quality_within_timelimit(
    model,
    max_time_in_seconds=0.5,
    obj_for_timeout=0,
    direction="maximize",
    n_samples_for_trial=10,  # Number of samples for each trial
    n_samples_for_verification=40,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-20 10:33:31,743 - INFO - Starting tuning for quality within time limit. Direction: maximize
# 2024-08-20 10:33:31,744 - INFO - Initialized Metric with direction: maximize
# 2024-08-20 10:33:31,744 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-20 10:33:31,744 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:33:31,745 - INFO - Starting solver with random_seed: 1474729200, max_time_in_seconds: 0.5
# 2024-08-20 10:33:32,279 - INFO - Solver found a solution with objective value: 128440.0
# 2024-08-20 10:33:32,280 - INFO - Starting solver with random_seed: 780779378, max_time_in_seconds: 0.5
# 2024-08-20 10:33:32,817 - INFO - Solver found a solution with objective value: 134975.0
# 2024-08-20 10:33:32,818 - INFO - Starting solver with random_seed: 2110865242, max_time_in_seconds: 0.5
# 2024-08-20 10:33:33,343 - INFO - Solver found a solution with objective value: 135420.0
# 2024-08-20 10:33:33,343 - INFO - Starting solver with random_seed: 220719114, max_time_in_seconds: 0.5
# 2024-08-20 10:33:33,882 - INFO - Solver found a solution with objective value: 133240.0
# 2024-08-20 10:33:33,883 - INFO - Starting solver with random_seed: 1013861912, max_time_in_seconds: 0.5
# 2024-08-20 10:33:34,409 - INFO - Solver found a solution with objective value: 132915.0
# 2024-08-20 10:33:34,410 - INFO - Starting solver with random_seed: 1170373201, max_time_in_seconds: 0.5
# 2024-08-20 10:33:34,935 - INFO - Solver found a solution with objective value: 135895.0
# 2024-08-20 10:33:34,936 - INFO - Starting solver with random_seed: 142601731, max_time_in_seconds: 0.5
# 2024-08-20 10:33:35,477 - INFO - Solver found a solution with objective value: 133470.0
# 2024-08-20 10:33:35,478 - INFO - Starting solver with random_seed: 471772428, max_time_in_seconds: 0.5
# 2024-08-20 10:33:36,028 - INFO - Solver found a solution with objective value: 135455.0
# 2024-08-20 10:33:36,028 - INFO - Starting solver with random_seed: 1471589480, max_time_in_seconds: 0.5
# 2024-08-20 10:33:36,567 - INFO - Solver found a solution with objective value: 131840.0
# 2024-08-20 10:33:36,567 - INFO - Starting solver with random_seed: 2015012932, max_time_in_seconds: 0.5
# 2024-08-20 10:33:37,124 - INFO - Solver found a solution with objective value: 136695.0
# 2024-08-20 10:33:37,124 - INFO - Starting solver with random_seed: 108571448, max_time_in_seconds: 0.5
# 2024-08-20 10:33:37,652 - INFO - Solver found a solution with objective value: 136350.0
# 2024-08-20 10:33:37,653 - INFO - Starting solver with random_seed: 306143503, max_time_in_seconds: 0.5
# 2024-08-20 10:33:38,191 - INFO - Solver found a solution with objective value: 132725.0
# 2024-08-20 10:33:38,191 - INFO - Starting solver with random_seed: 684482637, max_time_in_seconds: 0.5
# 2024-08-20 10:33:38,743 - INFO - Solver found a solution with objective value: 136530.0
# 2024-08-20 10:33:38,743 - INFO - Starting solver with random_seed: 708713335, max_time_in_seconds: 0.5
# 2024-08-20 10:33:39,271 - INFO - Solver found a solution with objective value: 134290.0
# 2024-08-20 10:33:39,272 - INFO - Starting solver with random_seed: 2134770697, max_time_in_seconds: 0.5
# 2024-08-20 10:33:39,829 - INFO - Solver found a solution with objective value: 132895.0
# 2024-08-20 10:33:39,830 - INFO - Starting solver with random_seed: 2131980056, max_time_in_seconds: 0.5
# 2024-08-20 10:33:40,379 - INFO - Solver found a solution with objective value: 135585.0
# 2024-08-20 10:33:40,380 - INFO - Starting solver with random_seed: 1933578672, max_time_in_seconds: 0.5
# 2024-08-20 10:33:40,905 - INFO - Solver found a solution with objective value: 134375.0
# 2024-08-20 10:33:40,906 - INFO - Starting solver with random_seed: 406555044, max_time_in_seconds: 0.5
# 2024-08-20 10:33:41,444 - INFO - Solver found a solution with objective value: 136305.0
# 2024-08-20 10:33:41,445 - INFO - Starting solver with random_seed: 920620881, max_time_in_seconds: 0.5
# 2024-08-20 10:33:41,971 - INFO - Solver found a solution with objective value: 133010.0
# 2024-08-20 10:33:41,971 - INFO - Starting solver with random_seed: 876601943, max_time_in_seconds: 0.5
# 2024-08-20 10:33:42,497 - INFO - Solver found a solution with objective value: 136635.0
# 2024-08-20 10:33:42,497 - INFO - Starting solver with random_seed: 326529171, max_time_in_seconds: 0.5
# 2024-08-20 10:33:43,027 - INFO - Solver found a solution with objective value: 133205.0
# 2024-08-20 10:33:43,028 - INFO - Starting solver with random_seed: 1942496227, max_time_in_seconds: 0.5
# 2024-08-20 10:33:43,558 - INFO - Solver found a solution with objective value: 134600.0
# 2024-08-20 10:33:43,559 - INFO - Starting solver with random_seed: 755422789, max_time_in_seconds: 0.5
# 2024-08-20 10:33:44,106 - INFO - Solver found a solution with objective value: 134230.0
# 2024-08-20 10:33:44,106 - INFO - Starting solver with random_seed: 1544668317, max_time_in_seconds: 0.5
# 2024-08-20 10:33:44,644 - INFO - Solver found a solution with objective value: 133995.0
# 2024-08-20 10:33:44,644 - INFO - Starting solver with random_seed: 1662554318, max_time_in_seconds: 0.5
# 2024-08-20 10:33:45,171 - INFO - Solver found a solution with objective value: 132730.0
# 2024-08-20 10:33:45,171 - INFO - Starting solver with random_seed: 379336437, max_time_in_seconds: 0.5
# 2024-08-20 10:33:45,697 - INFO - Solver found a solution with objective value: 133820.0
# 2024-08-20 10:33:45,698 - INFO - Starting solver with random_seed: 1087337098, max_time_in_seconds: 0.5
# 2024-08-20 10:33:46,222 - INFO - Solver found a solution with objective value: 128515.0
# 2024-08-20 10:33:46,223 - INFO - Starting solver with random_seed: 1240649923, max_time_in_seconds: 0.5
# 2024-08-20 10:33:46,749 - INFO - Solver found a solution with objective value: 133325.0
# 2024-08-20 10:33:46,749 - INFO - Starting solver with random_seed: 362342980, max_time_in_seconds: 0.5
# 2024-08-20 10:33:47,273 - INFO - Solver found a solution with objective value: 127820.0
# 2024-08-20 10:33:47,274 - INFO - Starting solver with random_seed: 1451400003, max_time_in_seconds: 0.5
# 2024-08-20 10:33:47,797 - INFO - Solver found a solution with objective value: 134825.0
# 2024-08-20 10:33:47,798 - INFO - Starting solver with random_seed: 1762433585, max_time_in_seconds: 0.5
# 2024-08-20 10:33:48,322 - INFO - Solver found a solution with objective value: 135530.0
# 2024-08-20 10:33:48,323 - INFO - Starting solver with random_seed: 1634364046, max_time_in_seconds: 0.5
# 2024-08-20 10:33:48,874 - INFO - Solver found a solution with objective value: 135850.0
# 2024-08-20 10:33:48,875 - INFO - Starting solver with random_seed: 1040185462, max_time_in_seconds: 0.5
# 2024-08-20 10:33:49,399 - INFO - Solver found a solution with objective value: 136600.0
# 2024-08-20 10:33:49,400 - INFO - Starting solver with random_seed: 193096804, max_time_in_seconds: 0.5
# 2024-08-20 10:33:49,933 - INFO - Solver found a solution with objective value: 134950.0
# 2024-08-20 10:33:49,934 - INFO - Starting solver with random_seed: 1752878594, max_time_in_seconds: 0.5
# 2024-08-20 10:33:50,459 - INFO - Solver found a solution with objective value: 134200.0
# 2024-08-20 10:33:50,460 - INFO - Starting solver with random_seed: 1258256710, max_time_in_seconds: 0.5
# 2024-08-20 10:33:50,993 - INFO - Solver found a solution with objective value: 134570.0
# 2024-08-20 10:33:50,994 - INFO - Starting solver with random_seed: 1734936871, max_time_in_seconds: 0.5
# 2024-08-20 10:33:51,524 - INFO - Solver found a solution with objective value: 133890.0
# 2024-08-20 10:33:51,525 - INFO - Starting solver with random_seed: 1880105947, max_time_in_seconds: 0.5
# 2024-08-20 10:33:52,051 - INFO - Solver found a solution with objective value: 133120.0
# 2024-08-20 10:33:52,052 - INFO - Starting solver with random_seed: 1167332064, max_time_in_seconds: 0.5
# 2024-08-20 10:33:52,606 - INFO - Solver found a solution with objective value: 134275.0
# 2024-08-20 10:33:52,607 - INFO - Starting solver with random_seed: 1658485334, max_time_in_seconds: 0.5
# 2024-08-20 10:33:53,132 - INFO - Solver found a solution with objective value: 136455.0
# 2024-08-20 10:33:53,133 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:33:53,133 - INFO - Baseline evaluation completed: min=127820.0, mean=134088.75, max=136695.0
# [I 2024-08-20 10:33:53,133] A new study created in memory with name: no-name-f3816ce9-7d2f-4781-a207-3a6815eb2ff1
# 2024-08-20 10:33:53,134 - INFO - Starting Optuna optimization.
# 2024-08-20 10:33:53,135 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:33:53,135 - INFO - Returning cached result.
# 2024-08-20 10:33:53,136 - INFO - Evaluating with params: {}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:33:53,136 - INFO - Returning cached result.
# 2024-08-20 10:33:53,136 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-20 10:33:53,136 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: 126932.5
# 2024-08-20 10:33:53,137 - INFO - Returning cached result.
# [I 2024-08-20 10:33:53,138] Trial 0 finished with value: 134088.75 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2, 'num_workers': 0}. Best is trial 0 with value: 134088.75.
# 2024-08-20 10:33:53,141 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:33:53,141 - INFO - Returning cached result.
# 2024-08-20 10:33:53,142 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'max_presolve_iterations': 10, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['reduced_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'polish_lp_solution': True, 'linearization_level': 0, 'symmetry_level': 1, 'num_workers': 8}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:33:53,142 - INFO - Starting solver with random_seed: 1235502335, max_time_in_seconds: 0.5
# 2024-08-20 10:33:53,660 - INFO - Solver found a solution with objective value: 137410.0
# 2024-08-20 10:33:53,660 - INFO - Starting solver with random_seed: 417055827, max_time_in_seconds: 0.5
# 2024-08-20 10:33:54,180 - INFO - Solver found a solution with objective value: 136015.0
# 2024-08-20 10:33:54,180 - INFO - Starting solver with random_seed: 1357178705, max_time_in_seconds: 0.5
# 2024-08-20 10:33:54,699 - INFO - Solver found a solution with objective value: 137375.0
# 2024-08-20 10:33:54,700 - INFO - Starting solver with random_seed: 1270257818, max_time_in_seconds: 0.5
# 2024-08-20 10:33:55,220 - INFO - Solver found a solution with objective value: 136945.0
# 2024-08-20 10:33:55,220 - INFO - Starting solver with random_seed: 1570685447, max_time_in_seconds: 0.5
# 2024-08-20 10:33:55,739 - INFO - Solver found a solution with objective value: 134975.0
# 2024-08-20 10:33:55,740 - INFO - Starting solver with random_seed: 288881439, max_time_in_seconds: 0.5
# 2024-08-20 10:33:56,257 - INFO - Solver found a solution with objective value: 135470.0
# 2024-08-20 10:33:56,257 - INFO - Starting solver with random_seed: 2139827362, max_time_in_seconds: 0.5
# 2024-08-20 10:33:56,780 - INFO - Solver found a solution with objective value: 135395.0
# 2024-08-20 10:33:56,781 - INFO - Starting solver with random_seed: 514321813, max_time_in_seconds: 0.5
# 2024-08-20 10:33:57,300 - INFO - Solver found a solution with objective value: 135845.0
# 2024-08-20 10:33:57,300 - INFO - Starting solver with random_seed: 2108198457, max_time_in_seconds: 0.5
# 2024-08-20 10:33:57,819 - INFO - Solver found a solution with objective value: 136670.0
# 2024-08-20 10:33:57,820 - INFO - Starting solver with random_seed: 229343293, max_time_in_seconds: 0.5
# 2024-08-20 10:33:58,340 - INFO - Solver found a solution with objective value: 133160.0
# 2024-08-20 10:33:58,340 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:33:58,340 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-20 10:33:58,341 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'max_presolve_iterations': 10, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['reduced_costs', 'quick_restart', 'quick_restart_no_lp'], 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'polish_lp_solution': True, 'linearization_level': 0, 'symmetry_level': 1, 'num_workers': 8}, num_runs: 40, knockout_score: 126932.5
# 2024-08-20 10:33:58,341 - INFO - Starting solver with random_seed: 922289261, max_time_in_seconds: 0.5
# 2024-08-20 10:33:58,859 - INFO - Solver found a solution with objective value: 133520.0
# 2024-08-20 10:33:58,860 - INFO - Starting solver with random_seed: 960479737, max_time_in_seconds: 0.5
# 2024-08-20 10:33:59,378 - INFO - Solver found a solution with objective value: 134490.0
# 2024-08-20 10:33:59,379 - INFO - Starting solver with random_seed: 619350708, max_time_in_seconds: 0.5
# 2024-08-20 10:33:59,897 - INFO - Solver found a solution with objective value: 135395.0
# 2024-08-20 10:33:59,897 - INFO - Starting solver with random_seed: 2051468602, max_time_in_seconds: 0.5
# 2024-08-20 10:34:00,417 - INFO - Solver found a solution with objective value: 130840.0
# 2024-08-20 10:34:00,418 - INFO - Starting solver with random_seed: 1641716759, max_time_in_seconds: 0.5
# 2024-08-20 10:34:00,938 - INFO - Solver found a solution with objective value: 136305.0
# 2024-08-20 10:34:00,938 - INFO - Starting solver with random_seed: 1489804109, max_time_in_seconds: 0.5
# 2024-08-20 10:34:01,457 - INFO - Solver found a solution with objective value: 137405.0
# 2024-08-20 10:34:01,457 - INFO - Starting solver with random_seed: 2070526299, max_time_in_seconds: 0.5
# 2024-08-20 10:34:01,979 - INFO - Solver found a solution with objective value: 134515.0
# 2024-08-20 10:34:01,979 - INFO - Starting solver with random_seed: 2076575853, max_time_in_seconds: 0.5
# 2024-08-20 10:34:02,498 - INFO - Solver found a solution with objective value: 135395.0
# 2024-08-20 10:34:02,499 - INFO - Starting solver with random_seed: 43669808, max_time_in_seconds: 0.5
# 2024-08-20 10:34:03,018 - INFO - Solver found a solution with objective value: 133975.0
# 2024-08-20 10:34:03,019 - INFO - Starting solver with random_seed: 2100349465, max_time_in_seconds: 0.5
# 2024-08-20 10:34:03,537 - INFO - Solver found a solution with objective value: 130450.0
# 2024-08-20 10:34:03,537 - INFO - Starting solver with random_seed: 2135372306, max_time_in_seconds: 0.5
# 2024-08-20 10:34:04,056 - INFO - Solver found a solution with objective value: 135980.0
# 2024-08-20 10:34:04,057 - INFO - Starting solver with random_seed: 82611406, max_time_in_seconds: 0.5
# 2024-08-20 10:34:04,577 - INFO - Solver found a solution with objective value: 134400.0
# 2024-08-20 10:34:04,578 - INFO - Starting solver with random_seed: 1904188441, max_time_in_seconds: 0.5
# 2024-08-20 10:34:05,102 - INFO - Solver found a solution with objective value: 134770.0
# 2024-08-20 10:34:05,103 - INFO - Starting solver with random_seed: 133354655, max_time_in_seconds: 0.5
# 2024-08-20 10:34:05,622 - INFO - Solver found a solution with objective value: 136500.0
# 2024-08-20 10:34:05,623 - INFO - Starting solver with random_seed: 257925764, max_time_in_seconds: 0.5
# 2024-08-20 10:34:06,144 - INFO - Solver found a solution with objective value: 134245.0
# 2024-08-20 10:34:06,144 - INFO - Starting solver with random_seed: 515971819, max_time_in_seconds: 0.5
# 2024-08-20 10:34:06,662 - INFO - Solver found a solution with objective value: 135735.0
# 2024-08-20 10:34:06,663 - INFO - Starting solver with random_seed: 2129557653, max_time_in_seconds: 0.5
# 2024-08-20 10:34:07,181 - INFO - Solver found a solution with objective value: 134430.0
# 2024-08-20 10:34:07,182 - INFO - Starting solver with random_seed: 1785915694, max_time_in_seconds: 0.5
# 2024-08-20 10:34:07,699 - INFO - Solver found a solution with objective value: 136960.0
# 2024-08-20 10:34:07,700 - INFO - Starting solver with random_seed: 736945234, max_time_in_seconds: 0.5
# 2024-08-20 10:34:08,218 - INFO - Solver found a solution with objective value: 136635.0
# 2024-08-20 10:34:08,219 - INFO - Starting solver with random_seed: 2022196101, max_time_in_seconds: 0.5
# 2024-08-20 10:34:08,738 - INFO - Solver found a solution with objective value: 135460.0
# 2024-08-20 10:34:08,739 - INFO - Starting solver with random_seed: 1109298584, max_time_in_seconds: 0.5
# 2024-08-20 10:34:09,257 - INFO - Solver found a solution with objective value: 132050.0
# 2024-08-20 10:34:09,258 - INFO - Starting solver with random_seed: 272439342, max_time_in_seconds: 0.5
# 2024-08-20 10:34:09,775 - INFO - Solver found a solution with objective value: 136100.0
# 2024-08-20 10:34:09,776 - INFO - Starting solver with random_seed: 1925407519, max_time_in_seconds: 0.5
# 2024-08-20 10:34:10,294 - INFO - Solver found a solution with objective value: 134930.0
# 2024-08-20 10:34:10,294 - INFO - Starting solver with random_seed: 1473426958, max_time_in_seconds: 0.5
# 2024-08-20 10:34:10,812 - INFO - Solver found a solution with objective value: 129875.0
# 2024-08-20 10:34:10,813 - INFO - Starting solver with random_seed: 203393746, max_time_in_seconds: 0.5
# 2024-08-20 10:34:11,333 - INFO - Solver found a solution with objective value: 134130.0
# 2024-08-20 10:34:11,333 - INFO - Starting solver with random_seed: 1359659267, max_time_in_seconds: 0.5
# 2024-08-20 10:34:11,852 - INFO - Solver found a solution with objective value: 135795.0
# 2024-08-20 10:34:11,852 - INFO - Starting solver with random_seed: 435688688, max_time_in_seconds: 0.5
# 2024-08-20 10:34:12,370 - INFO - Solver found a solution with objective value: 133845.0
# 2024-08-20 10:34:12,370 - INFO - Starting solver with random_seed: 1271510068, max_time_in_seconds: 0.5
# 2024-08-20 10:34:12,890 - INFO - Solver found a solution with objective value: 135150.0
# 2024-08-20 10:34:12,890 - INFO - Starting solver with random_seed: 1705658700, max_time_in_seconds: 0.5
# 2024-08-20 10:34:13,413 - INFO - Solver found a solution with objective value: 137275.0
# 2024-08-20 10:34:13,414 - INFO - Starting solver with random_seed: 917286199, max_time_in_seconds: 0.5
# 2024-08-20 10:34:13,932 - INFO - Solver found a solution with objective value: 133310.0
# 2024-08-20 10:34:13,933 - INFO - Evaluation completed and result cached.
# [I 2024-08-20 10:34:13,934] Trial 1 finished with value: 134978.125 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 6, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1, 'num_workers': 1}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:13,937 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:13,937 - INFO - Returning cached result.
# 2024-08-20 10:34:13,937 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['default_lp', 'reduced_costs', 'quick_restart'], 'search_branching': 6, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'fp_rounding': 3, 'linearization_level': 0, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 0, 'num_workers': 8}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:13,938 - INFO - Starting solver with random_seed: 1009353131, max_time_in_seconds: 0.5
# 2024-08-20 10:34:14,458 - INFO - Solver found a solution with objective value: 97625.0
# 2024-08-20 10:34:14,459 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:14,460] Trial 2 finished with value: 97625.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 6, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 0, 'num_workers': 1}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:14,463 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:14,464 - INFO - Returning cached result.
# 2024-08-20 10:34:14,464 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'probing'], 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 0, 'num_workers': 8}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:14,464 - INFO - Starting solver with random_seed: 885858398, max_time_in_seconds: 0.5
# 2024-08-20 10:34:14,985 - INFO - Solver found a solution with objective value: 135555.0
# 2024-08-20 10:34:14,985 - INFO - Starting solver with random_seed: 332491420, max_time_in_seconds: 0.5
# 2024-08-20 10:34:15,506 - INFO - Solver found a solution with objective value: 137125.0
# 2024-08-20 10:34:15,506 - INFO - Starting solver with random_seed: 448974513, max_time_in_seconds: 0.5
# 2024-08-20 10:34:16,030 - INFO - Solver found a solution with objective value: 135620.0
# 2024-08-20 10:34:16,031 - INFO - Starting solver with random_seed: 1849493699, max_time_in_seconds: 0.5
# 2024-08-20 10:34:16,559 - INFO - Solver found a solution with objective value: 110415.0
# 2024-08-20 10:34:16,559 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:16,560] Trial 3 finished with value: 110415.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 0, 'num_workers': 1}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:16,563 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:16,564 - INFO - Returning cached result.
# 2024-08-20 10:34:16,564 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['default_lp', 'reduced_costs', 'quick_restart_no_lp'], 'search_branching': 6, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'polish_lp_solution': True, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:16,564 - INFO - Starting solver with random_seed: 57692825, max_time_in_seconds: 0.5
# 2024-08-20 10:34:17,086 - INFO - Solver found a solution with objective value: 113420.0
# 2024-08-20 10:34:17,087 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:17,088] Trial 4 finished with value: 113420.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 6, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 1, 'num_workers': 0}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:17,091 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:17,092 - INFO - Returning cached result.
# 2024-08-20 10:34:17,092 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'presolve_bve_threshold': 100, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'quick_restart', 'lb_tree_search', 'probing'], 'search_branching': 3, 'repair_hint': True, 'use_lns_only': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'fp_rounding': 1, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 2, 'symmetry_level': 1, 'num_workers': 8}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:17,092 - INFO - Starting solver with random_seed: 1873067019, max_time_in_seconds: 0.5
# 2024-08-20 10:34:17,611 - INFO - Solver found a solution with objective value: 136755.0
# 2024-08-20 10:34:17,612 - INFO - Starting solver with random_seed: 1335991707, max_time_in_seconds: 0.5
# 2024-08-20 10:34:18,131 - INFO - Solver found a solution with objective value: 113110.0
# 2024-08-20 10:34:18,131 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:18,132] Trial 5 finished with value: 113110.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 3, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 1, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 1, 'num_workers': 1}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:18,136 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:18,136 - INFO - Returning cached result.
# 2024-08-20 10:34:18,136 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'fixed', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'probing'], 'search_branching': 8, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'max_all_diff_cut_size': 128, 'symmetry_level': 1, 'num_workers': 8}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:18,137 - INFO - Starting solver with random_seed: 1604867452, max_time_in_seconds: 0.5
# 2024-08-20 10:34:18,604 - INFO - Solver found a solution with objective value: 94000.0
# 2024-08-20 10:34:18,605 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:18,606] Trial 6 finished with value: 94000.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 8, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1, 'num_workers': 1}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:18,609 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:18,609 - INFO - Returning cached result.
# 2024-08-20 10:34:18,610 - INFO - Evaluating with params: {'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 10.0, 'ignore_subsolvers': ['no_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 7, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'fp_rounding': 3, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 1, 'num_workers': 8}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:18,610 - INFO - Starting solver with random_seed: 1861173677, max_time_in_seconds: 0.5
# 2024-08-20 10:34:19,131 - INFO - Solver found a solution with objective value: 59475.0
# 2024-08-20 10:34:19,131 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:19,132] Trial 7 finished with value: 59475.0 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 7, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 1, 'num_workers': 1}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:19,135 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:19,136 - INFO - Returning cached result.
# 2024-08-20 10:34:19,136 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'max_presolve_iterations': 10, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'probing'], 'search_branching': 2, 'repair_hint': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'symmetry_level': 0}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:19,136 - INFO - Starting solver with random_seed: 1507957035, max_time_in_seconds: 0.5
# 2024-08-20 10:34:19,723 - INFO - Solver found a solution with objective value: 136970.0
# 2024-08-20 10:34:19,723 - INFO - Starting solver with random_seed: 26725727, max_time_in_seconds: 0.5
# 2024-08-20 10:34:20,387 - INFO - Solver found a solution with objective value: 136175.0
# 2024-08-20 10:34:20,388 - INFO - Starting solver with random_seed: 1178177332, max_time_in_seconds: 0.5
# 2024-08-20 10:34:21,038 - INFO - Solver found a solution with objective value: 122500.0
# 2024-08-20 10:34:21,039 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:21,040] Trial 8 finished with value: 122500.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 4, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 2, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 0, 'num_workers': 0}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:21,043 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:21,043 - INFO - Returning cached result.
# 2024-08-20 10:34:21,043 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'ignore_subsolvers': ['default_lp', 'max_lp', 'pseudo_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 3, 'repair_hint': True, 'use_lb_relax_lns': True, 'optimize_with_core': True, 'fp_rounding': 3, 'linearization_level': 2, 'max_all_diff_cut_size': 32, 'symmetry_level': 1, 'num_workers': 8}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:21,043 - INFO - Starting solver with random_seed: 642760435, max_time_in_seconds: 0.5
# 2024-08-20 10:34:21,565 - INFO - Solver found a solution with objective value: 132720.0
# 2024-08-20 10:34:21,565 - INFO - Starting solver with random_seed: 2067405647, max_time_in_seconds: 0.5
# 2024-08-20 10:34:22,086 - INFO - Solver found a solution with objective value: 134560.0
# 2024-08-20 10:34:22,086 - INFO - Starting solver with random_seed: 642459511, max_time_in_seconds: 0.5
# 2024-08-20 10:34:22,608 - INFO - Solver found a solution with objective value: 132320.0
# 2024-08-20 10:34:22,608 - INFO - Starting solver with random_seed: 746359173, max_time_in_seconds: 0.5
# 2024-08-20 10:34:23,133 - INFO - Solver found a solution with objective value: 134020.0
# 2024-08-20 10:34:23,133 - INFO - Starting solver with random_seed: 1268777238, max_time_in_seconds: 0.5
# 2024-08-20 10:34:23,654 - INFO - Solver found a solution with objective value: 130770.0
# 2024-08-20 10:34:23,654 - INFO - Starting solver with random_seed: 435777811, max_time_in_seconds: 0.5
# 2024-08-20 10:34:24,175 - INFO - Solver found a solution with objective value: 132520.0
# 2024-08-20 10:34:24,176 - INFO - Starting solver with random_seed: 1447892682, max_time_in_seconds: 0.5
# 2024-08-20 10:34:24,698 - INFO - Solver found a solution with objective value: 131710.0
# 2024-08-20 10:34:24,699 - INFO - Starting solver with random_seed: 1886054101, max_time_in_seconds: 0.5
# 2024-08-20 10:34:25,220 - INFO - Solver found a solution with objective value: 134240.0
# 2024-08-20 10:34:25,220 - INFO - Starting solver with random_seed: 184970618, max_time_in_seconds: 0.5
# 2024-08-20 10:34:25,740 - INFO - Solver found a solution with objective value: 128225.0
# 2024-08-20 10:34:25,741 - INFO - Starting solver with random_seed: 94556378, max_time_in_seconds: 0.5
# 2024-08-20 10:34:26,262 - INFO - Solver found a solution with objective value: 132955.0
# 2024-08-20 10:34:26,262 - INFO - Evaluation completed and result cached.
# [I 2024-08-20 10:34:26,263] Trial 9 finished with value: 132404.0 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 0, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 3, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 1, 'num_workers': 1}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:26,308 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:26,308 - INFO - Returning cached result.
# 2024-08-20 10:34:26,309 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['fixed', 'max_lp', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 1, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 2, 'max_all_diff_cut_size': 32}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:26,309 - INFO - Starting solver with random_seed: 405888890, max_time_in_seconds: 0.5
# 2024-08-20 10:34:26,832 - INFO - Solver found a solution with objective value: 133195.0
# 2024-08-20 10:34:26,833 - INFO - Starting solver with random_seed: 840124784, max_time_in_seconds: 0.5
# 2024-08-20 10:34:27,360 - INFO - Solver found a solution with objective value: 134240.0
# 2024-08-20 10:34:27,360 - INFO - Starting solver with random_seed: 453788271, max_time_in_seconds: 0.5
# 2024-08-20 10:34:27,882 - INFO - Solver found a solution with objective value: 135600.0
# 2024-08-20 10:34:27,883 - INFO - Starting solver with random_seed: 1644837415, max_time_in_seconds: 0.5
# 2024-08-20 10:34:28,404 - INFO - Solver found a solution with objective value: 134875.0
# 2024-08-20 10:34:28,405 - INFO - Starting solver with random_seed: 1718140262, max_time_in_seconds: 0.5
# 2024-08-20 10:34:28,928 - INFO - Solver found a solution with objective value: 134235.0
# 2024-08-20 10:34:28,929 - INFO - Starting solver with random_seed: 884421129, max_time_in_seconds: 0.5
# 2024-08-20 10:34:29,461 - INFO - Solver found a solution with objective value: 134070.0
# 2024-08-20 10:34:29,462 - INFO - Starting solver with random_seed: 1778975830, max_time_in_seconds: 0.5
# 2024-08-20 10:34:29,982 - INFO - Solver found a solution with objective value: 114950.0
# 2024-08-20 10:34:29,983 - INFO - Returning knockout result.
# [I 2024-08-20 10:34:29,985] Trial 10 finished with value: 114950.0 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 1, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2, 'num_workers': 0}. Best is trial 1 with value: 134978.125.
# 2024-08-20 10:34:30,030 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:34:30,031 - INFO - Returning cached result.
# 2024-08-20 10:34:30,031 - INFO - Evaluating with params: {'presolve_bve_threshold': 1000, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 1.0, 'use_lns_only': True, 'feasibility_jump_linearization_level': 1, 'cut_level': 0}, num_runs: 10, knockout_score: 126932.5
# 2024-08-20 10:34:30,032 - INFO - Starting solver with random_seed: 6155791, max_time_in_seconds: 0.5
# 2024-08-20 10:34:30,559 - INFO - Solver found a solution with objective value: 113740.0
# 2024-08-20 10:34:30,560 - INFO - Returning knockout result.
# ...
# 2024-08-20 10:39:37,383 - INFO - Starting solver with random_seed: 1362132571, max_time_in_seconds: 0.5
# 2024-08-20 10:39:37,910 - INFO - Solver found a solution with objective value: 136140.0
# 2024-08-20 10:39:37,911 - INFO - Starting solver with random_seed: 1294870731, max_time_in_seconds: 0.5
# 2024-08-20 10:39:38,448 - INFO - Solver found a solution with objective value: 137155.0
# 2024-08-20 10:39:38,449 - INFO - Starting solver with random_seed: 975496118, max_time_in_seconds: 0.5
# 2024-08-20 10:39:38,980 - INFO - Solver found a solution with objective value: 136415.0
# 2024-08-20 10:39:38,981 - INFO - Starting solver with random_seed: 1638106975, max_time_in_seconds: 0.5
# 2024-08-20 10:39:39,505 - INFO - Solver found a solution with objective value: 134040.0
# 2024-08-20 10:39:39,506 - INFO - Starting solver with random_seed: 946786695, max_time_in_seconds: 0.5
# 2024-08-20 10:39:40,041 - INFO - Solver found a solution with objective value: 136905.0
# 2024-08-20 10:39:40,042 - INFO - Starting solver with random_seed: 1249579830, max_time_in_seconds: 0.5
# 2024-08-20 10:39:40,564 - INFO - Solver found a solution with objective value: 136625.0
# 2024-08-20 10:39:40,565 - INFO - Starting solver with random_seed: 41958572, max_time_in_seconds: 0.5
# 2024-08-20 10:39:41,084 - INFO - Solver found a solution with objective value: 136805.0
# 2024-08-20 10:39:41,085 - INFO - Starting solver with random_seed: 1719969655, max_time_in_seconds: 0.5
# 2024-08-20 10:39:41,605 - INFO - Solver found a solution with objective value: 135925.0
# 2024-08-20 10:39:41,605 - INFO - Starting solver with random_seed: 136683416, max_time_in_seconds: 0.5
# 2024-08-20 10:39:42,136 - INFO - Solver found a solution with objective value: 136920.0
# 2024-08-20 10:39:42,137 - INFO - Starting solver with random_seed: 1802863129, max_time_in_seconds: 0.5
# 2024-08-20 10:39:42,659 - INFO - Solver found a solution with objective value: 136970.0
# 2024-08-20 10:39:42,660 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:39:42,660 - INFO - Parameter 'fp_rounding' can be dropped from the optimized parameters.
# 2024-08-20 10:39:42,661 - INFO - Evaluating resetting parameter 'symmetry_level' to default...
# 2024-08-20 10:39:42,661 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 2, 'max_presolve_iterations': 10, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'search_branching': 7, 'use_lns_only': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 1}, num_runs: 10, knockout_score: None
# 2024-08-20 10:39:42,662 - INFO - Starting solver with random_seed: 1656199295, max_time_in_seconds: 0.5
# 2024-08-20 10:39:43,184 - INFO - Solver found a solution with objective value: 134605.0
# 2024-08-20 10:39:43,185 - INFO - Starting solver with random_seed: 1914190146, max_time_in_seconds: 0.5
# 2024-08-20 10:39:43,708 - INFO - Solver found a solution with objective value: 137000.0
# 2024-08-20 10:39:43,709 - INFO - Starting solver with random_seed: 75500495, max_time_in_seconds: 0.5
# 2024-08-20 10:39:44,236 - INFO - Solver found a solution with objective value: 136400.0
# 2024-08-20 10:39:44,236 - INFO - Starting solver with random_seed: 303756672, max_time_in_seconds: 0.5
# 2024-08-20 10:39:44,756 - INFO - Solver found a solution with objective value: 136170.0
# 2024-08-20 10:39:44,756 - INFO - Starting solver with random_seed: 1606009922, max_time_in_seconds: 0.5
# 2024-08-20 10:39:45,277 - INFO - Solver found a solution with objective value: 135455.0
# 2024-08-20 10:39:45,278 - INFO - Starting solver with random_seed: 364744330, max_time_in_seconds: 0.5
# 2024-08-20 10:39:45,799 - INFO - Solver found a solution with objective value: 136330.0
# 2024-08-20 10:39:45,800 - INFO - Starting solver with random_seed: 1451277594, max_time_in_seconds: 0.5
# 2024-08-20 10:39:46,320 - INFO - Solver found a solution with objective value: 135545.0
# 2024-08-20 10:39:46,321 - INFO - Starting solver with random_seed: 1651042828, max_time_in_seconds: 0.5
# 2024-08-20 10:39:46,841 - INFO - Solver found a solution with objective value: 136600.0
# 2024-08-20 10:39:46,841 - INFO - Starting solver with random_seed: 1625738660, max_time_in_seconds: 0.5
# 2024-08-20 10:39:47,361 - INFO - Solver found a solution with objective value: 136625.0
# 2024-08-20 10:39:47,362 - INFO - Starting solver with random_seed: 1599870062, max_time_in_seconds: 0.5
# 2024-08-20 10:39:47,886 - INFO - Solver found a solution with objective value: 136740.0
# 2024-08-20 10:39:47,887 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:39:47,887 - INFO - Parameter 'symmetry_level' can be dropped from the optimized parameters.
# 2024-08-20 10:39:47,888 - INFO - Evaluating with params: {'cp_model_probing_level': 1}, num_runs: 40, knockout_score: None
# 2024-08-20 10:39:47,888 - INFO - Starting solver with random_seed: 1768957966, max_time_in_seconds: 0.5
# 2024-08-20 10:39:48,414 - INFO - Solver found a solution with objective value: 136505.0
# 2024-08-20 10:39:48,414 - INFO - Starting solver with random_seed: 2002195224, max_time_in_seconds: 0.5
# 2024-08-20 10:39:48,940 - INFO - Solver found a solution with objective value: 134475.0
# 2024-08-20 10:39:48,940 - INFO - Starting solver with random_seed: 913455390, max_time_in_seconds: 0.5
# 2024-08-20 10:39:49,481 - INFO - Solver found a solution with objective value: 133875.0
# 2024-08-20 10:39:49,482 - INFO - Starting solver with random_seed: 1997818738, max_time_in_seconds: 0.5
# 2024-08-20 10:39:50,041 - INFO - Solver found a solution with objective value: 129470.0
# 2024-08-20 10:39:50,042 - INFO - Starting solver with random_seed: 227304952, max_time_in_seconds: 0.5
# 2024-08-20 10:39:50,568 - INFO - Solver found a solution with objective value: 136250.0
# 2024-08-20 10:39:50,569 - INFO - Starting solver with random_seed: 287427206, max_time_in_seconds: 0.5
# 2024-08-20 10:39:51,114 - INFO - Solver found a solution with objective value: 132095.0
# 2024-08-20 10:39:51,114 - INFO - Starting solver with random_seed: 1740388819, max_time_in_seconds: 0.5
# 2024-08-20 10:39:51,641 - INFO - Solver found a solution with objective value: 137075.0
# 2024-08-20 10:39:51,642 - INFO - Starting solver with random_seed: 524067211, max_time_in_seconds: 0.5
# 2024-08-20 10:39:52,168 - INFO - Solver found a solution with objective value: 130625.0
# 2024-08-20 10:39:52,169 - INFO - Starting solver with random_seed: 1674468223, max_time_in_seconds: 0.5
# 2024-08-20 10:39:52,694 - INFO - Solver found a solution with objective value: 132055.0
# 2024-08-20 10:39:52,694 - INFO - Starting solver with random_seed: 939373772, max_time_in_seconds: 0.5
# 2024-08-20 10:39:53,219 - INFO - Solver found a solution with objective value: 137380.0
# 2024-08-20 10:39:53,220 - INFO - Starting solver with random_seed: 1699339847, max_time_in_seconds: 0.5
# 2024-08-20 10:39:53,745 - INFO - Solver found a solution with objective value: 127180.0
# 2024-08-20 10:39:53,746 - INFO - Starting solver with random_seed: 1761921577, max_time_in_seconds: 0.5
# 2024-08-20 10:39:54,271 - INFO - Solver found a solution with objective value: 134730.0
# 2024-08-20 10:39:54,272 - INFO - Starting solver with random_seed: 487202661, max_time_in_seconds: 0.5
# 2024-08-20 10:39:54,796 - INFO - Solver found a solution with objective value: 133175.0
# 2024-08-20 10:39:54,796 - INFO - Starting solver with random_seed: 1080310800, max_time_in_seconds: 0.5
# 2024-08-20 10:39:55,356 - INFO - Solver found a solution with objective value: 132925.0
# 2024-08-20 10:39:55,357 - INFO - Starting solver with random_seed: 2025260524, max_time_in_seconds: 0.5
# 2024-08-20 10:39:55,882 - INFO - Solver found a solution with objective value: 136455.0
# 2024-08-20 10:39:55,883 - INFO - Starting solver with random_seed: 1134183980, max_time_in_seconds: 0.5
# 2024-08-20 10:39:56,407 - INFO - Solver found a solution with objective value: 134415.0
# 2024-08-20 10:39:56,407 - INFO - Starting solver with random_seed: 666048102, max_time_in_seconds: 0.5
# 2024-08-20 10:39:56,960 - INFO - Solver found a solution with objective value: 136750.0
# 2024-08-20 10:39:56,961 - INFO - Starting solver with random_seed: 431420237, max_time_in_seconds: 0.5
# 2024-08-20 10:39:57,486 - INFO - Solver found a solution with objective value: 131690.0
# 2024-08-20 10:39:57,486 - INFO - Starting solver with random_seed: 1925029135, max_time_in_seconds: 0.5
# 2024-08-20 10:39:58,011 - INFO - Solver found a solution with objective value: 128730.0
# 2024-08-20 10:39:58,012 - INFO - Starting solver with random_seed: 707904182, max_time_in_seconds: 0.5
# 2024-08-20 10:39:58,555 - INFO - Solver found a solution with objective value: 134490.0
# 2024-08-20 10:39:58,556 - INFO - Starting solver with random_seed: 263796054, max_time_in_seconds: 0.5
# 2024-08-20 10:39:59,079 - INFO - Solver found a solution with objective value: 133865.0
# 2024-08-20 10:39:59,080 - INFO - Starting solver with random_seed: 1458573879, max_time_in_seconds: 0.5
# 2024-08-20 10:39:59,604 - INFO - Solver found a solution with objective value: 133665.0
# 2024-08-20 10:39:59,605 - INFO - Starting solver with random_seed: 844843908, max_time_in_seconds: 0.5
# 2024-08-20 10:40:00,129 - INFO - Solver found a solution with objective value: 131890.0
# 2024-08-20 10:40:00,130 - INFO - Starting solver with random_seed: 1279843297, max_time_in_seconds: 0.5
# 2024-08-20 10:40:00,656 - INFO - Solver found a solution with objective value: 133695.0
# 2024-08-20 10:40:00,656 - INFO - Starting solver with random_seed: 885816455, max_time_in_seconds: 0.5
# 2024-08-20 10:40:01,211 - INFO - Solver found a solution with objective value: 136705.0
# 2024-08-20 10:40:01,212 - INFO - Starting solver with random_seed: 1436298521, max_time_in_seconds: 0.5
# 2024-08-20 10:40:01,738 - INFO - Solver found a solution with objective value: 134975.0
# 2024-08-20 10:40:01,739 - INFO - Starting solver with random_seed: 1762225620, max_time_in_seconds: 0.5
# 2024-08-20 10:40:02,263 - INFO - Solver found a solution with objective value: 137010.0
# 2024-08-20 10:40:02,264 - INFO - Starting solver with random_seed: 1446150668, max_time_in_seconds: 0.5
# 2024-08-20 10:40:02,789 - INFO - Solver found a solution with objective value: 136000.0
# 2024-08-20 10:40:02,790 - INFO - Starting solver with random_seed: 1464211579, max_time_in_seconds: 0.5
# 2024-08-20 10:40:03,316 - INFO - Solver found a solution with objective value: 136625.0
# 2024-08-20 10:40:03,316 - INFO - Starting solver with random_seed: 2023428180, max_time_in_seconds: 0.5
# 2024-08-20 10:40:03,848 - INFO - Solver found a solution with objective value: 136835.0
# 2024-08-20 10:40:03,849 - INFO - Starting solver with random_seed: 1124277344, max_time_in_seconds: 0.5
# 2024-08-20 10:40:04,382 - INFO - Solver found a solution with objective value: 134720.0
# 2024-08-20 10:40:04,383 - INFO - Starting solver with random_seed: 232099024, max_time_in_seconds: 0.5
# 2024-08-20 10:40:04,909 - INFO - Solver found a solution with objective value: 134915.0
# 2024-08-20 10:40:04,909 - INFO - Starting solver with random_seed: 587011341, max_time_in_seconds: 0.5
# 2024-08-20 10:40:05,434 - INFO - Solver found a solution with objective value: 135170.0
# 2024-08-20 10:40:05,434 - INFO - Starting solver with random_seed: 495027555, max_time_in_seconds: 0.5
# 2024-08-20 10:40:05,993 - INFO - Solver found a solution with objective value: 135265.0
# 2024-08-20 10:40:05,994 - INFO - Starting solver with random_seed: 306335946, max_time_in_seconds: 0.5
# 2024-08-20 10:40:06,519 - INFO - Solver found a solution with objective value: 133680.0
# 2024-08-20 10:40:06,519 - INFO - Starting solver with random_seed: 1815932062, max_time_in_seconds: 0.5
# 2024-08-20 10:40:07,044 - INFO - Solver found a solution with objective value: 130920.0
# 2024-08-20 10:40:07,044 - INFO - Starting solver with random_seed: 215336588, max_time_in_seconds: 0.5
# 2024-08-20 10:40:07,593 - INFO - Solver found a solution with objective value: 136530.0
# 2024-08-20 10:40:07,594 - INFO - Starting solver with random_seed: 963031511, max_time_in_seconds: 0.5
# 2024-08-20 10:40:08,119 - INFO - Solver found a solution with objective value: 136530.0
# 2024-08-20 10:40:08,120 - INFO - Starting solver with random_seed: 1365572358, max_time_in_seconds: 0.5
# 2024-08-20 10:40:08,645 - INFO - Solver found a solution with objective value: 135405.0
# 2024-08-20 10:40:08,646 - INFO - Starting solver with random_seed: 190549479, max_time_in_seconds: 0.5
# 2024-08-20 10:40:09,171 - INFO - Solver found a solution with objective value: 134625.0
# 2024-08-20 10:40:09,171 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:40:09,172 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter              ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ cp_model_probing_level │   1   │   100.00%    │       2       │
# └─────┴────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                                    ┃      Mean ┃      Min ┃      Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━┩
# │ Objective [MAX] with Default Parameters   │ 134088.75 │ 127820.0 │ 136695.0 │       40 │
# │ Objective [MAX] with Optimized Parameters │ 134234.25 │ 127180.0 │ 137380.0 │       40 │
# └───────────────────────────────────────────┴───────────┴──────────┴──────────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-20 10:40:09,183 - INFO - Hyperparameter tuning completed.
# 2024-08-20 10:40:09,184 - INFO - Tuning for quality within time limit completed.

# %%
best = tune_for_gap_within_timelimit(
    model,
    max_time_in_seconds=0.5,
    n_samples_for_trial=10,  # Number of samples for each trial
    n_samples_for_verification=40,  # Number of samples for each statistically relevant comparison.
    n_trials=50,  # Number of trials to run with Optuna
)
# Out:
# 2024-08-20 10:40:09,190 - INFO - Starting tuning for gap within time limit. Limit: 10
# 2024-08-20 10:40:09,190 - INFO - Initialized Metric with direction: minimize
# 2024-08-20 10:40:09,191 - INFO - Starting hyperparameter tuning with 50 trials.
# 2024-08-20 10:40:09,191 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:09,191 - INFO - Starting solver with random_seed: 2024416477, max_time_in_seconds: 0.5
# 2024-08-20 10:40:09,729 - INFO - Solver found a solution with objective value: 133695.0
# 2024-08-20 10:40:09,729 - INFO - Starting solver with random_seed: 187553639, max_time_in_seconds: 0.5
# 2024-08-20 10:40:10,258 - INFO - Solver found a solution with objective value: 135245.0
# 2024-08-20 10:40:10,258 - INFO - Starting solver with random_seed: 1757071169, max_time_in_seconds: 0.5
# 2024-08-20 10:40:10,804 - INFO - Solver found a solution with objective value: 136300.0
# 2024-08-20 10:40:10,804 - INFO - Starting solver with random_seed: 934348371, max_time_in_seconds: 0.5
# 2024-08-20 10:40:11,330 - INFO - Solver found a solution with objective value: 135700.0
# 2024-08-20 10:40:11,331 - INFO - Starting solver with random_seed: 1105650601, max_time_in_seconds: 0.5
# 2024-08-20 10:40:11,887 - INFO - Solver found a solution with objective value: 131825.0
# 2024-08-20 10:40:11,888 - INFO - Starting solver with random_seed: 426238421, max_time_in_seconds: 0.5
# 2024-08-20 10:40:12,417 - INFO - Solver found a solution with objective value: 133450.0
# 2024-08-20 10:40:12,418 - INFO - Starting solver with random_seed: 1961482108, max_time_in_seconds: 0.5
# 2024-08-20 10:40:12,963 - INFO - Solver found a solution with objective value: 132135.0
# 2024-08-20 10:40:12,964 - INFO - Starting solver with random_seed: 1522896506, max_time_in_seconds: 0.5
# 2024-08-20 10:40:13,491 - INFO - Solver found a solution with objective value: 136580.0
# 2024-08-20 10:40:13,491 - INFO - Starting solver with random_seed: 1791144650, max_time_in_seconds: 0.5
# 2024-08-20 10:40:14,018 - INFO - Solver found a solution with objective value: 133340.0
# 2024-08-20 10:40:14,018 - INFO - Starting solver with random_seed: 1345780726, max_time_in_seconds: 0.5
# 2024-08-20 10:40:14,545 - INFO - Solver found a solution with objective value: 134420.0
# 2024-08-20 10:40:14,545 - INFO - Starting solver with random_seed: 1319560158, max_time_in_seconds: 0.5
# 2024-08-20 10:40:15,070 - INFO - Solver found a solution with objective value: 129465.0
# 2024-08-20 10:40:15,070 - INFO - Starting solver with random_seed: 972066160, max_time_in_seconds: 0.5
# 2024-08-20 10:40:15,618 - INFO - Solver found a solution with objective value: 134445.0
# 2024-08-20 10:40:15,618 - INFO - Starting solver with random_seed: 1246926, max_time_in_seconds: 0.5
# 2024-08-20 10:40:16,173 - INFO - Solver found a solution with objective value: 134800.0
# 2024-08-20 10:40:16,173 - INFO - Starting solver with random_seed: 640705721, max_time_in_seconds: 0.5
# 2024-08-20 10:40:16,733 - INFO - Solver found a solution with objective value: 132965.0
# 2024-08-20 10:40:16,733 - INFO - Starting solver with random_seed: 2123433330, max_time_in_seconds: 0.5
# 2024-08-20 10:40:17,260 - INFO - Solver found a solution with objective value: 135080.0
# 2024-08-20 10:40:17,260 - INFO - Starting solver with random_seed: 28440431, max_time_in_seconds: 0.5
# 2024-08-20 10:40:17,813 - INFO - Solver found a solution with objective value: 134285.0
# 2024-08-20 10:40:17,813 - INFO - Starting solver with random_seed: 2010159719, max_time_in_seconds: 0.5
# 2024-08-20 10:40:18,338 - INFO - Solver found a solution with objective value: 134900.0
# 2024-08-20 10:40:18,339 - INFO - Starting solver with random_seed: 1828325224, max_time_in_seconds: 0.5
# 2024-08-20 10:40:18,897 - INFO - Solver found a solution with objective value: 133795.0
# 2024-08-20 10:40:18,897 - INFO - Starting solver with random_seed: 1420348652, max_time_in_seconds: 0.5
# 2024-08-20 10:40:19,436 - INFO - Solver found a solution with objective value: 133840.0
# 2024-08-20 10:40:19,437 - INFO - Starting solver with random_seed: 554708845, max_time_in_seconds: 0.5
# 2024-08-20 10:40:19,986 - INFO - Solver found a solution with objective value: 127675.0
# 2024-08-20 10:40:19,986 - INFO - Starting solver with random_seed: 1617025262, max_time_in_seconds: 0.5
# 2024-08-20 10:40:20,522 - INFO - Solver found a solution with objective value: 135070.0
# 2024-08-20 10:40:20,522 - INFO - Starting solver with random_seed: 339879424, max_time_in_seconds: 0.5
# 2024-08-20 10:40:21,076 - INFO - Solver found a solution with objective value: 135040.0
# 2024-08-20 10:40:21,077 - INFO - Starting solver with random_seed: 462675895, max_time_in_seconds: 0.5
# 2024-08-20 10:40:21,602 - INFO - Solver found a solution with objective value: 133680.0
# 2024-08-20 10:40:21,602 - INFO - Starting solver with random_seed: 1139369735, max_time_in_seconds: 0.5
# 2024-08-20 10:40:22,128 - INFO - Solver found a solution with objective value: 129030.0
# 2024-08-20 10:40:22,128 - INFO - Starting solver with random_seed: 574005523, max_time_in_seconds: 0.5
# 2024-08-20 10:40:22,654 - INFO - Solver found a solution with objective value: 136505.0
# 2024-08-20 10:40:22,655 - INFO - Starting solver with random_seed: 94529861, max_time_in_seconds: 0.5
# 2024-08-20 10:40:23,184 - INFO - Solver found a solution with objective value: 135195.0
# 2024-08-20 10:40:23,184 - INFO - Starting solver with random_seed: 1410449225, max_time_in_seconds: 0.5
# 2024-08-20 10:40:23,710 - INFO - Solver found a solution with objective value: 133315.0
# 2024-08-20 10:40:23,710 - INFO - Starting solver with random_seed: 917102847, max_time_in_seconds: 0.5
# 2024-08-20 10:40:24,266 - INFO - Solver found a solution with objective value: 135600.0
# 2024-08-20 10:40:24,266 - INFO - Starting solver with random_seed: 236130616, max_time_in_seconds: 0.5
# 2024-08-20 10:40:24,807 - INFO - Solver found a solution with objective value: 135445.0
# 2024-08-20 10:40:24,807 - INFO - Starting solver with random_seed: 1341127889, max_time_in_seconds: 0.5
# 2024-08-20 10:40:25,333 - INFO - Solver found a solution with objective value: 136255.0
# 2024-08-20 10:40:25,333 - INFO - Starting solver with random_seed: 1264069495, max_time_in_seconds: 0.5
# 2024-08-20 10:40:25,861 - INFO - Solver found a solution with objective value: 133715.0
# 2024-08-20 10:40:25,861 - INFO - Starting solver with random_seed: 521847401, max_time_in_seconds: 0.5
# 2024-08-20 10:40:26,407 - INFO - Solver found a solution with objective value: 136650.0
# 2024-08-20 10:40:26,408 - INFO - Starting solver with random_seed: 1324721235, max_time_in_seconds: 0.5
# 2024-08-20 10:40:26,933 - INFO - Solver found a solution with objective value: 133800.0
# 2024-08-20 10:40:26,934 - INFO - Starting solver with random_seed: 277131768, max_time_in_seconds: 0.5
# 2024-08-20 10:40:27,460 - INFO - Solver found a solution with objective value: 137230.0
# 2024-08-20 10:40:27,461 - INFO - Starting solver with random_seed: 2046327326, max_time_in_seconds: 0.5
# 2024-08-20 10:40:27,987 - INFO - Solver found a solution with objective value: 134820.0
# 2024-08-20 10:40:27,988 - INFO - Starting solver with random_seed: 57055354, max_time_in_seconds: 0.5
# 2024-08-20 10:40:28,512 - INFO - Solver found a solution with objective value: 136630.0
# 2024-08-20 10:40:28,513 - INFO - Starting solver with random_seed: 1260208592, max_time_in_seconds: 0.5
# 2024-08-20 10:40:29,053 - INFO - Solver found a solution with objective value: 135925.0
# 2024-08-20 10:40:29,054 - INFO - Starting solver with random_seed: 1642954139, max_time_in_seconds: 0.5
# 2024-08-20 10:40:29,603 - INFO - Solver found a solution with objective value: 134805.0
# 2024-08-20 10:40:29,604 - INFO - Starting solver with random_seed: 788586662, max_time_in_seconds: 0.5
# 2024-08-20 10:40:30,129 - INFO - Solver found a solution with objective value: 136530.0
# 2024-08-20 10:40:30,129 - INFO - Starting solver with random_seed: 1312441857, max_time_in_seconds: 0.5
# 2024-08-20 10:40:30,690 - INFO - Solver found a solution with objective value: 134200.0
# 2024-08-20 10:40:30,691 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:40:30,691 - INFO - Baseline evaluation completed: min=0.008197915907600379, mean=0.0322656060171803, max=0.08744859996083806
# [I 2024-08-20 10:40:30,692] A new study created in memory with name: no-name-2f915972-0614-4996-957e-8b2ab5a65c84
# 2024-08-20 10:40:30,692 - INFO - Starting Optuna optimization.
# 2024-08-20 10:40:30,694 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:30,694 - INFO - Returning cached result.
# 2024-08-20 10:40:30,694 - INFO - Evaluating with params: {}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:30,695 - INFO - Returning cached result.
# 2024-08-20 10:40:30,695 - INFO - The trial yielded the best result so far, increasing the number of samples to be sure.
# 2024-08-20 10:40:30,695 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:30,696 - INFO - Returning cached result.
# [I 2024-08-20 10:40:30,697] Trial 0 finished with value: 0.0322656060171803 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 2, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:30,701 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:30,702 - INFO - Returning cached result.
# 2024-08-20 10:40:30,702 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'presolve_probing_deterministic_time_limit': 1.0, 'ignore_subsolvers': ['fixed', 'reduced_costs', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 4, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'linearization_level': 2, 'cut_level': 0, 'max_all_diff_cut_size': 32, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:30,703 - INFO - Starting solver with random_seed: 2045464637, max_time_in_seconds: 0.5
# 2024-08-20 10:40:31,232 - INFO - Solver found a solution with objective value: 112155.0
# 2024-08-20 10:40:31,233 - INFO - Returning knockout result.
# [I 2024-08-20 10:40:31,234] Trial 1 finished with value: 2.0513574963220544 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 0, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 4, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 0, 'symmetry_level': 1, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:31,237 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:31,238 - INFO - Returning cached result.
# 2024-08-20 10:40:31,238 - INFO - Evaluating with params: {'preferred_variable_order': 2, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 1, 'ignore_subsolvers': ['fixed', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart', 'probing'], 'search_branching': 1, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'max_all_diff_cut_size': 128, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:31,238 - INFO - Starting solver with random_seed: 2116453817, max_time_in_seconds: 0.5
# 2024-08-20 10:40:31,759 - INFO - Solver found a solution with objective value: 116775.0
# 2024-08-20 10:40:31,759 - INFO - Returning knockout result.
# [I 2024-08-20 10:40:31,760] Trial 2 finished with value: 5.227574395204453 and parameters: {'preferred_variable_order': 2, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 3, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 2, 'symmetry_level': 1, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:31,763 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:31,764 - INFO - Returning cached result.
# 2024-08-20 10:40:31,764 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0.1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'lb_tree_search'], 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'optimize_with_core': True, 'diversify_lns_params': True, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:31,764 - INFO - Starting solver with random_seed: 225747326, max_time_in_seconds: 0.5
# 2024-08-20 10:40:32,304 - INFO - Solver found a solution with objective value: 134280.0
# 2024-08-20 10:40:32,305 - INFO - Starting solver with random_seed: 2041963209, max_time_in_seconds: 0.5
# 2024-08-20 10:40:32,826 - INFO - Solver found a solution with objective value: 95615.0
# 2024-08-20 10:40:32,826 - INFO - Returning knockout result.
# [I 2024-08-20 10:40:32,827] Trial 3 finished with value: 0.45521100245777335 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 3, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 0, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 2, 'symmetry_level': 0, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:32,831 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:32,831 - INFO - Returning cached result.
# 2024-08-20 10:40:32,831 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'binary_minimization_algorithm': 2, 'presolve_bve_threshold': 100, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'reduced_costs', 'lb_tree_search', 'probing'], 'search_branching': 1, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 2, 'add_objective_cut': True, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:32,831 - INFO - Starting solver with random_seed: 338447909, max_time_in_seconds: 0.5
# 2024-08-20 10:40:33,353 - INFO - Solver found a solution with objective value: 114035.0
# 2024-08-20 10:40:33,354 - INFO - Returning knockout result.
# [I 2024-08-20 10:40:33,355] Trial 4 finished with value: 5.794975226904021 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 1, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 2, 'add_objective_cut': True, 'cut_level': 1, 'max_all_diff_cut_size': 1, 'symmetry_level': 1, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:33,358 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:33,359 - INFO - Returning cached result.
# 2024-08-20 10:40:33,359 - INFO - Evaluating with params: {'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'max_lp', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 8, 'repair_hint': True, 'fp_rounding': 1, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:33,359 - INFO - Starting solver with random_seed: 434993716, max_time_in_seconds: 0.5
# 2024-08-20 10:40:33,891 - INFO - Solver found a solution with objective value: 134425.0
# 2024-08-20 10:40:33,892 - INFO - Starting solver with random_seed: 1871521502, max_time_in_seconds: 0.5
# 2024-08-20 10:40:34,414 - INFO - Solver found a solution with objective value: 132740.0
# 2024-08-20 10:40:34,415 - INFO - Starting solver with random_seed: 1114811037, max_time_in_seconds: 0.5
# 2024-08-20 10:40:34,944 - INFO - Solver found a solution with objective value: 134470.0
# 2024-08-20 10:40:34,945 - INFO - Starting solver with random_seed: 112620748, max_time_in_seconds: 0.5
# 2024-08-20 10:40:35,477 - INFO - Solver found a solution with objective value: 135760.0
# 2024-08-20 10:40:35,477 - INFO - Starting solver with random_seed: 830065454, max_time_in_seconds: 0.5
# 2024-08-20 10:40:36,008 - INFO - Solver found a solution with objective value: 134085.0
# 2024-08-20 10:40:36,009 - INFO - Starting solver with random_seed: 2084454478, max_time_in_seconds: 0.5
# 2024-08-20 10:40:36,539 - INFO - Solver found a solution with objective value: 135230.0
# 2024-08-20 10:40:36,540 - INFO - Starting solver with random_seed: 56317926, max_time_in_seconds: 0.5
# 2024-08-20 10:40:37,067 - INFO - Solver found a solution with objective value: 135505.0
# 2024-08-20 10:40:37,067 - INFO - Starting solver with random_seed: 1673698194, max_time_in_seconds: 0.5
# 2024-08-20 10:40:37,592 - INFO - Solver found a solution with objective value: 135355.0
# 2024-08-20 10:40:37,593 - INFO - Starting solver with random_seed: 1581907098, max_time_in_seconds: 0.5
# 2024-08-20 10:40:38,117 - INFO - Solver found a solution with objective value: 134375.0
# 2024-08-20 10:40:38,117 - INFO - Starting solver with random_seed: 366226162, max_time_in_seconds: 0.5
# 2024-08-20 10:40:38,642 - INFO - Solver found a solution with objective value: 135825.0
# 2024-08-20 10:40:38,643 - INFO - Evaluation completed and result cached.
# [I 2024-08-20 10:40:38,644] Trial 5 finished with value: 0.03313393157120272 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 1, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 8, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 0, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:38,647 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:38,647 - INFO - Returning cached result.
# 2024-08-20 10:40:38,647 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp'], 'search_branching': 2, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'linearization_level': 0, 'max_all_diff_cut_size': 32}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:38,648 - INFO - Starting solver with random_seed: 1875340259, max_time_in_seconds: 0.5
# 2024-08-20 10:40:39,181 - INFO - Solver found a solution with objective value: 136260.0
# 2024-08-20 10:40:39,182 - INFO - Returning knockout result.
# [I 2024-08-20 10:40:39,183] Trial 6 finished with value: 2.5212094525172466 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 0, 'max_presolve_iterations': 4, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 2, 'repair_hint': True, 'use_lns_only': True, 'use_lb_relax_lns': True, 'use_objective_lb_search': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 1, 'max_all_diff_cut_size': 0, 'symmetry_level': 2, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:39,186 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:39,186 - INFO - Returning cached result.
# 2024-08-20 10:40:39,187 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 0.1, 'ignore_subsolvers': ['pseudo_costs', 'reduced_costs', 'quick_restart', 'quick_restart_no_lp', 'lb_tree_search', 'probing'], 'search_branching': 4, 'repair_hint': True, 'use_objective_lb_search': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'add_objective_cut': True, 'cut_level': 2, 'symmetry_level': 0, 'num_workers': 8}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:39,187 - INFO - Starting solver with random_seed: 590458098, max_time_in_seconds: 0.5
# 2024-08-20 10:40:39,728 - INFO - Solver found a solution with objective value: 133825.0
# 2024-08-20 10:40:39,728 - INFO - Starting solver with random_seed: 1485450825, max_time_in_seconds: 0.5
# 2024-08-20 10:40:40,305 - INFO - Solver found a solution with objective value: 135185.0
# 2024-08-20 10:40:40,305 - INFO - Starting solver with random_seed: 607695931, max_time_in_seconds: 0.5
# 2024-08-20 10:40:40,916 - INFO - Solver found a solution with objective value: 135100.0
# 2024-08-20 10:40:40,917 - INFO - Starting solver with random_seed: 783113577, max_time_in_seconds: 0.5
# 2024-08-20 10:40:41,449 - INFO - Solver found a solution with objective value: 133800.0
# 2024-08-20 10:40:41,449 - INFO - Starting solver with random_seed: 515993986, max_time_in_seconds: 0.5
# 2024-08-20 10:40:41,971 - INFO - Solver found a solution with objective value: 134330.0
# 2024-08-20 10:40:41,972 - INFO - Starting solver with random_seed: 795811210, max_time_in_seconds: 0.5
# 2024-08-20 10:40:42,492 - INFO - Solver found a solution with objective value: 133960.0
# 2024-08-20 10:40:42,493 - INFO - Starting solver with random_seed: 1063363539, max_time_in_seconds: 0.5
# 2024-08-20 10:40:43,051 - INFO - Solver found a solution with objective value: 135215.0
# 2024-08-20 10:40:43,052 - INFO - Starting solver with random_seed: 1734434719, max_time_in_seconds: 0.5
# 2024-08-20 10:40:43,573 - INFO - Solver found a solution with objective value: 133715.0
# 2024-08-20 10:40:43,574 - INFO - Starting solver with random_seed: 1703366443, max_time_in_seconds: 0.5
# 2024-08-20 10:40:44,117 - INFO - Solver found a solution with objective value: 135420.0
# 2024-08-20 10:40:44,118 - INFO - Starting solver with random_seed: 145196954, max_time_in_seconds: 0.5
# 2024-08-20 10:40:44,638 - INFO - Solver found a solution with objective value: 134085.0
# 2024-08-20 10:40:44,639 - INFO - Evaluation completed and result cached.
# [I 2024-08-20 10:40:44,640] Trial 7 finished with value: 0.033479989872512016 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 0, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': True, 'search_branching': 4, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': True, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 1, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 1, 'symmetry_level': 0, 'num_workers': 1}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:44,643 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:44,643 - INFO - Returning cached result.
# 2024-08-20 10:40:44,643 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 2, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 10.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'max_lp', 'pseudo_costs', 'reduced_costs', 'quick_restart_no_lp', 'probing'], 'use_lns_only': True, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 0, 'num_workers': 8}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:44,644 - INFO - Starting solver with random_seed: 1598333197, max_time_in_seconds: 0.5
# 2024-08-20 10:40:45,248 - INFO - Solver found a solution with objective value: 134785.0
# 2024-08-20 10:40:45,248 - INFO - Returning knockout result.
# [I 2024-08-20 10:40:45,249] Trial 8 finished with value: 3.597507141002337 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': True, 'also_bump_variables_in_conflict_reasons': True, 'binary_minimization_algorithm': 4, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 1, 'cp_model_probing_level': 1, 'presolve_probing_deterministic_time_limit': 3, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': True, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': True, 'search_branching': 0, 'repair_hint': False, 'use_lns_only': True, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': True, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 2, 'diversify_lns_params': True, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 2, 'symmetry_level': 0, 'num_workers': 1}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:45,253 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:45,253 - INFO - Returning cached result.
# 2024-08-20 10:40:45,253 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 1000, 'max_presolve_iterations': 5, 'cp_model_probing_level': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['default_lp', 'no_lp', 'max_lp', 'reduced_costs'], 'search_branching': 7, 'repair_hint': True, 'use_lb_relax_lns': True, 'use_objective_shaving_search': True, 'feasibility_jump_linearization_level': 0, 'polish_lp_solution': True, 'linearization_level': 2, 'cut_level': 0, 'symmetry_level': 1}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:45,253 - INFO - Starting solver with random_seed: 2098320963, max_time_in_seconds: 0.5
# 2024-08-20 10:40:45,778 - INFO - Solver found a solution with objective value: 135530.0
# 2024-08-20 10:40:45,779 - INFO - Returning knockout result.
# [I 2024-08-20 10:40:45,781] Trial 9 finished with value: 5.713347598317716 and parameters: {'preferred_variable_order': 1, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 2, 'clause_cleanup_protection': 1, 'presolve_bve_threshold': 2, 'max_presolve_iterations': 3, 'cp_model_probing_level': 0, 'presolve_probing_deterministic_time_limit': 4, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': True, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': True, 'ignore_subsolvers:max_lp': True, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': True, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 7, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': True, 'use_objective_lb_search': False, 'use_objective_shaving_search': True, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 2, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 2, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 1, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:45,826 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:45,826 - INFO - Returning cached result.
# 2024-08-20 10:40:45,826 - INFO - Evaluating with params: {'presolve_probing_deterministic_time_limit': 5.0, 'ignore_subsolvers': ['fixed', 'quick_restart'], 'search_branching': 5, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 32, 'num_workers': 8}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:45,827 - INFO - Starting solver with random_seed: 1076217962, max_time_in_seconds: 0.5
# 2024-08-20 10:40:46,349 - INFO - Solver found a solution with objective value: 130810.0
# 2024-08-20 10:40:46,350 - INFO - Starting solver with random_seed: 384825587, max_time_in_seconds: 0.5
# 2024-08-20 10:40:46,872 - INFO - Solver found a solution with objective value: 132345.0
# 2024-08-20 10:40:46,872 - INFO - Starting solver with random_seed: 2140300823, max_time_in_seconds: 0.5
# 2024-08-20 10:40:47,396 - INFO - Solver found a solution with objective value: 131940.0
# 2024-08-20 10:40:47,397 - INFO - Starting solver with random_seed: 2052481678, max_time_in_seconds: 0.5
# 2024-08-20 10:40:47,917 - INFO - Solver found a solution with objective value: 131910.0
# 2024-08-20 10:40:47,918 - INFO - Starting solver with random_seed: 1464839567, max_time_in_seconds: 0.5
# 2024-08-20 10:40:48,439 - INFO - Solver found a solution with objective value: 135435.0
# 2024-08-20 10:40:48,440 - INFO - Starting solver with random_seed: 1329255463, max_time_in_seconds: 0.5
# 2024-08-20 10:40:48,961 - INFO - Solver found a solution with objective value: 131730.0
# 2024-08-20 10:40:48,961 - INFO - Starting solver with random_seed: 1675748344, max_time_in_seconds: 0.5
# 2024-08-20 10:40:49,483 - INFO - Solver found a solution with objective value: 131440.0
# 2024-08-20 10:40:49,484 - INFO - Starting solver with random_seed: 1411422461, max_time_in_seconds: 0.5
# 2024-08-20 10:40:50,005 - INFO - Solver found a solution with objective value: 133250.0
# 2024-08-20 10:40:50,006 - INFO - Starting solver with random_seed: 1881740310, max_time_in_seconds: 0.5
# 2024-08-20 10:40:50,543 - INFO - Solver found a solution with objective value: 131750.0
# 2024-08-20 10:40:50,543 - INFO - Starting solver with random_seed: 638908988, max_time_in_seconds: 0.5
# 2024-08-20 10:40:51,065 - INFO - Solver found a solution with objective value: 131155.0
# 2024-08-20 10:40:51,066 - INFO - Evaluation completed and result cached.
# [I 2024-08-20 10:40:51,067] Trial 10 finished with value: 0.04970297669667441 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 0, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 2, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': False, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': True, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': True, 'ignore_subsolvers:quick_restart_no_lp': False, 'ignore_subsolvers:lb_tree_search': False, 'ignore_subsolvers:probing': False, 'search_branching': 5, 'repair_hint': False, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 1, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': True, 'linearization_level': 0, 'add_objective_cut': True, 'cut_level': 2, 'max_all_diff_cut_size': 0, 'symmetry_level': 2, 'num_workers': 1}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:51,113 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:51,113 - INFO - Returning cached result.
# 2024-08-20 10:40:51,113 - INFO - Evaluating with params: {'clause_cleanup_protection': 2, 'max_presolve_iterations': 2, 'presolve_probing_deterministic_time_limit': 5.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['quick_restart_no_lp', 'lb_tree_search'], 'search_branching': 8, 'repair_hint': True, 'fp_rounding': 1, 'cut_level': 0}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:51,113 - INFO - Starting solver with random_seed: 235229124, max_time_in_seconds: 0.5
# 2024-08-20 10:40:51,638 - INFO - Solver found a solution with objective value: 132800.0
# 2024-08-20 10:40:51,639 - INFO - Starting solver with random_seed: 741078314, max_time_in_seconds: 0.5
# 2024-08-20 10:40:52,164 - INFO - Solver found a solution with objective value: 136825.0
# 2024-08-20 10:40:52,164 - INFO - Starting solver with random_seed: 773309814, max_time_in_seconds: 0.5
# 2024-08-20 10:40:52,699 - INFO - Solver found a solution with objective value: 134750.0
# 2024-08-20 10:40:52,700 - INFO - Starting solver with random_seed: 1078922455, max_time_in_seconds: 0.5
# 2024-08-20 10:40:53,231 - INFO - Solver found a solution with objective value: 133730.0
# 2024-08-20 10:40:53,231 - INFO - Starting solver with random_seed: 1894600824, max_time_in_seconds: 0.5
# 2024-08-20 10:40:53,756 - INFO - Solver found a solution with objective value: 134380.0
# 2024-08-20 10:40:53,757 - INFO - Starting solver with random_seed: 1684501338, max_time_in_seconds: 0.5
# 2024-08-20 10:40:54,283 - INFO - Solver found a solution with objective value: 135955.0
# 2024-08-20 10:40:54,283 - INFO - Starting solver with random_seed: 1159204841, max_time_in_seconds: 0.5
# 2024-08-20 10:40:54,809 - INFO - Solver found a solution with objective value: 133990.0
# 2024-08-20 10:40:54,809 - INFO - Starting solver with random_seed: 1866632711, max_time_in_seconds: 0.5
# 2024-08-20 10:40:55,338 - INFO - Solver found a solution with objective value: 135420.0
# 2024-08-20 10:40:55,338 - INFO - Starting solver with random_seed: 504580875, max_time_in_seconds: 0.5
# 2024-08-20 10:40:55,861 - INFO - Solver found a solution with objective value: 135930.0
# 2024-08-20 10:40:55,862 - INFO - Starting solver with random_seed: 1917070347, max_time_in_seconds: 0.5
# 2024-08-20 10:40:56,393 - INFO - Solver found a solution with objective value: 133635.0
# 2024-08-20 10:40:56,394 - INFO - Evaluation completed and result cached.
# [I 2024-08-20 10:40:56,396] Trial 11 finished with value: 0.03364623197044983 and parameters: {'preferred_variable_order': 0, 'use_erwa_heuristic': False, 'also_bump_variables_in_conflict_reasons': False, 'binary_minimization_algorithm': 1, 'clause_cleanup_protection': 2, 'presolve_bve_threshold': 1, 'max_presolve_iterations': 1, 'cp_model_probing_level': 2, 'presolve_probing_deterministic_time_limit': 2, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers:default_lp': False, 'ignore_subsolvers:fixed': False, 'ignore_subsolvers:no_lp': False, 'ignore_subsolvers:max_lp': False, 'ignore_subsolvers:pseudo_costs': False, 'ignore_subsolvers:reduced_costs': False, 'ignore_subsolvers:quick_restart': False, 'ignore_subsolvers:quick_restart_no_lp': True, 'ignore_subsolvers:lb_tree_search': True, 'ignore_subsolvers:probing': False, 'search_branching': 8, 'repair_hint': True, 'use_lns_only': False, 'use_lb_relax_lns': False, 'use_objective_lb_search': False, 'use_objective_shaving_search': False, 'optimize_with_core': False, 'feasibility_jump_linearization_level': 2, 'fp_rounding': 1, 'diversify_lns_params': False, 'polish_lp_solution': False, 'linearization_level': 1, 'add_objective_cut': False, 'cut_level': 0, 'max_all_diff_cut_size': 1, 'symmetry_level': 2, 'num_workers': 0}. Best is trial 0 with value: 0.0322656060171803.
# 2024-08-20 10:40:56,442 - INFO - Evaluating with params: {}, num_runs: 40, knockout_score: None
# 2024-08-20 10:40:56,442 - INFO - Returning cached result.
# 2024-08-20 10:40:56,443 - INFO - Evaluating with params: {'clause_cleanup_protection': 2, 'presolve_bve_threshold': 100, 'max_presolve_iterations': 1, 'presolve_probing_deterministic_time_limit': 1.0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['no_lp', 'lb_tree_search'], 'search_branching': 8, 'repair_hint': True, 'fp_rounding': 1, 'max_all_diff_cut_size': 128}, num_runs: 10, knockout_score: 0.09537366836616183
# 2024-08-20 10:40:56,443 - INFO - Starting solver with random_seed: 771955812, max_time_in_seconds: 0.5
# 2024-08-20 10:40:57,033 - INFO - Solver found a solution with objective value: 131970.0
# 2024-08-20 10:40:57,034 - INFO - Starting solver with random_seed: 1924579865, max_time_in_seconds: 0.5
# 2024-08-20 10:40:57,664 - INFO - Solver found a solution with objective value: 129705.0
# 2024-08-20 10:40:57,664 - INFO - Starting solver with random_seed: 1411894292, max_time_in_seconds: 0.5
# 2024-08-20 10:40:58,302 - INFO - Solver found a solution with objective value: 134575.0
# 2024-08-20 10:40:58,303 - INFO - Starting solver with random_seed: 1611218013, max_time_in_seconds: 0.5
# 2024-08-20 10:40:58,887 - INFO - Solver found a solution with objective value: 132770.0
# 2024-08-20 10:40:58,888 - INFO - Starting solver with random_seed: 1931716491, max_time_in_seconds: 0.5
# 2024-08-20 10:40:59,542 - INFO - Solver found a solution with objective value: 136950.0
# 2024-08-20 10:40:59,543 - INFO - Starting solver with random_seed: 1865132704, max_time_in_seconds: 0.5
# 2024-08-20 10:41:00,192 - INFO - Solver found a solution with objective value: 135360.0
# 2024-08-20 10:41:00,193 - INFO - Starting solver with random_seed: 728986162, max_time_in_seconds: 0.5
# 2024-08-20 10:41:00,754 - INFO - Solver found a solution with objective value: 134700.0
# 2024-08-20 10:41:00,755 - INFO - Starting solver with random_seed: 961751493, max_time_in_seconds: 0.5
# 2024-08-20 10:41:01,402 - INFO - Solver found a solution with objective value: 132370.0
# 2024-08-20 10:41:01,402 - INFO - Starting solver with random_seed: 1291417202, max_time_in_seconds: 0.5
# 2024-08-20 10:41:02,030 - INFO - Solver found a solution with objective value: 135760.0
# 2024-08-20 10:41:02,031 - INFO - Starting solver with random_seed: 1009272839, max_time_in_seconds: 0.5
# 2024-08-20 10:41:02,622 - INFO - Solver found a solution with objective value: 132590.0
# 2024-08-20 10:41:02,623 - INFO - Evaluation completed and result cached.
# ...
# 2024-08-20 10:46:08,636 - INFO - Evaluating with params: {'preferred_variable_order': 1, 'binary_minimization_algorithm': 0, 'max_presolve_iterations': 10, 'cp_model_probing_level': 0, 'encode_complex_linear_constraint_with_integer': True, 'ignore_subsolvers': ['fixed', 'pseudo_costs', 'quick_restart', 'probing'], 'search_branching': 6, 'repair_hint': True, 'use_lb_relax_lns': True, 'feasibility_jump_linearization_level': 0, 'fp_rounding': 0, 'linearization_level': 0, 'cut_level': 0, 'max_all_diff_cut_size': 128, 'symmetry_level': 0}, num_runs: 10, knockout_score: None
# 2024-08-20 10:46:08,636 - INFO - Starting solver with random_seed: 319321068, max_time_in_seconds: 0.5
# 2024-08-20 10:46:09,192 - INFO - Solver found a solution with objective value: 136985.0
# 2024-08-20 10:46:09,193 - INFO - Starting solver with random_seed: 179228237, max_time_in_seconds: 0.5
# 2024-08-20 10:46:09,725 - INFO - Solver found a solution with objective value: 136690.0
# 2024-08-20 10:46:09,725 - INFO - Starting solver with random_seed: 1019052089, max_time_in_seconds: 0.5
# 2024-08-20 10:46:10,248 - INFO - Solver found a solution with objective value: 134750.0
# 2024-08-20 10:46:10,248 - INFO - Starting solver with random_seed: 253133907, max_time_in_seconds: 0.5
# 2024-08-20 10:46:10,774 - INFO - Solver found a solution with objective value: 136665.0
# 2024-08-20 10:46:10,775 - INFO - Starting solver with random_seed: 1707755652, max_time_in_seconds: 0.5
# 2024-08-20 10:46:11,298 - INFO - Solver found a solution with objective value: 136670.0
# 2024-08-20 10:46:11,299 - INFO - Starting solver with random_seed: 1239766471, max_time_in_seconds: 0.5
# 2024-08-20 10:46:11,823 - INFO - Solver found a solution with objective value: 136670.0
# 2024-08-20 10:46:11,824 - INFO - Starting solver with random_seed: 1250793174, max_time_in_seconds: 0.5
# 2024-08-20 10:46:12,348 - INFO - Solver found a solution with objective value: 136885.0
# 2024-08-20 10:46:12,348 - INFO - Starting solver with random_seed: 112072815, max_time_in_seconds: 0.5
# 2024-08-20 10:46:12,872 - INFO - Solver found a solution with objective value: 136870.0
# 2024-08-20 10:46:12,873 - INFO - Starting solver with random_seed: 894631065, max_time_in_seconds: 0.5
# 2024-08-20 10:46:13,396 - INFO - Solver found a solution with objective value: 136790.0
# 2024-08-20 10:46:13,397 - INFO - Starting solver with random_seed: 1002280170, max_time_in_seconds: 0.5
# 2024-08-20 10:46:13,948 - INFO - Solver found a solution with objective value: 136665.0
# 2024-08-20 10:46:13,949 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:46:13,949 - INFO - Parameter 'num_workers' is essential for performance.
# 2024-08-20 10:46:13,949 - INFO - Evaluating with params: {'cp_model_probing_level': 0, 'search_branching': 6, 'cut_level': 0, 'num_workers': 8}, num_runs: 40, knockout_score: None
# 2024-08-20 10:46:13,950 - INFO - Starting solver with random_seed: 990831403, max_time_in_seconds: 0.5
# 2024-08-20 10:46:14,470 - INFO - Solver found a solution with objective value: 137145.0
# 2024-08-20 10:46:14,470 - INFO - Starting solver with random_seed: 2103384930, max_time_in_seconds: 0.5
# 2024-08-20 10:46:14,991 - INFO - Solver found a solution with objective value: 137025.0
# 2024-08-20 10:46:14,991 - INFO - Starting solver with random_seed: 1009149361, max_time_in_seconds: 0.5
# 2024-08-20 10:46:15,512 - INFO - Solver found a solution with objective value: 137280.0
# 2024-08-20 10:46:15,513 - INFO - Starting solver with random_seed: 236017197, max_time_in_seconds: 0.5
# 2024-08-20 10:46:16,033 - INFO - Solver found a solution with objective value: 136735.0
# 2024-08-20 10:46:16,034 - INFO - Starting solver with random_seed: 66025882, max_time_in_seconds: 0.5
# 2024-08-20 10:46:16,554 - INFO - Solver found a solution with objective value: 136655.0
# 2024-08-20 10:46:16,555 - INFO - Starting solver with random_seed: 35269228, max_time_in_seconds: 0.5
# 2024-08-20 10:46:17,075 - INFO - Solver found a solution with objective value: 136985.0
# 2024-08-20 10:46:17,076 - INFO - Starting solver with random_seed: 1142851469, max_time_in_seconds: 0.5
# 2024-08-20 10:46:17,595 - INFO - Solver found a solution with objective value: 135860.0
# 2024-08-20 10:46:17,596 - INFO - Starting solver with random_seed: 221152561, max_time_in_seconds: 0.5
# 2024-08-20 10:46:18,115 - INFO - Solver found a solution with objective value: 136910.0
# 2024-08-20 10:46:18,116 - INFO - Starting solver with random_seed: 1034269599, max_time_in_seconds: 0.5
# 2024-08-20 10:46:18,636 - INFO - Solver found a solution with objective value: 136760.0
# 2024-08-20 10:46:18,637 - INFO - Starting solver with random_seed: 722483116, max_time_in_seconds: 0.5
# 2024-08-20 10:46:19,156 - INFO - Solver found a solution with objective value: 136755.0
# 2024-08-20 10:46:19,157 - INFO - Starting solver with random_seed: 1990549667, max_time_in_seconds: 0.5
# 2024-08-20 10:46:19,678 - INFO - Solver found a solution with objective value: 136985.0
# 2024-08-20 10:46:19,679 - INFO - Starting solver with random_seed: 809346077, max_time_in_seconds: 0.5
# 2024-08-20 10:46:20,200 - INFO - Solver found a solution with objective value: 136670.0
# 2024-08-20 10:46:20,200 - INFO - Starting solver with random_seed: 319979787, max_time_in_seconds: 0.5
# 2024-08-20 10:46:20,720 - INFO - Solver found a solution with objective value: 137080.0
# 2024-08-20 10:46:20,721 - INFO - Starting solver with random_seed: 1950482646, max_time_in_seconds: 0.5
# 2024-08-20 10:46:21,242 - INFO - Solver found a solution with objective value: 136665.0
# 2024-08-20 10:46:21,243 - INFO - Starting solver with random_seed: 816021746, max_time_in_seconds: 0.5
# 2024-08-20 10:46:21,761 - INFO - Solver found a solution with objective value: 135065.0
# 2024-08-20 10:46:21,762 - INFO - Starting solver with random_seed: 1466070867, max_time_in_seconds: 0.5
# 2024-08-20 10:46:22,282 - INFO - Solver found a solution with objective value: 136680.0
# 2024-08-20 10:46:22,282 - INFO - Starting solver with random_seed: 1253765141, max_time_in_seconds: 0.5
# 2024-08-20 10:46:22,802 - INFO - Solver found a solution with objective value: 136840.0
# 2024-08-20 10:46:22,803 - INFO - Starting solver with random_seed: 631429287, max_time_in_seconds: 0.5
# 2024-08-20 10:46:23,323 - INFO - Solver found a solution with objective value: 137110.0
# 2024-08-20 10:46:23,324 - INFO - Starting solver with random_seed: 1316908140, max_time_in_seconds: 0.5
# 2024-08-20 10:46:23,876 - INFO - Solver found a solution with objective value: 136980.0
# 2024-08-20 10:46:23,877 - INFO - Starting solver with random_seed: 240406759, max_time_in_seconds: 0.5
# 2024-08-20 10:46:24,397 - INFO - Solver found a solution with objective value: 136985.0
# 2024-08-20 10:46:24,398 - INFO - Starting solver with random_seed: 389133372, max_time_in_seconds: 0.5
# 2024-08-20 10:46:24,922 - INFO - Solver found a solution with objective value: 136530.0
# 2024-08-20 10:46:24,922 - INFO - Starting solver with random_seed: 213021318, max_time_in_seconds: 0.5
# 2024-08-20 10:46:25,444 - INFO - Solver found a solution with objective value: 137120.0
# 2024-08-20 10:46:25,444 - INFO - Starting solver with random_seed: 2102366135, max_time_in_seconds: 0.5
# 2024-08-20 10:46:25,965 - INFO - Solver found a solution with objective value: 137000.0
# 2024-08-20 10:46:25,966 - INFO - Starting solver with random_seed: 517511574, max_time_in_seconds: 0.5
# 2024-08-20 10:46:26,485 - INFO - Solver found a solution with objective value: 136675.0
# 2024-08-20 10:46:26,486 - INFO - Starting solver with random_seed: 1157658371, max_time_in_seconds: 0.5
# 2024-08-20 10:46:27,007 - INFO - Solver found a solution with objective value: 136665.0
# 2024-08-20 10:46:27,008 - INFO - Starting solver with random_seed: 1426817603, max_time_in_seconds: 0.5
# 2024-08-20 10:46:27,535 - INFO - Solver found a solution with objective value: 137075.0
# 2024-08-20 10:46:27,536 - INFO - Starting solver with random_seed: 1378644964, max_time_in_seconds: 0.5
# 2024-08-20 10:46:28,056 - INFO - Solver found a solution with objective value: 137105.0
# 2024-08-20 10:46:28,057 - INFO - Starting solver with random_seed: 2103468741, max_time_in_seconds: 0.5
# 2024-08-20 10:46:28,579 - INFO - Solver found a solution with objective value: 137135.0
# 2024-08-20 10:46:28,579 - INFO - Starting solver with random_seed: 705680992, max_time_in_seconds: 0.5
# 2024-08-20 10:46:29,098 - INFO - Solver found a solution with objective value: 136850.0
# 2024-08-20 10:46:29,099 - INFO - Starting solver with random_seed: 1749804144, max_time_in_seconds: 0.5
# 2024-08-20 10:46:29,619 - INFO - Solver found a solution with objective value: 136875.0
# 2024-08-20 10:46:29,620 - INFO - Starting solver with random_seed: 1421278363, max_time_in_seconds: 0.5
# 2024-08-20 10:46:30,139 - INFO - Solver found a solution with objective value: 137005.0
# 2024-08-20 10:46:30,139 - INFO - Starting solver with random_seed: 1186872512, max_time_in_seconds: 0.5
# 2024-08-20 10:46:30,659 - INFO - Solver found a solution with objective value: 137055.0
# 2024-08-20 10:46:30,660 - INFO - Starting solver with random_seed: 611876906, max_time_in_seconds: 0.5
# 2024-08-20 10:46:31,180 - INFO - Solver found a solution with objective value: 137180.0
# 2024-08-20 10:46:31,180 - INFO - Starting solver with random_seed: 37305835, max_time_in_seconds: 0.5
# 2024-08-20 10:46:31,700 - INFO - Solver found a solution with objective value: 136675.0
# 2024-08-20 10:46:31,701 - INFO - Starting solver with random_seed: 1869310964, max_time_in_seconds: 0.5
# 2024-08-20 10:46:32,223 - INFO - Solver found a solution with objective value: 136980.0
# 2024-08-20 10:46:32,223 - INFO - Starting solver with random_seed: 1205605820, max_time_in_seconds: 0.5
# 2024-08-20 10:46:32,743 - INFO - Solver found a solution with objective value: 136665.0
# 2024-08-20 10:46:32,744 - INFO - Starting solver with random_seed: 1155972423, max_time_in_seconds: 0.5
# 2024-08-20 10:46:33,265 - INFO - Solver found a solution with objective value: 136995.0
# 2024-08-20 10:46:33,266 - INFO - Starting solver with random_seed: 17831462, max_time_in_seconds: 0.5
# 2024-08-20 10:46:33,787 - INFO - Solver found a solution with objective value: 136655.0
# 2024-08-20 10:46:33,787 - INFO - Starting solver with random_seed: 2094142150, max_time_in_seconds: 0.5
# 2024-08-20 10:46:34,306 - INFO - Solver found a solution with objective value: 135840.0
# 2024-08-20 10:46:34,307 - INFO - Starting solver with random_seed: 353802701, max_time_in_seconds: 0.5
# 2024-08-20 10:46:34,827 - INFO - Solver found a solution with objective value: 136655.0
# 2024-08-20 10:46:34,828 - INFO - Evaluation completed and result cached.
# 2024-08-20 10:46:34,828 - INFO - Evaluation complete. Returning results.
# ────────────────────────────────────────────── OPTIMIZED PARAMETERS ───────────────────────────────────────────────
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Parameter              ┃ Value ┃ Contribution ┃ Default Value ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1   │ cp_model_probing_level │   0   │    14.67%    │       2       │
# │ 2   │ search_branching       │   6   │    50.41%    │       0       │
# │ 3   │ cut_level              │   0   │    13.92%    │       1       │
# │ 4   │ num_workers            │   8   │    21.01%    │       0       │
# └─────┴────────────────────────┴───────┴──────────────┴───────────────┘
# ────────────────────────────────────────────────── Descriptions ───────────────────────────────────────────────────
# 1. cp_model_probing_level Defines the intensity of probing during presolve, where variables are temporarily fixed
# to infer more information about the problem. Higher levels of probing can result in a more simplified problem but
# require more computation time during presolve.
#
# 2. search_branching Defines the branching strategy the solver uses to navigate the search tree. The options are:
#
#  • 0 (AUTOMATIC_SEARCH): The solver automatically selects the most appropriate strategy.
#  • 1 (FIXED_SEARCH): Follows a fixed variable order, as specified by the user or the problem model.
#  • 2 (PORTFOLIO_SEARCH): Uses a combination of multiple strategies to explore the search space.
#  • 3 (LP_SEARCH): Branches based on the LP relaxation of the problem, leveraging the reduced costs of variables.
#  • 4 (PSEUDO_COST_SEARCH): Branches using pseudo-costs, which are estimates of the impact of branching decisions
#    based on past experiences.
#  • 5 (PORTFOLIO_WITH_QUICK_RESTART_SEARCH): Quickly explores different heuristics with low conflict limits, aiming
#    to find a good initial solution.
#  • 6 (HINT_SEARCH): Prioritizes decisions based on hints provided by the user or the problem model.
#  • 7 (PARTIAL_FIXED_SEARCH): Begins with a fixed strategy, then switches to automatic search for the remaining
#    decisions.
#  • 8 (RANDOMIZED_SEARCH): Introduces randomization into branching decisions to diversify the search.
#
# 3. cut_level Sets the level of effort the solver will invest in generating cutting planes, which are linear
# constraints added to remove infeasible regions. Properly applied, cuts can significantly reduce the search space
# and help the solver find an optimal solution more quickly.
#
# 4. num_workers Sets the number of workers used to parallelize the search. Usually, more workers lead to faster
# search times, but at the same time, fewer works can use the CPU and memory more efficiently, leading to a
# potentially better search. A value of 0 will use the number of available CPU cores.
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                                 ┃ Mean ┃  Min ┃  Max ┃ #Samples ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━━━┩
# │ Relative gap with Default Parameters   │ 0.03 │ 0.01 │ 0.09 │       40 │
# │ Relative gap with Optimized Parameters │ 0.02 │ 0.01 │ 0.03 │       40 │
# └────────────────────────────────────────┴──────┴──────┴──────┴──────────┘
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭──────────────────────────────────────────────────── WARNING ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │      The optimized parameters listed above were obtained based on a sampling approach                           │
# │      and may not fully capture the complexities of the entire problem space.                                    │
# │      While statistical reasoning has been applied, these results should be considered                           │
# │      as a suggestion for further evaluation rather than definitive settings.                                    │
# │                                                                                                                 │
# │      It is strongly recommended to validate these parameters in larger, more comprehensive                      │
# │      experiments before adopting them in critical applications.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2024-08-20 10:46:34,843 - INFO - Hyperparameter tuning completed.
